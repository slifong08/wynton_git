# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
from sklearn.decomposition import PCA

import sys

# %%
CL, MER, NMUTS = "common", 15, 2
CONFIG = os.path.join(os.path.dirname(os.getcwd()), "config.ini")
PATH="/wynton/home/ahituv/fongsl/nullomers/data/lock/common/concatmers/sei_predictions/chromatin-profiles-hdf5/"
COORS = [
    "chr10:133080140-133080340",  # inactive
    'chr1:206663895-206664095',  # inactive
    "chr15:45387502-45387702",  # inactive
    
    "chr12:50933777-50933977",  # active
    "chr16:22922244-22922444",   # active
    "chr6:73520947-73521147",   # active
    "chr8:41156753-41156953"   # active
]

INACTIVE = [    "chr10:133080140-133080340",  # inactive
    'chr1:206663895-206664095',  # inactive
    "chr15:45387502-45387702",  # inactive
           ]

# %% [markdown]
# # predict sequence classes

# %%
os.chdir("/wynton/home/ahituv/fongsl/bin/sei-framework")

for COOR in COORS:
    
    # results file
    OUT =  os.path.join(PATH,
                 f"common.15mers.2mut.nulls.fo.pam.CONCAT-10.ext4096.{COOR}.raw_sequence_class_scores.npy")
    
    # infile
    F = os.path.join(
        PATH, f"common.{MER}mers.{NMUTS}mut.nulls.fo.pam.CONCAT-10.ext4096.{COOR}_predictions.h5")
    
    # sei part 2 command
    cmd = [
            "bash /wynton/home/ahituv/fongsl/bin/sei-framework/2_raw_sc_score.sh",
            F, 
            PATH
            ]

    # if not already run
    if os.path.exists(OUT) is False:
        print(" ".join(cmd))
        os.system(" ".join(cmd))

# %% [markdown]
# # analyze data

# %% [markdown]
# ## load labels

# %%
def processLabel(label_file):
    
    # read label file as pd dataframe
    lab = pd.read_csv(label_file,sep ='\t')
    lab = lab.drop(columns = ["index"])  # redundant index column
    
    # rename the first col. This is the endogenous sequence
    lab["name"].iloc[0] = f"{COOR}_-1_endog"
    
    # str splitting
    # coordinates
    lab["coor"]= lab["name"].apply(lambda x: x.split("_")[0] if "_" in x else None)

    # the concat number
    lab["concat_id"]= lab["name"].apply(lambda x: ".".join(x.split("_")[1:]))
    lab["concat_id_number"]= lab["name"].apply(lambda x: x.split("_")[1]).map(int)
    
    # the type (endogenous, kmer, nullomer )
    lab["concat_type"]= lab["name"].apply(lambda x: x.split("_")[2])
    
    lab["c"] = "b"
    
    lab.loc[lab["concat_type"].str.contains("endog"), "c"] = "r"
    lab.loc[lab["concat_type"].str.contains("kmer"), "c"] = "y"
    
    return lab

# %%
def returnSequenceClassLabels():
    file="/wynton/home/ahituv/fongsl/bin/sei-framework/sequence_class_labels.csv"
    lab = pd.read_csv(file)
    
    return lab

# %%
"""
# get sequence class labels. See Methods section of Chen 2022 for interpretation of these PC labels.
# apparently labels >40 are low active/heterochromatin. 
#Make up <2% of the genome. But 2% of the genome can still be significant.
"""

seqClass = returnSequenceClassLabels()

seqClass.head()
# Out:
#   #Sequence class label         Sequence class name  Rank by size Group
# 0                   PC1  Polycomb / Heterochromatin             0    PC
# 1                    L1                  Low signal             1     L
# 2                   TN1               Transcription             2    TN
# 3                   TN2               Transcription             3    TN
# 4                    L2                  Low signal             4     L

# %%
datas = {}
for COOR in COORS:
    # open npy data
    data = np.load(
        os.path.join(PATH,
                 f"common.15mers.2mut.nulls.fo.pam.CONCAT-10.ext4096.{COOR}.raw_sequence_class_scores.npy"),
                allow_pickle=True)
    labels = os.path.join(PATH, 
                     f"common.15mers.2mut.nulls.fo.pam.CONCAT-10.ext4096.{COOR}_row_labels.txt")

    # turn into pd dataframe
    df = pd.DataFrame(data)
    
    # rename columns
    df.columns = list(seqClass["#Sequence class label"])[:-1]
    
    # process labels file
    lab = processLabel(labels)
    
    ## add labels and data together
    df = pd.merge(lab, df, left_index=True, right_index=True)

    datas[COOR]= df

# %% [markdown]
# ## combine results

# %%
df = pd.concat(datas.values())

df.head()
# Out:
#                                       name                       coor  \
# 0       chr10:133080140-133080340_-1_endog  chr10:133080140-133080340
# 1  chr10:133080140-133080340_1_concat-null  chr10:133080140-133080340
# 2  chr10:133080140-133080340_1_concat-kmer  chr10:133080140-133080340
# 3  chr10:133080140-133080340_2_concat-null  chr10:133080140-133080340
# 4  chr10:133080140-133080340_2_concat-kmer  chr10:133080140-133080340
#
#        concat_id  concat_id_number  concat_type  c       PC1        L1  \
# 0       -1.endog                -1        endog  r  6.482182  3.249681
# 1  1.concat-null                 1  concat-null  b  6.183464  3.118330
# 2  1.concat-kmer                 1  concat-kmer  y  6.239453  3.171999
# 3  2.concat-null                 2  concat-null  b  7.069335  3.608191
# 4  2.concat-kmer                 2  concat-kmer  y  7.010955  3.626810
#
#         TN1       TN2  ...     L/HET     L/HET     L/HET     L/HET     L/HET  \
# 0  2.447702  2.717271  ...  0.042906  1.150516  4.432318  5.584652  2.107701
# 1  2.713802  2.839614  ...  0.047606  1.319265  5.166355  5.425963  1.984890
# 2  3.112989  3.197493  ...  0.047745  1.321789  5.021655  5.515739  2.007824
# 3  3.202336  3.309253  ...  0.048920  1.496726  5.892833  6.020467  2.351188
# 4  3.186181  3.335327  ...  0.050829  1.385264  5.334833  5.957517  2.289851
#
#       L/HET     L/HET     L/HET     L/HET     L/HET
# 0  2.672769  3.682160  2.677110  3.495075  3.912445
# 1  2.883699  4.535702  2.611302  3.187604  4.254385
# 2  2.747476  4.383468  2.757899  3.307534  4.091720
# 3  3.412969  4.809049  2.949658  3.507294  4.885540
# 4  3.010276  4.542644  2.919258  3.685547  4.431013
#
# [5 rows x 67 columns]

# %% [markdown]
# # PCA

# %%
pca = PCA(n_components=2)

# %%
X, y = df[list(df)[5:45]], df[list(df)[:5]]
y
# Out:
#                                           name                       coor  \
# 0           chr10:133080140-133080340_-1_endog  chr10:133080140-133080340
# 1      chr10:133080140-133080340_1_concat-null  chr10:133080140-133080340
# 2      chr10:133080140-133080340_1_concat-kmer  chr10:133080140-133080340
# 3      chr10:133080140-133080340_2_concat-null  chr10:133080140-133080340
# 4      chr10:133080140-133080340_2_concat-kmer  chr10:133080140-133080340
# ...                                        ...                        ...
# 16000  chr8:41156753-41156953_8000_concat-kmer     chr8:41156753-41156953
# 16001  chr8:41156753-41156953_8001_concat-null     chr8:41156753-41156953
# 16002  chr8:41156753-41156953_8001_concat-kmer     chr8:41156753-41156953
# 16003  chr8:41156753-41156953_8002_concat-null     chr8:41156753-41156953
# 16004  chr8:41156753-41156953_8002_concat-kmer     chr8:41156753-41156953
#
#               concat_id  concat_type  c
# 0              -1.endog        endog  r
# 1         1.concat-null  concat-null  b
# 2         1.concat-kmer  concat-kmer  y
# 3         2.concat-null  concat-null  b
# 4         2.concat-kmer  concat-kmer  y
# ...                 ...          ... ..
# 16000  8000.concat-kmer  concat-kmer  y
# 16001  8001.concat-null  concat-null  b
# 16002  8001.concat-kmer  concat-kmer  y
# 16003  8002.concat-null  concat-null  b
# 16004  8002.concat-kmer  concat-kmer  y
#
# [112035 rows x 5 columns]

# %%
X
# Out:
#             PC1        L1       TN1       TN2        L2        E1        E2  \
# 0      6.482182  3.249681  2.447702  2.717271  2.327597  2.238897  2.171775
# 1      6.183464  3.118330  2.713802  2.839614  2.388879  1.648716  1.705572
# 2      6.239453  3.171999  3.112989  3.197493  2.314096  1.757548  1.836024
# 3      7.069335  3.608191  3.202336  3.309253  2.725402  1.887302  1.973553
# 4      7.010955  3.626810  3.186181  3.335327  2.570305  2.172008  2.099837
# ...         ...       ...       ...       ...       ...       ...       ...
# 16000  7.662255  3.391543  1.914996  2.318242  1.287338  5.832050  5.064692
# 16001  8.001386  3.271159  2.202346  2.498882  1.358372  5.088524  4.997580
# 16002  5.485659  2.074228  2.029815  2.162144  0.714193  2.476915  3.419506
# 16003  4.512173  2.098466  1.732739  2.007023  0.756263  2.948461  3.605752
# 16004  3.354784  1.930914  1.275603  1.630189  0.672754  3.046881  3.704668
#
#              E3        L3        E4  ...       E10       TF4      HET4  \
# 0      2.628973  4.452637  1.565991  ...  1.836911  1.284182  5.360318
# 1      2.091077  4.791674  1.047894  ...  1.789563  1.133129  6.238221
# 2      2.222911  4.818022  1.122384  ...  1.900859  1.182098  6.006309
# 3      2.447114  5.124232  1.185968  ...  1.853249  1.266158  7.279461
# 4      2.583747  5.120929  1.396515  ...  1.970907  1.348068  6.702960
# ...         ...       ...       ...  ...       ...       ...       ...
# 16000  4.421478  4.894295  5.589330  ...  2.544257  2.085053  3.863820
# 16001  4.188116  5.006704  6.200764  ...  2.171586  2.072828  4.654726
# 16002  2.561564  3.919765  2.341989  ...  1.050511  1.038451  2.929342
# 16003  2.675657  3.539173  2.690254  ...  1.112488  1.147059  2.463839
# 16004  2.746584  2.501736  2.669022  ...  1.059937  1.092568  1.529614
#
#              L7       PC4      HET5       E11       TF5       E12      HET6
# 0      1.462608  3.132465  1.269848  2.415537  1.753370  1.756911  0.520774
# 1      1.863442  2.293423  1.643429  2.042949  1.549798  1.541749  0.680231
# 2      1.740426  2.496108  1.550516  2.155421  1.655200  1.608286  0.647729
# 3      2.073701  2.777778  1.807451  2.343158  1.813646  1.787400  0.727778
# 4      1.886544  3.172782  1.657862  2.479091  1.867631  1.878779  0.673140
# ...         ...       ...       ...       ...       ...       ...       ...
# 16000  1.099671  5.453306  1.164527  4.592004  2.822577  5.051708  0.541606
# 16001  1.233543  4.485463  1.572253  4.642967  3.000865  9.043920  0.679933
# 16002  0.701699  2.740723  0.545254  2.416367  1.700914  2.191827  0.247113
# 16003  0.837178  2.842022  0.673835  2.442724  1.688092  2.455644  0.302095
# 16004  0.532485  2.676573  0.331450  2.123689  1.515477  1.942851  0.131743
#
# [112035 rows x 40 columns]

# %%
Xt = pca.fit_transform(df[list(df)[5:45]])
pca.explained_variance_ratio_
# Out:
# array([0.96772208, 0.01577764])

# %%
y["c"] = "b"

y.loc[y["coor"].str.contains("endog"), "c"] = "r"
y.loc[y["coor"].str.contains("kmer"), "c"] = "y"
# Out:
#                                           name                       coor  \
# 0           chr10:133080140-133080340_-1_endog  chr10:133080140-133080340
# 1      chr10:133080140-133080340_1_concat-null  chr10:133080140-133080340
# 2      chr10:133080140-133080340_1_concat-kmer  chr10:133080140-133080340
# 3      chr10:133080140-133080340_2_concat-null  chr10:133080140-133080340
# 4      chr10:133080140-133080340_2_concat-kmer  chr10:133080140-133080340
# ...                                        ...                        ...
# 16000  chr8:41156753-41156953_8000_concat-kmer     chr8:41156753-41156953
# 16001  chr8:41156753-41156953_8001_concat-null     chr8:41156753-41156953
# 16002  chr8:41156753-41156953_8001_concat-kmer     chr8:41156753-41156953
# 16003  chr8:41156753-41156953_8002_concat-null     chr8:41156753-41156953
# 16004  chr8:41156753-41156953_8002_concat-kmer     chr8:41156753-41156953
#
#               concat_id  concat_type  c
# 0              -1.endog        endog  r
# 1         1.concat-null  concat-null  b
# 2         1.concat-kmer  concat-kmer  y
# 3         2.concat-null  concat-null  b
# 4         2.concat-kmer  concat-kmer  y
# ...                 ...          ... ..
# 16000  8000.concat-kmer  concat-kmer  y
# 16001  8001.concat-null  concat-null  b
# 16002  8001.concat-kmer  concat-kmer  y
# 16003  8002.concat-null  concat-null  b
# 16004  8002.concat-kmer  concat-kmer  y
#
# [112035 rows x 5 columns]

# %%
fig, ax= plt.subplots(figsize=(6,6))
plt.scatter(np.array(Xt)[:,0], np.array(Xt)[:,1],  
            c=(y["c"]),
            alpha=0.2)
ax.set(xlabel=f"PC1-{round(pca.explained_variance_ratio_[0],2)}",
       ylabel=f"PC1-{round(pca.explained_variance_ratio_[1],2)}",
       title="label encoded sequence PCA"
)
# Out:
# [Text(0.5, 0, 'PC1-0.97'),
#  Text(0, 0.5, 'PC1-0.02'),
#  Text(0.5, 1.0, 'label encoded sequence PCA')]

# %% [markdown]
# # heat map

# %%
df.loc[(df["concat_id_number"]==1)| (df["concat_id_number"]==-1), 
                list(df)[:44]].sort_values(by="concat_id")
# Out:
#                                       name                       coor  \
# 0       chr10:133080140-133080340_-1_endog  chr10:133080140-133080340
# 0          chr8:41156753-41156953_-1_endog     chr8:41156753-41156953
# 0        chr1:206663895-206664095_-1_endog   chr1:206663895-206664095
# 0          chr6:73520947-73521147_-1_endog     chr6:73520947-73521147
# 0         chr15:45387502-45387702_-1_endog    chr15:45387502-45387702
# 0         chr16:22922244-22922444_-1_endog    chr16:22922244-22922444
# 0         chr12:50933777-50933977_-1_endog    chr12:50933777-50933977
# 2     chr6:73520947-73521147_1_concat-kmer     chr6:73520947-73521147
# 2    chr16:22922244-22922444_1_concat-kmer    chr16:22922244-22922444
# 2    chr12:50933777-50933977_1_concat-kmer    chr12:50933777-50933977
# 2     chr8:41156753-41156953_1_concat-kmer     chr8:41156753-41156953
# 2    chr15:45387502-45387702_1_concat-kmer    chr15:45387502-45387702
# 2   chr1:206663895-206664095_1_concat-kmer   chr1:206663895-206664095
# 2  chr10:133080140-133080340_1_concat-kmer  chr10:133080140-133080340
# 1    chr15:45387502-45387702_1_concat-null    chr15:45387502-45387702
# 1    chr16:22922244-22922444_1_concat-null    chr16:22922244-22922444
# 1   chr1:206663895-206664095_1_concat-null   chr1:206663895-206664095
# 1     chr6:73520947-73521147_1_concat-null     chr6:73520947-73521147
# 1  chr10:133080140-133080340_1_concat-null  chr10:133080140-133080340
# 1     chr8:41156753-41156953_1_concat-null     chr8:41156753-41156953
# 1    chr12:50933777-50933977_1_concat-null    chr12:50933777-50933977
#
#        concat_id  concat_id_number  concat_type  c        PC1        L1  \
# 0       -1.endog                -1        endog  r   6.482182  3.249681
# 0       -1.endog                -1        endog  r   1.666308  1.556214
# 0       -1.endog                -1        endog  r  15.366208  9.091540
# 0       -1.endog                -1        endog  r   9.681533  6.467166
# 0       -1.endog                -1        endog  r   1.442957  2.708474
# 0       -1.endog                -1        endog  r   1.433577  1.098763
# 0       -1.endog                -1        endog  r   3.166821  2.487803
# 2  1.concat-kmer                 1  concat-kmer  y  15.182599  8.648743
# 2  1.concat-kmer                 1  concat-kmer  y   5.845751  1.938649
# 2  1.concat-kmer                 1  concat-kmer  y   6.626962  2.451669
# 2  1.concat-kmer                 1  concat-kmer  y   6.284477  2.407966
# 2  1.concat-kmer                 1  concat-kmer  y   3.678838  1.177362
# 2  1.concat-kmer                 1  concat-kmer  y  15.818432  9.532699
# 2  1.concat-kmer                 1  concat-kmer  y   6.239453  3.171999
# 1  1.concat-null                 1  concat-null  b   4.063116  1.703613
# 1  1.concat-null                 1  concat-null  b   6.259562  2.368094
# 1  1.concat-null                 1  concat-null  b  15.352542  9.062626
# 1  1.concat-null                 1  concat-null  b  13.447769  8.008969
# 1  1.concat-null                 1  concat-null  b   6.183464  3.118330
# 1  1.concat-null                 1  concat-null  b   6.493598  2.708278
# 1  1.concat-null                 1  concat-null  b   7.558243  3.054790
#
#         TN1       TN2  ...       TN4      HET3        E10       TF4  \
# 0  2.447702  2.717271  ...  3.334962  4.111442   1.836911  1.284182
# 0  0.558354  0.884454  ...  0.769935  1.425835   0.743237  0.781192
# 0  4.215595  5.477120  ...  5.218499  5.027758   9.706249  6.902284
# 0  4.226597  4.678774  ...  4.553813  4.502370  10.476438  8.867321
# 0  1.288940  1.778923  ...  0.795445  1.001410   2.369303  2.910065
# 0  0.202435  0.408190  ...  0.302005  1.065397   0.433431  0.348505
# 0  1.941712  2.200844  ...  1.919622  1.840171   1.348550  1.527436
# 2  6.063208  6.583894  ...  6.760425  6.380296  11.939509  9.890211
# 2  0.736476  0.970105  ...  1.763288  1.973319   0.743097  0.630435
# 2  3.674239  3.383050  ...  4.500256  1.965438   1.217079  1.243925
# 2  1.561678  1.848972  ...  2.523420  1.822229   1.292781  1.210489
# 2  0.922660  1.028825  ...  1.696518  1.037001   0.575590  0.568236
# 2  4.158573  5.351134  ...  5.057609  5.346304  10.903133  7.044355
# 2  3.112989  3.197493  ...  3.917738  4.266589   1.900859  1.182098
# 1  1.061317  1.231734  ...  1.674082  1.364613   1.274873  1.238321
# 1  0.804817  1.124693  ...  1.835050  2.698183   0.949450  0.782934
# 1  4.286266  5.330964  ...  5.126574  5.455207  10.968252  7.380904
# 1  5.428226  5.896829  ...  6.020700  5.880239  11.605576  9.939812
# 1  2.713802  2.839614  ...  3.552495  4.442715   1.789563  1.133129
# 1  1.551252  1.894324  ...  2.531645  2.375741   1.446011  1.347145
# 1  3.308861  3.239089  ...  4.232932  2.549629   2.044911  1.880671
#
#         HET4        L7        PC4       HET5        E11        TF5
# 0   5.360318  1.462608   3.132465   1.269848   2.415537   1.753370
# 0   1.394160  0.620902   1.488119   0.354673   1.311262   0.942450
# 0   6.821299  2.864892  14.366849   3.767941  20.653798   8.172729
# 0   6.733261  3.178491   6.926714  11.759428  18.228869  11.151450
# 0   1.040438  0.530540   1.987005   0.790223   2.702060  11.206530
# 0   0.852229  0.267750   1.235229   0.116676   0.633057   0.498880
# 0   1.734370  0.869475   2.266706   0.591974   4.039957   2.205238
# 2  10.210478  3.778318   9.883284  12.676018  23.336986  12.863180
# 2   3.443420  1.234131   2.764223   1.332756   1.523268   0.967261
# 2   3.758654  1.412601   2.783473   1.431922   4.115666   2.147080
# 2   2.955937  1.127687   3.745331   1.138076   2.714915   1.872160
# 2   2.036358  0.653987   1.281001   0.822508   1.242365   1.193767
# 2   7.510131  3.378224  16.328203   4.603846  18.537966   8.422069
# 2   6.006309  1.740426   2.496108   1.550516   2.155421   1.655200
# 1   2.390146  0.656075   1.990400   0.948075   2.214153   2.348546
# 1   4.205642  1.269149   3.240686   1.278318   1.854777   1.195015
# 1   8.003675  3.383415  14.806680   5.603325  19.976667   8.629214
# 1   9.156630  3.829063   8.688380  12.827362  21.701395  12.369019
# 1   6.238221  1.863442   2.293423   1.643429   2.042949   1.549798
# 1   3.831397  1.281632   3.826469   1.269305   3.037488   2.014320
# 1   4.568605  1.480426   3.718322   1.857251   5.847301   2.947367
#
# [21 rows x 44 columns]

# %%
max_concat_n =df["concat_id_number"].max() 
for i in np.arange(max_concat_n):

    test=df.loc[(df["concat_id_number"]==i+1)| (df["concat_id_number"]==-1), 
                list(df)[:44]].sort_values(by="concat_id")
    test=test.set_index("name")


    lut = dict(zip(test["concat_type"].unique(), "ryb"))
    print(lut)
    row_colors = test.concat_type.map(lut)

    cm = sns.clustermap(test[test.columns[5:]].drop_duplicates(), 
                       row_colors=row_colors,
                       figsize=(12,8),
                        robust=True,
                        #row_cluster=False,
                       )

    plt.setp(cm.ax_heatmap.xaxis.get_majorticklabels(), fontsize=10)
    plt.setp(cm.ax_heatmap.yaxis.get_majorticklabels(), fontsize=10)

    if i>2:
        break
# Out:
# {'endog': 'r', 'concat-kmer': 'y', 'concat-null': 'b'}
# {'endog': 'r', 'concat-kmer': 'y', 'concat-null': 'b'}
# {'endog': 'r', 'concat-kmer': 'y', 'concat-null': 'b'}
# {'endog': 'r', 'concat-kmer': 'y', 'concat-null': 'b'}
