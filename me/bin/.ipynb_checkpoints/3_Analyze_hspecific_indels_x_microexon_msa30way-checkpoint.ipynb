# %% [markdown]
# # intersect microexons by human-specific gaps, insertions, substitutions
#
# input
#
# - MSA 30-way all human gaps/insertions/subs bed
#     - formatted from ./2_format_subs_indels.ipynb
#
# - microexon bed
#     - formatted from ./0_microexon-to-bed.ipynb
#
# method
#    - pybedtool intersection: microexon x hu-specific subs/gaps/ins
#        - write microexon info, write hu-specific subs/gaps/ins info
#
#    - write intersection file
#
#    - inspect microexon overlapping variants
#
#    - inspect microexon intron/exon variants
#
#
# return
#    - intersection file

# %%
import matplotlib.pyplot as plt
import numpy as np
import os, sys
import pandas as pd
import pybedtools as pbt
import seaborn as sns
sys.path.append("/wynton/home/ahituv/fongsl/tools/py_")
import config_readwrite as crw

config_tag = "config.ini"
config, configfile_name = crw.read_config(os.path.join(os.getcwd(), config_tag))

PATH = config["hu-specific"]["path"]
ALL = config["hu-specific"]["file"]
ME = config["microexon"]["bed"]

# %% [markdown]
# ## write outfile

# %%
OUT = "/wynton/home/ahituv/fongsl/microexons/data/human.hg38.total_detected_truncated_x_HUSP.bed"

# add out file to config
crw.check_section(config, "hu_x_me")
config["hu_x_me"]["bed"]=OUT
crw.write_config(config, configfile_name )

# %% [markdown]
# ## load bed objects

# %%
bed = pbt.BedTool(ALL)
me = pbt.BedTool(ME)

# %% [markdown]
# ## intersect human-specific deletions with microexon

# %%
intr = me.intersect(bed, output=OUT, wa=True, wb=True)

# %% [markdown]
# ## inspect microexons

# %%
# check column names
if "#chr" not in list(pd.read_csv(OUT, sep = '\t', nrows=2)):
    
    # if columns not named, name cols
    cols = ["#chr", "startMe", "endMe", "geneName", "label", 
            "#chrVar", "startVar", "endVar", "nSpecies", 
            "mafStart", "mafLen","species", "mut", "mutLen", "id"]
    
    # open out file, drop duplicates
    df = pd.read_csv(OUT, sep='\t', header=None).drop_duplicates()
    
    # rename cols
    df.columns=cols
    
    # re-save outfile
    df.to_csv(OUT, sep='\t', index=False)
else:
    df = pd.read_csv(OUT, sep='\t').drop_duplicates()

# %%
df.head()
# Out:
#     #chr   startMe     endMe geneName      label #chrVar  startVar    endVar  \
# 0  chr22  35954273  35954283   RBFOX2  microexon   chr22  35954281  35954282
# 1  chr18  55601917  55601921     TCF4  microexon   chr18  55601919  55601920
# 2   chr6  79203033  79203047    HMGN3  microexon    chr6  79203033  79203034
# 3   chr3  16511156  16511159    RFTN1  microexon    chr3  16511156  16511157
# 4   chr3  56448386  56448390     ERC2  microexon    chr3  56448387  56448388
#
#    nSpecies  mafStart  mafLen  \
# 0        28  35954255     299
# 1        24  55601867      60
# 2        29  79202977     140
# 3        30  16511069     369
# 4        29  56448252     244
#
#                                              species  mut  mutLen  \
# 0  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 1  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 2  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 3  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 4  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
#
#                         id
# 0  chr22:35954281-35954282
# 1  chr18:55601919-55601920
# 2   chr6:79203033-79203034
# 3   chr3:16511156-16511157
# 4   chr3:56448387-56448388

# %% [markdown]
# # how many microexon overlaps are there?

# %%
df.groupby("label")["id"].count()
# Out:
# label
# dsINT        200727
# microexon        52
# upINT        224381
# Name: id, dtype: int64

# %% [markdown]
# ## what kind of mutations overlap microexons?

# %%
df.groupby(["label", "mut"])["id"].count()
# Out:
# label      mut
# dsINT      DEL     10578
#            INS      9102
#            SUB    181047
# microexon  DEL         5
#            INS         1
#            SUB        46
# upINT      DEL     11637
#            INS      9846
#            SUB    202898
# Name: id, dtype: int64

# %% [markdown]
# ## inspect Dels

# %%
df.loc[(df["label"]== 'microexon') & (df["mut"]=="DEL")]
# Out:
#      #chr    startMe      endMe   geneName      label #chrVar   startVar  \
# 9   chr20    5571014    5571031     GPCPD1  microexon   chr20    5571022
# 12   chr9   40228343   40228365  ANKRD20A2  microexon    chr9   40228343
# 20   chr4   77928045   77928067      MRPL1  microexon    chr4   77928045
# 36  chr17   12095462   12095466     MAP2K4  microexon   chr17   12095465
# 43   chr2  241684501  241684508      DTYMK  microexon    chr2  241684505
#
#        endVar  nSpecies   mafStart  mafLen  \
# 9     5571023        23    5570792     349
# 12   40228344        16   40228121     273
# 20   77928046        27   77927783     809
# 36   12095466        30   12095134     428
# 43  241684506        20  241684465     280
#
#                                               species  mut  mutLen  \
# 9   hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  DEL       3
# 12  hg38,panPan2,gorGor5,nomLeu3,rheMac8,macFas5,m...  DEL       1
# 20  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  DEL       1
# 36  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  DEL       4
# 43  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  DEL       8
#
#                           id
# 9      chr20:5571022-5571023
# 12    chr9:40228343-40228344
# 20    chr4:77928045-77928046
# 36   chr17:12095465-12095466
# 43  chr2:241684505-241684506

# %% [markdown]
# ## inspect INS

# %%
df.loc[(df["label"]== 'microexon') & (df["mut"]=="INS")]
# Out:
#     #chr    startMe      endMe geneName      label #chrVar   startVar  \
# 35  chr8  124496879  124496901   TATDN1  microexon    chr8  124496884
#
#        endVar  nSpecies   mafStart  mafLen  \
# 35  124496885        21  124496718     272
#
#                                               species  mut  mutLen  \
# 35  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  INS       1
#
#                           id
# 35  chr8:124496884-124496885

# %% [markdown]
# ## inspect subs

# %%
df.loc[(df["label"]== 'microexon') & (df["mut"]=="SUB")]
# Out:
#      #chr    startMe      endMe    geneName      label #chrVar   startVar  \
# 0   chr22   35954273   35954283      RBFOX2  microexon   chr22   35954281
# 1   chr18   55601917   55601921        TCF4  microexon   chr18   55601919
# 2    chr6   79203033   79203047       HMGN3  microexon    chr6   79203033
# 3    chr3   16511156   16511159       RFTN1  microexon    chr3   16511156
# 4    chr3   56448386   56448390        ERC2  microexon    chr3   56448387
# 5   chr18   13006176   13006197      CEP192  microexon   chr18   13006189
# 6    chr9    9069540    9069545       PTPRD  microexon    chr9    9069544
# 7    chr8   73955646   73955663        ELOC  microexon    chr8   73955661
# 8    chr4   82530828   82530832    TMEM150C  microexon    chr4   82530831
# 10   chr5  134612453  134612477       SAR1B  microexon    chr5  134612469
# 11   chr7   87681056   87681061       ABCB1  microexon    chr7   87681057
# 13   chr9   88445252   88445279       SPIN1  microexon    chr9   88445269
# 14  chr17   19863329   19863348        ULK2  microexon   chr17   19863340
# 15   chr5  113102160  113102168         MCC  microexon    chr5  113102161
# 16   chr5   27026483   27026510        CDH9  microexon    chr5   27026490
# 17  chr19   44268302   44268319      ZNF233  microexon   chr19   44268317
# 18  chr11  113740207  113740213        ZW10  microexon   chr11  113740212
# 19  chr11   66657242   66657259        RBM4  microexon   chr11   66657256
# 21   chr2   95899824   95899851    ANKRD36C  microexon    chr2   95899847
# 22  chr10   94846137   94846161     CYP2C19  microexon   chr10   94846158
# 23   chr4   91022032   91022054      CCSER1  microexon    chr4   91022038
# 24   chr4  142617378  142617404      INPP4B  microexon    chr4  142617385
# 25  chr19   47205103   47205129        SAE1  microexon   chr19   47205118
# 26  chr10   73329449   73329471      CFAP70  microexon   chr10   73329461
# 27  chr12   63591817   63591842     DPY19L2  microexon   chr12   63591832
# 28  chr12   63591817   63591842     DPY19L2  microexon   chr12   63591833
# 29   chr1   23110601   23110607       LUZP1  microexon    chr1   23110601
# 30  chr16   83000698   83000706       CDH13  microexon   chr16   83000699
# 31   chr2  169688942  169688948     CCDC173  microexon    chr2  169688943
# 32  chr21    5122542    5122557  FP565260.2  microexon   chr21    5122555
# 33   chr9  136051731  136051740       NACC2  microexon    chr9  136051735
# 34   chr2   97552009   97552032    ANKRD36B  microexon    chr2   97552021
# 37  chr18   13717532   13717553     FAM210A  microexon   chr18   13717545
# 38   chr1  115663115  115663121      VANGL1  microexon    chr1  115663117
# 39   chr2  120023535  120023539     EPB41L5  microexon    chr2  120023538
# 40   chr9   33546741   33546765    ANKRD18B  microexon    chr9   33546757
# 41   chr1  111135247  111135252       DRAM2  microexon    chr1  111135247
# 42   chr6  169663119  169663134       WDR27  microexon    chr6  169663127
# 44  chr20   35866735   35866738       PHF20  microexon   chr20   35866737
# 45  chr20   44632403   44632426         ADA  microexon   chr20   44632409
# 46   chr3   43673973   43673976       ANO10  microexon    chr3   43673973
# 47  chr16   69457783   69457798       CYB5B  microexon   chr16   69457783
# 48   chr5   65566083   65566100       PPWD1  microexon    chr5   65566091
# 49   chr1   17574025   17574029   ARHGEF10L  microexon    chr1   17574027
# 50   chr2  228040708  228040730      SPHKAP  microexon    chr2  228040727
# 51  chr21   44139495   44139510      GATD3A  microexon   chr21   44139496
#
#        endVar  nSpecies   mafStart  mafLen  \
# 0    35954282        28   35954255     299
# 1    55601920        24   55601867      60
# 2    79203034        29   79202977     140
# 3    16511157        30   16511069     369
# 4    56448388        29   56448252     244
# 5    13006190        25   13006168      75
# 6     9069545        30    9069486     177
# 7    73955662        21   73955622     154
# 8    82530832        21   82530715     402
# 10  134612470        21  134612460      98
# 11   87681058         6   87680784    1136
# 13   88445270        24   88445167     143
# 14   19863341        23   19863282     211
# 15  113102162        28  113102154      25
# 16   27026491        23   27026259     295
# 17   44268318        16   44268163     328
# 18  113740213        23  113740131     154
# 19   66657257        13   66657129     355
# 21   95899848        13   95899821      27
# 22   94846159        19   94846122      87
# 23   91022039         6   91022008    1799
# 24  142617386        23  142617377      17
# 25   47205119        25   47205104      22
# 26   73329462         4   73328795     685
# 27   63591833        16   63591754      97
# 28   63591834        16   63591754      97
# 29   23110602         9   23110594       9
# 30   83000700         8   83000601     292
# 31  169688944         7  169688481     572
# 32    5122556        16    5122541     249
# 33  136051736        23  136051721     103
# 34   97552022        15   97552018      29
# 37   13717546        17   13717521      53
# 38  115663118        24  115663111      40
# 39  120023539        14  120023284     571
# 40   33546758        20   33546603     300
# 41  111135248        29  111135242      16
# 42  169663128        22  169663125       3
# 44   35866738        28   35866651     105
# 45   44632410        23   44632374     265
# 46   43673974        23   43673960      17
# 47   69457784        29   69457732      63
# 48   65566092        28   65566028      74
# 49   17574028        25   17573996      43
# 50  228040728        27  228040712      66
# 51   44139497        19   44139322     239
#
#                                               species  mut  mutLen  \
# 0   hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 1   hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 2   hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 3   hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 4   hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 5   hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,m...  SUB       1
# 6   hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 7   hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 8   hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 10  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 11       hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3  SUB       1
# 13  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 14  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 15  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 16  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 17  hg38,panTro5,panPan2,gorGor5,ponAbe2,rheMac8,m...  SUB       1
# 18  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 19  hg38,panTro5,gorGor5,ponAbe2,nomLeu3,rheMac8,m...  SUB       1
# 21  hg38,panTro5,ponAbe2,rheMac8,macFas5,macNem1,c...  SUB       1
# 22  hg38,panTro5,panPan2,gorGor5,nomLeu3,rheMac8,m...  SUB       1
# 23       hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3  SUB       1
# 24  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 25  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 26                       hg38,panTro5,panPan2,gorGor5  SUB       1
# 27  hg38,panTro5,panPan2,gorGor5,nomLeu3,rheMac8,m...  SUB       1
# 28  hg38,panTro5,panPan2,gorGor5,nomLeu3,rheMac8,m...  SUB       1
# 29  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 30  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,c...  SUB       1
# 31  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,p...  SUB       1
# 32  hg38,panTro5,panPan2,gorGor5,nomLeu3,rheMac8,m...  SUB       1
# 33  hg38,panTro5,panPan2,gorGor5,rheMac8,macFas5,m...  SUB       1
# 34  hg38,panTro5,gorGor5,rheMac8,macFas5,macNem1,c...  SUB       1
# 37  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 38  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 39  hg38,panTro5,panPan2,gorGor5,ponAbe2,rheMac8,m...  SUB       1
# 40  hg38,panTro5,panPan2,gorGor5,nomLeu3,rheMac8,m...  SUB       1
# 41  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 42  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 44  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 45  hg38,panTro5,panPan2,gorGor5,ponAbe2,rheMac8,m...  SUB       1
# 46  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 47  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 48  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
# 49  hg38,panTro5,panPan2,gorGor5,ponAbe2,rheMac8,m...  SUB       1
# 50  hg38,panTro5,panPan2,gorGor5,ponAbe2,rheMac8,m...  SUB       1
# 51  hg38,panTro5,panPan2,gorGor5,ponAbe2,nomLeu3,r...  SUB       1
#
#                            id
# 0     chr22:35954281-35954282
# 1     chr18:55601919-55601920
# 2      chr6:79203033-79203034
# 3      chr3:16511156-16511157
# 4      chr3:56448387-56448388
# 5     chr18:13006189-13006190
# 6        chr9:9069544-9069545
# 7      chr8:73955661-73955662
# 8      chr4:82530831-82530832
# 10   chr5:134612469-134612470
# 11     chr7:87681057-87681058
# 13     chr9:88445269-88445270
# 14    chr17:19863340-19863341
# 15   chr5:113102161-113102162
# 16     chr5:27026490-27026491
# 17    chr19:44268317-44268318
# 18  chr11:113740212-113740213
# 19    chr11:66657256-66657257
# 21     chr2:95899847-95899848
# 22    chr10:94846158-94846159
# 23     chr4:91022038-91022039
# 24   chr4:142617385-142617386
# 25    chr19:47205118-47205119
# 26    chr10:73329461-73329462
# 27    chr12:63591832-63591833
# 28    chr12:63591833-63591834
# 29     chr1:23110601-23110602
# 30    chr16:83000699-83000700
# 31   chr2:169688943-169688944
# 32      chr21:5122555-5122556
# 33   chr9:136051735-136051736
# 34     chr2:97552021-97552022
# 37    chr18:13717545-13717546
# 38   chr1:115663117-115663118
# 39   chr2:120023538-120023539
# 40     chr9:33546757-33546758
# 41   chr1:111135247-111135248
# 42   chr6:169663127-169663128
# 44    chr20:35866737-35866738
# 45    chr20:44632409-44632410
# 46     chr3:43673973-43673974
# 47    chr16:69457783-69457784
# 48     chr5:65566091-65566092
# 49     chr1:17574027-17574028
# 50   chr2:228040727-228040728
# 51    chr21:44139496-44139497
