# %%
#!/usr/bin/env python
# coding: utf-8

# 20221129
# 
# sarahfong
# 
# ### intersect nullomers, empirical shuffle with phylop 100way bigWig
# 
# split by exonic/non-exonic
# 
# 
# use bigWigSummary executable from UCSC to get phylop 
# 
# 
# compare nullomers v. empirical background

# In[ ]:
—

# %%
import glob
from joblib import Parallel, delayed
import os
import pybedtools as pbt
import subprocess
import sys


import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import statsmodels as sm

# append path
sys.path.append("/wynton/home/ahituv/fongsl/tools/py_/")

# import config reader
import config_readwrite as crw
import zippery

config_tag = sys.argv[1]
NBASES = sys.argv[2]

config_tag = "config-exon.ini"
NBASES = 100

# %%
# append path
sys.path.append("/wynton/home/ahituv/fongsl/tools/py_/")

# import config reader
import config_readwrite as crw
import count_lines as cl
import plot_params as pp

config_name = os.path.join(os.getcwd(), config_tag)

config, configname = crw.read_config(config_name)


# select config variables
ANNOT = config["GENCODE"]["ANNOT"]  

# nullomer GENCODE intersections
OVERLAP = config[f"DATAxGENCODE"]["OVERLAP"]  
NOOVERLAP_REF = config[f"DATAxGENCODE"]["NOOVERLAP_REF"]

# nullomer shuffles
EX_EXP_SHUF = config["SHUFFLE"]["ex_exp_star"]
NOEX_EXP_SHUF = config["SHUFFLE"]["noex_exp_star"]

# phylop files, wiggle track executables
PHYLOP_BW = config["PHYLOP"]["100WAY_BW"]


PHYLOP_BW = "/wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw"
PHYLOP_PATH = os.path.join(config["DATA"]["PATH"], "phylop")
SRC_BW = "/wynton/home/ahituv/fongsl/nullomers/src/bigWigSummary"

config["PHYLOP"]["100WAY_BW"] = PHYLOP_BW
config["PHYLOP"]["PATH"] = PHYLOP_PATH
config["PHYLOP"]["FLANK_BP"]= str(NBASES)

crw.check_section(config, "SRC")
config["SRC"]["bigwigsummary"] = SRC_BW


# # functions


def expand_bedcoor(bedfile, nbases):
    """
    write expanded bedcoordinates file. 
    
    inputs
        bedfile (str) - full path to bed file to expand
        nbases (int) - number of bases to expand by IN EACH DIRECTION
        
    method
        
        1. build outfile str
        2. make pybedtool object (if outfile does not exist, else skip)
        3. use bedtools slop to expand bed coordinates, save output
        4. unit test expansion
        
    returns
        expanded (bedtool object) - expanded bed coordinates
        outbed (str) - full path to expanded coordinate bedfile
    """
    
    #1
    out = bedfile.strip(".bed") + f"-EXPANDED-{nbases}.bed"
    
    if os.path.exists(out) is False:
        #2
        bed = pbt.BedTool(bedfile)

        #3
        expanded = bed.slop(genome="hg38", b=nbases, output=out)
    else:
        print("expanded", nbases, " in either direction, already")
        expanded = pbt.BedTool(out)
    
    #4
    with open(bedfile, "r") as file:
        for line in file:
            print("original", line)
            break

        for line in expanded:
            print("expanded", line)
            break
    
    return expanded, out


# ## parse bigwig for bed coordinates

# In[ ]:


def getBwBedLineSummary(bw, bed_line_list, nsteps, outfile, src):
    
    chr_, start_, end_, nid = bed_line_list
    
    ### insert a check for existing file, number of lines in file. 
    
    with open(outfile, "a") as writer:
        newline = "\t".join(bed_line_list)+"\t"
        writer.write(newline)
        writer.close()
                            
    cmd = f"{src} {bw} {chr_} {start_} {end_} {nsteps} >> {outfile}"
    
    os.system(cmd)
    


# ## expand + bw extract function

# In[ ]:


def expandAndBwExtract(bed, nbases, bw, outpath):
    """
    combined function that:
        0. makes an outfile. 
        1. takes locus and expands the bed coordinates of the locus. 
        2. extracts the phylop base scores for the expanded locus, writing the scores as a vector

    return 
        outfile (str) - name to output values. 
    """
    #0 make the outfile
    name = (bed.split("/")[-1]).strip(".bed") + "-phylop.txt"
    outfile = os.path.join(outpath, name)

    #1 expand bed coordinates
    ex, outex = expand_bedcoor(bed, nbases)
    
    # get phylop values from bigwig
    for line in ex:
        bedlist = [line[0], line[1], line[2], line[3]]
        getBwBedLineSummary(bw, bedlist, nbases*2, outfile, SRC_BW)

    print(outfile)
    return outfile


def parallelBigWigVal(file_list, nbases, bw, outpath):
    
    """
    run parallel jobs to parse bigwigs for bed values


    input
        file_list (list) - list of strs w/ full paths to bed files to run in parallel
        nbases (int) - number of bases around nullomer mutation to get bw values from
        bw (str) - full path to bigwig file to parse
        outpath (str) - path to write outfile

        
    method
        run parallel jobs to extract plylop values from bw
        
    return
        exps_phylop (list) - list of outfiles
    
    notes
        ncores is fixed at 16
        
    """
    ncores=16
    
    exps_phylop = Parallel(
                        n_jobs=ncores, verbose=100, prefer="threads")\
                        (delayed(expandAndBwExtract)\
                        (bed, nbases, bw, outpath) for bed in file_list)
    return exps_phylop
    


# # Analyze 

# ## functions for analysis

# In[ ]:


def extract_phylop_values(bedfile):
    
    """
    return list of phylop average values from .bed file
    
    input
        bedfile (str) - path to bed file intersected w/ phylop.bw using bigWigAverageOverBed (above)
        
    method
        1. instantiate a list
        2. open the bedfile
        3. parse bedfile lines
        4. str split line to get relevant bedfile info, including phylop mean val at 4th index 
        5. append the value to a list of phylop values
    return
        phylop_vals (list) - list of mean phylop_values for all elements in the list. 
        
    """
    
    phylop_vals=[]  #1 collect phylop values from file
    
    #2 open the phylop.bed file
    with open(bedfile, "r") as phylofile:
        
        #3 parse lines
        for line in phylofile.readlines():
            
            #4 str split line to extract values
            chr_, posminusone, pos, nid, mean_phylop_val = (line.strip("\n")).split("\t")
            
            #5 append phylop_val to list of values
            phylop_vals.append(float(mean_phylop_val))
            
    return phylop_vals

# %%
# In[ ]:


def make_pdDataFrame(val_list, exp_val_list, sample_id):
    
    # make pd dataframe from val_list
    df=pd.DataFrame({"phylop":val_list})
    df["sample"] = sample_id
    
    # make pd dataframe from expected
    exp_df=pd.DataFrame({"phylop":exp_val_list})
    exp_df["sample"] = "shuffle"

    # concat the two dataframes together and reset index
    df=pd.concat([df, exp_df]).reset_index()
    
    return df


# In[ ]:


def results_stat_plot(df, sample_id):
    
    pp.fonts()
    
    # plot histplot
    fig,ax=plt.subplots(figsize=(6,6))
    sns.histplot(x="phylop", data=df, hue="sample", common_norm=False, stat="percent")
    ax.set(title=sample_id)
    
    # plot boxplot
    fig,ax=plt.subplots(figsize=(6,6))
    sns.boxplot(x="sample", y="phylop", data=df, notch=True, showfliers=False)
    ax.set(title=sample_id)

    # do MWU
    print(stats.mannwhitneyu(vals, exp_vals))

    # print descriptive stat
    print(df.groupby("sample")["phylop"].describe())

# %%
# # Main 

# ## exonic, non-exonic; expand; extract bw values

def main(argv):

# %%
    runlist =[
            OVERLAP,
            NOOVERLAP_REF
            ]

    for BED in runlist:

        print(BED)
        # combined function that expands mutations and extracts phylop scores
        out = expandAndBwExtract(BED, NBASES, PHYLOP_BW, PHYLOP_PATH)
# Out:
# /scratch/fongsl/nullomers/data/mutations-uniq-woRMSK.GENCODE-exon_overlap.bed
# expanded 100  in either direction, already
# original chr1	634787	634788	N_12347
#
# expanded chr1	634687	634888	N_12347
#
# /scratch/fongsl/nullomers/data/phylop/mutations-uniq-woRMSK.GENCODE-exon_overlap-phylop.txt

# %%
    # ## shuffled exonic, non-exonic; expand; extract bw values

    exp_lists = [
                glob.glob(EX_EXP_SHUF), 
                glob.glob(NOEX_EXP_SHUF)
                ]

# %%
exp_lists
# Out:
# [['/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-1.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-0.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-2.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-3.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-4.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-6.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-5.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-7.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-8.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-9.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-10.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-11.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-12.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-13.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-14.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-15.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-16.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-17.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-18.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-19.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-20.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-21.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-22.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-23.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-24.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-25.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-26.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-27.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-28.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-29.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-30.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-31.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-32.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-33.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-34.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-35.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-36.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-37.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-38.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-39.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-40.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-41.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-42.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-43.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-44.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-45.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-46.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-47.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-48.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-49.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-50.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-51.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-52.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-53.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-54.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-55.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-56.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-57.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-58.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-59.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-60.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-61.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-62.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-63.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-64.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-65.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-66.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-67.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-68.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-69.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-70.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-71.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-72.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-73.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-74.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-75.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-76.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-77.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-78.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-79.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-80.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-81.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-82.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-83.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-85.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-84.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-86.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-87.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-88.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-89.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-90.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-91.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-92.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-93.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-94.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-95.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-96.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-97.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-98.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-100.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-102.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-103.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-106.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-108.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-99.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-101.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-104.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-105.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-107.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-109.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-110.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-111.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-112.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-113.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-114.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-115.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-118.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-116.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-117.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-119.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-120.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-121.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-122.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-123.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-124.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-125.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-126.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-127.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-128.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-129.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-130.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-131.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-132.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-133.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-134.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-135.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-136.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-137.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-138.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-139.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-140.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-141.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-142.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-143.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-144.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-145.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-146.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-147.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-148.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-149.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-150.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-151.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-152.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-153.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-154.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-155.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-156.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-157.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-158.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-159.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-160.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-161.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-162.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-163.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-164.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-165.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-166.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-167.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-168.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-169.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-170.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-171.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-172.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-173.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-174.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-175.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-176.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-177.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-178.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-179.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-180.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-181.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-182.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-183.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-184.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-185.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-186.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-188.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-187.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-189.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-190.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-191.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-192.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-193.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-194.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-195.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-196.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-197.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-198.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-199.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-200.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-201.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-202.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-203.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-204.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-205.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-206.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-207.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-208.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-209.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-210.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-211.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-212.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-213.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-214.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-215.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-216.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-217.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-218.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-219.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-220.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-221.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-222.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-223.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-224.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-225.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-226.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-227.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-228.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-229.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-230.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-231.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-232.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-233.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-234.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-235.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-236.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-237.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-238.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-239.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-240.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-241.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-242.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-243.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-244.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-245.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-246.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-247.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-248.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-249.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-250.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-251.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-252.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-253.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-254.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-255.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-256.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-257.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-258.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-259.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-260.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-261.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-262.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-263.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-264.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-265.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-267.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-266.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-268.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-269.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-270.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-271.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-272.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-273.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-274.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-275.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-276.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-277.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-278.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-279.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-280.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-281.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-282.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-283.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-284.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-285.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-286.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-287.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-288.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-289.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-290.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-291.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-292.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-293.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-294.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-295.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-296.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-297.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-298.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-299.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-300.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-301.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-302.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-303.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-304.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-305.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-306.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-307.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-308.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-309.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-310.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-311.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-312.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-313.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-314.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-315.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-316.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-317.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-318.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-319.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-320.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-321.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-322.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-323.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-324.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-325.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-326.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-327.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-328.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-329.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-331.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-330.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-332.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-333.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-334.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-335.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-336.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-337.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-338.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-339.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-340.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-341.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-342.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-343.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-344.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-345.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-346.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-347.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-348.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-349.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-350.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-351.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-352.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-353.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-354.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-355.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-356.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-357.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-358.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-359.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-360.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-361.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-362.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-363.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-364.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-365.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-366.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-367.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-368.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-369.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-370.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-371.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-372.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-373.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-374.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-375.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-376.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-377.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-378.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-379.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-380.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-381.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-383.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-382.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-384.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-385.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-386.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-387.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-388.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-389.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-390.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-391.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-392.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-393.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-394.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-395.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-396.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-397.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-398.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-399.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-400.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-401.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-402.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-403.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-404.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-405.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-406.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-407.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-408.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-409.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-410.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-411.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-412.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-413.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-414.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-415.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-416.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-417.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-418.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-419.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-420.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-421.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-422.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-423.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-424.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-425.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-426.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-427.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-428.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-429.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-430.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-431.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-432.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-433.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-434.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-435.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-436.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-437.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-438.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-439.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-440.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-441.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-442.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-443.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-444.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-445.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-446.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-447.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-448.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-449.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-450.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-451.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-452.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-453.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-454.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-455.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-456.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-457.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-458.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-459.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-460.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-461.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-462.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-463.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-464.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-465.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-466.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-467.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-468.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-469.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-470.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-471.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-472.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-473.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-474.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-475.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-476.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-477.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-478.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-479.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-480.bed',
# ...
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-358.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-359.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-360.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-361.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-362.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-363.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-364.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-365.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-366.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-367.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-368.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-369.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-370.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-371.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-372.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-373.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-374.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-375.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-376.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-377.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-378.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-379.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-380.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-381.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-382.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-383.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-384.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-385.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-386.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-387.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-388.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-389.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-390.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-391.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-392.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-393.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-394.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-395.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-397.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-396.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-398.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-399.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-400.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-401.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-402.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-403.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-404.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-405.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-406.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-407.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-408.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-409.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-410.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-411.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-412.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-413.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-414.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-415.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-416.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-417.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-418.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-419.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-420.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-421.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-422.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-423.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-424.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-425.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-426.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-427.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-428.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-429.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-430.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-431.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-432.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-433.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-434.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-435.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-436.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-437.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-438.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-439.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-440.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-441.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-442.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-443.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-444.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-445.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-446.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-447.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-448.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-449.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-450.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-451.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-452.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-453.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-454.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-455.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-456.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-457.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-458.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-459.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-460.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-461.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-462.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-463.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-464.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-465.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-466.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-467.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-468.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-469.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-470.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-472.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-471.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-473.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-474.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-475.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-476.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-477.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-478.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-479.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-480.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-481.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-482.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-483.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-484.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-485.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-486.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-487.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-488.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-489.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-490.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-491.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-492.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-493.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-494.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-495.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-496.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-497.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-498.bed',
#   '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_no-overlap-ref.only-499.bed']]

# %%
    for exp_list in exp_lists:
        print(exp_list)
        exps_phylop = parallelBigWigVal(exp_list, NBASES, PHYLOP_BW, PHYLOP_PATH)
# Out:
# ['/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-1.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-0.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-2.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-3.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-4.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-6.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-5.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-7.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-8.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-9.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-10.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-11.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-12.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-13.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-14.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-15.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-16.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-17.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-18.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-19.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-20.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-21.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-22.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-23.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-24.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-25.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-26.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-27.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-28.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-29.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-30.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-31.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-32.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-33.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-34.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-35.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-36.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-37.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-38.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-39.bed', '/scratch/fongsl/nullomers/data/shuffle/shuf-mutations-uniq-woRMSK.GENCODE-exon_overlap-40.bed', '/scratch/fongsl/nullomers/data/ ...
# [Parallel(n_jobs=16)]: Using backend ThreadingBackend with 16 concurrent workers.
# original chr1	152156406	152156407	N_12347
#
# original chr2	52866476	52866477	N_12347
#
# original chr1	26854170	26854171	N_12347
#
# expanded chr1	152156306	152156507	N_12347
#
# original chr7	126535837	126535838	N_12347
#
# expanded chr2	52866376	52866577	N_12347
#
# expanded chr7	126535737	126535938	N_12347
#
# original chr7	134575911	134575912	N_12347
#
# expanded chr1	26854070	26854271	N_12347
#
# expanded chr7	134575811	134576012	N_12347
#
# original chr13	51771417	51771418	N_12347
#
# expanded chr13	51771317	51771518	N_12347
#
# original chr1	163075932	163075933	N_12347
#
# original chrX	102807130	102807131	N_12347
#
# original chr17	63833150	63833151	N_12347
#
# original chrX	3826697	3826698	N_12347
#
# original chr7	38260086	38260087	N_12347
#
# original chr9	121146245	121146246	N_12347
#
# expanded chrX	102807030	102807231	N_12347
#
# original chr16	2804932	2804933	N_12347
#
# original chr6	30605999	30606000	N_12347
#
# expanded chr1	163075832	163076033	N_12347
#
# original chr18	79396219	79396220	N_12347
#
# expanded chr17	63833050	63833251	N_12347
#
# original chr2	193899060	193899061	N_12347
#
# expanded chrX	3826597	3826798	N_12347
#
# expanded chr9	121146145	121146346	N_12347
#
# expanded chr16	2804832	2805033	N_12347
#
# expanded chr7	38259986	38260187	N_12347
#
# expanded chr2	193898960	193899161	N_12347
#
# expanded chr18	79396119	79396320	N_12347
#
# expanded chr6	30605899	30606100	N_12347
# no data in region chr15:85213500-85213701 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr21:18561400-18561601 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr19:27724121-27724322 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr2:230372524-230372725 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chrY:21038738-21038939 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr19:15347475-15347676 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr15:47133622-47133823 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr18:14010355-14010556 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr22:18386338-18386539 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr5:43578080-43578281 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr6:8165411-8165612 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chrX:113689266-113689467 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr1:32973501-32973702 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr19:387039-387240 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr16:65233728-65233929 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr5:136303700-136303901 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr4:188740965-188741166 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr12:8284065-8284266 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr19:46039212-46039413 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr19:20750810-20751011 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr8:144868900-144869101 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr13:52064825-52065026 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr5:21471030-21471231 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr22:18939584-18939785 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw
#
# no data in region chr4:61760632-61760833 in /wynton/group/databases/goldenPath/hg38/phyloP100way/hg38.phyloP100way.bw

# %%
    # # write config

    crw.write_config(config, configname)

# %%
if __name__ == "__main__":
    main(sys.argv[1:])
