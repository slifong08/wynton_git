# %%
import glob
import os, sys
import pandas as pd

BLAST_PATH="/wynton/home/ahituv/fongsl/nullomers/data/mpra/blast/" 
CSV = "/wynton/home/ahituv/fongsl/nullomers/data/mpra/PromoterNullomer_ABV20.csv"

# %% [markdown]
# # open original dataframe

# %%
def formatInsertDf(csv):
    
    """
    format the orignal insert dataframe and calculate insert lengths
    
    input
        csv (str) - full path to .csv insert file from Ofer.
    
    method 
        1. read the csv file w/ select columns
            - ID_ORIG (int) - insert id
            - INSERT (str) - insert sequence
            - CATEGORY (str) - Nullomer, control scramble, control frequent kmer (aka knownmers)
            - expression (str) - categorical
                scrm_expression = case_when(log2(avg) >= log(2) & pv_scrm <= 0.05 ~ “Up-regulated”,
                           log2(avg) <= -log(2) & pv_scrm <= 0.05 ~ “Down-regulated”,
                           TRUE ~ “Unchanged”))
            - Rep_count (int) - n replicates

        2. calculate the length of the insert
        
        3. get knowmer subset
            - rep count = 3
            - category = control_freq
            
        4. get nullomer subset
            - rep count = 3
            - category = nullomer
            - expression != Unchanged
            
        5. make dictionary of insert id, length
        
        6 concatenate knownmer and nullomer subsets
        
    return
        concat (pd dataframe obj) - dataframe of nullomer and knownmer stats
        len_dict (dictionary) - dictionary of insert_id:insert length
        
    """
    #1
    insert_df = pd.read_csv(CSV, usecols=["ID_ORIG", "INSERT", "CATEGORY", "expression", "Rep_count"])
    
    #2
    insert_df["len"]=insert_df["INSERT"].str.len()  # get length of insert

    #3
    knownmers = insert_df.loc[
                        (insert_df["Rep_count"]==3)
                        & (insert_df["CATEGORY"] =="CONTROL_FREQ")
                        ]
    
    #4
    nullomers = insert_df.loc[
                        (insert_df["Rep_count"]==3)
                        & (insert_df["CATEGORY"] =="NULLOER")
                        & (insert_df["expression"]!="Unchanged")
                        ]
    
    #5 dictionary of ids: insert lengths
    
    len_dict = insert_df[["ID_ORIG", "len"]].copy().drop_duplicates().set_index('ID_ORIG')['len'].to_dict()
    
    #6
    concat = pd.concat([knownmers, nullomers]) # concat the dataframes together
    
    return concat, len_dict

# %%
insert_df, len_dict = formatInsertDf(CSV)

# %% [markdown]
# # open blast files

# %%
def openBlastTxt(file):
    
    cols = ["query acc.ver", 
        "subject acc.ver", "% identity", "alignment length",
        "mismatches", "gap opens",
        "q. start", "q. end", "s. start", "s. end",
        "evalue", "bit score"]

    df = pd.read_csv(file, sep='\t', comment='#', header = None, names=cols)
    
    return df

# %%
def countHits(df, len_dict):

    # count the total number of hits per mer
    
    hit_dict = {}

    for i in df["query acc.ver"].unique():
        
        test = df.loc[df["query acc.ver"]==i].copy()   # subset the dataframe
        
        ID = test["dataset"].iloc[0]  # is this nullomer or knownmer? 
        
        insert_len = len_dict[i] # get insert legnth
        
        n_total_hits = test.shape[0]  # count the total number of hits

        perfect_hits = test.loc[
                                (test["len_dif"]==0)
                                & (test["mismatches"]==0)
                                & (test["gap opens"]==0)
                                &(test["% identity"]==100)
                               ].shape[0]  # count the perfect number of hits (length dif is zero)
        
        hit_dict[i] = (ID, n_total_hits, perfect_hits, (perfect_hits/n_total_hits))
        
    return hit_dict

# %% [markdown]
# #  open blast file

# %%
file_identity = ["knownmer", "nullomer"]
fs = glob.glob(os.path.join(BLAST_PATH, "*"))

collection_dict = {}

for file, file_id in zip(fs, file_identity):
    df  = openBlastTxt(file)
    df["dataset"] = file_id
    collection_dict[file_id] = df

# add insert info to dataframe. 
bdf = pd.concat(collection_dict.values())

bdf = pd.merge(bdf, insert_df, how= "left", left_on="query acc.ver", right_on='ID_ORIG')

bdf["len_dif"] = bdf["alignment length"] - bdf["len"] # if zero, perfect match

bdf.head()
# Out:
#    query acc.ver subject acc.ver  % identity  alignment length  mismatches  \
# 0          46077  NW_021160017.1       100.0                15           0
# 1          46077  NW_021160017.1       100.0                15           0
# 2          46077  NW_021160017.1       100.0                15           0
# 3          46077  NW_021160017.1       100.0                15           0
# 4          46077  NW_021160017.1       100.0                15           0
#
#    gap opens  q. start  q. end  s. start  s. end  evalue  bit score   dataset  \
# 0          0         1      15      1113    1099     6.4       30.2  knownmer
# 1          0         1      15      3667    3653     6.4       30.2  knownmer
# 2          0         1      15      3838    3824     6.4       30.2  knownmer
# 3          0         1      15      7072    7058     6.4       30.2  knownmer
# 4          0         1      15      8778    8764     6.4       30.2  knownmer
#
#    ID_ORIG           INSERT   len  len_dif
# 0    46077  AAAATCTAGACAGAA  15.0      0.0
# 1    46077  AAAATCTAGACAGAA  15.0      0.0
# 2    46077  AAAATCTAGACAGAA  15.0      0.0
# 3    46077  AAAATCTAGACAGAA  15.0      0.0
# 4    46077  AAAATCTAGACAGAA  15.0      0.0

# %% [markdown]
# # count the number of perfect matches

# %%
hit_dict = countHits(bdf, len_dict)

hit_dict
# Out:
# {46077: ('knownmer', 31885, 19545, 0.6129841618315822),
#  46086: ('knownmer', 26361, 19512, 0.7401843632639126),
#  46089: ('knownmer', 111, 107, 0.963963963963964),
#  46095: ('knownmer', 114, 101, 0.8859649122807017),
#  46098: ('knownmer', 114, 101, 0.8859649122807017),
#  46104: ('knownmer', 146, 105, 0.7191780821917808),
#  46125: ('knownmer', 202, 134, 0.6633663366336634),
#  46134: ('knownmer', 112, 108, 0.9642857142857143),
#  46140: ('knownmer', 102, 102, 1.0),
#  46152: ('knownmer', 105, 103, 0.9809523809523809),
#  46170: ('knownmer', 113, 108, 0.9557522123893806),
#  46171: ('knownmer', 113, 108, 0.9557522123893806),
#  46179: ('knownmer', 102, 101, 0.9901960784313726),
#  46185: ('knownmer', 148, 102, 0.6891891891891891),
#  46188: ('knownmer', 148, 102, 0.6891891891891891),
#  46189: ('knownmer', 148, 102, 0.6891891891891891),
#  46197: ('knownmer', 104, 100, 0.9615384615384616),
#  46200: ('knownmer', 104, 100, 0.9615384615384616),
#  46203: ('knownmer', 36596, 19960, 0.5454147994316318),
#  46214: ('knownmer', 157, 109, 0.6942675159235668),
#  46215: ('knownmer', 102, 101, 0.9901960784313726),
#  46221: ('knownmer', 128, 103, 0.8046875),
#  46224: ('knownmer', 128, 103, 0.8046875),
#  46226: ('knownmer', 128, 103, 0.8046875),
#  46227: ('knownmer', 52675, 20080, 0.38120550545799714),
#  46230: ('knownmer', 45686, 19665, 0.430438208641597),
#  46233: ('knownmer', 45686, 19665, 0.430438208641597),
#  46242: ('knownmer', 105, 105, 1.0),
#  46248: ('knownmer', 52675, 20080, 0.38120550545799714),
#  46266: ('knownmer', 113912, 19751, 0.17338822951049934),
#  46269: ('knownmer', 118, 102, 0.864406779661017),
#  46272: ('knownmer', 118, 102, 0.864406779661017),
#  46278: ('knownmer', 114, 100, 0.8771929824561403),
#  46283: ('knownmer', 128, 103, 0.8046875),
#  46296: ('knownmer', 106, 102, 0.9622641509433962),
#  46300: ('knownmer', 105, 105, 1.0),
#  46302: ('knownmer', 105, 105, 1.0),
#  46308: ('knownmer', 111, 101, 0.9099099099099099),
#  46312: ('knownmer', 105, 103, 0.9809523809523809),
#  46326: ('knownmer', 101, 100, 0.9900990099009901),
#  46332: ('knownmer', 255, 101, 0.396078431372549),
#  46342: ('knownmer', 27350, 19761, 0.7225228519195612),
#  46344: ('knownmer', 27350, 19761, 0.7225228519195612),
#  46350: ('knownmer', 24448, 19742, 0.8075098167539267),
#  46365: ('knownmer', 110, 107, 0.9727272727272728),
#  46372: ('knownmer', 110, 107, 0.9727272727272728),
#  46389: ('knownmer', 34402, 19777, 0.574879367478635),
#  46398: ('knownmer', 107, 107, 1.0),
#  46404: ('knownmer', 3129, 119, 0.03803131991051454),
#  46416: ('knownmer', 106, 106, 1.0),
#  46422: ('knownmer', 107, 100, 0.9345794392523364),
#  46437: ('knownmer', 370, 209, 0.5648648648648649),
#  46443: ('knownmer', 114, 106, 0.9298245614035088),
#  46446: ('knownmer', 114, 106, 0.9298245614035088),
#  46449: ('knownmer', 30392, 19890, 0.6544485390892341),
#  46458: ('knownmer', 102, 101, 0.9901960784313726),
#  46462: ('knownmer', 111, 105, 0.9459459459459459),
#  46470: ('knownmer', 120125, 19826, 0.16504474505723205),
#  46476: ('knownmer', 105, 101, 0.9619047619047619),
#  46482: ('knownmer', 29580, 19821, 0.670081135902637),
#  46494: ('knownmer', 30085, 19952, 0.6631876350340702),
#  46498: ('knownmer', 305, 101, 0.33114754098360655),
#  46500: ('knownmer', 305, 101, 0.33114754098360655),
#  46503: ('knownmer', 110, 106, 0.9636363636363636),
#  46506: ('knownmer', 110, 106, 0.9636363636363636),
#  46512: ('knownmer', 119787, 19995, 0.16692128528137443),
#  46527: ('knownmer', 29638, 19854, 0.6698832579796208),
#  46532: ('knownmer', 29638, 19854, 0.6698832579796208),
#  46536: ('knownmer', 102, 101, 0.9901960784313726),
#  46539: ('knownmer', 119, 106, 0.8907563025210085),
#  46548: ('knownmer', 119, 106, 0.8907563025210085),
#  46551: ('knownmer', 102, 101, 0.9901960784313726),
#  46554: ('knownmer', 102, 101, 0.9901960784313726),
#  46560: ('knownmer', 104, 102, 0.9807692307692307),
#  46572: ('knownmer', 36530, 19904, 0.5448672324117164),
#  46599: ('knownmer', 105, 104, 0.9904761904761905),
#  46605: ('knownmer', 112, 101, 0.9017857142857143),
#  46614: ('knownmer', 32029, 19870, 0.6203752848980612),
#  46618: ('knownmer', 129, 108, 0.8372093023255814),
#  46623: ('knownmer', 106, 102, 0.9622641509433962),
#  46626: ('knownmer', 106, 102, 0.9622641509433962),
#  46629: ('knownmer', 111, 109, 0.9819819819819819),
#  46635: ('knownmer', 107, 102, 0.9532710280373832),
#  46644: ('knownmer', 170, 107, 0.6294117647058823),
#  46651: ('knownmer', 30792, 19916, 0.6467913743829566),
#  46659: ('knownmer', 124, 108, 0.8709677419354839),
#  46662: ('knownmer', 107, 102, 0.9532710280373832),
#  46674: ('knownmer', 124, 104, 0.8387096774193549),
#  46689: ('knownmer', 111, 105, 0.9459459459459459),
#  46692: ('knownmer', 111, 105, 0.9459459459459459),
#  46698: ('knownmer', 167613, 20051, 0.11962675926091651),
#  46707: ('knownmer', 29651, 19957, 0.6730633030926444),
#  46734: ('knownmer', 104, 100, 0.9615384615384616),
#  46735: ('knownmer', 104, 100, 0.9615384615384616),
#  46743: ('knownmer', 30362, 20324, 0.669389368289309),
#  46750: ('knownmer', 39341, 20061, 0.5099260313667675),
#  46753: ('knownmer', 39341, 20061, 0.5099260313667675),
#  46764: ('knownmer', 29110, 19998, 0.6869804190999657),
#  46765: ('knownmer', 29110, 19998, 0.6869804190999657),
#  46767: ('knownmer', 109, 100, 0.9174311926605505),
#  46770: ('knownmer', 109, 100, 0.9174311926605505),
#  46782: ('knownmer', 91456, 20048, 0.21920923722883134),
#  46785: ('knownmer', 108, 101, 0.9351851851851852),
#  46797: ('knownmer', 176, 102, 0.5795454545454546),
#  46821: ('knownmer', 33625, 20050, 0.5962825278810409),
#  46827: ('knownmer', 124, 103, 0.8306451612903226),
#  46829: ('knownmer', 124, 103, 0.8306451612903226),
#  46834: ('knownmer', 111, 104, 0.9369369369369369),
#  46842: ('knownmer', 112, 108, 0.9642857142857143),
#  46845: ('knownmer', 104, 101, 0.9711538461538461),
#  46848: ('knownmer', 104, 101, 0.9711538461538461),
#  46854: ('knownmer', 271, 124, 0.4575645756457565),
#  46858: ('knownmer', 104, 102, 0.9807692307692307),
#  46872: ('knownmer', 106, 106, 1.0),
#  46875: ('knownmer', 104, 100, 0.9615384615384616),
#  46878: ('knownmer', 104, 100, 0.9615384615384616),
#  46905: ('knownmer', 106, 101, 0.9528301886792453),
#  46908: ('knownmer', 106, 101, 0.9528301886792453),
#  46914: ('knownmer', 101, 101, 1.0),
#  46920: ('knownmer', 40887, 20125, 0.4922102379729498),
#  46921: ('knownmer', 40887, 20125, 0.4922102379729498),
#  46929: ('knownmer', 39602, 20137, 0.5084844199787889),
#  46930: ('knownmer', 39602, 20137, 0.5084844199787889),
#  46941: ('knownmer', 172, 112, 0.6511627906976745),
#  46950: ('knownmer', 1286, 108, 0.08398133748055987),
#  46968: ('knownmer', 23761, 20164, 0.8486174824291907),
#  46971: ('knownmer', 39058, 20257, 0.5186389472067182),
#  46977: ('knownmer', 35534, 20197, 0.5683852085326729),
#  46990: ('knownmer', 31795, 20201, 0.6353514703569744),
#  46992: ('knownmer', 31795, 20201, 0.6353514703569744),
#  46993: ('knownmer', 31795, 20201, 0.6353514703569744),
#  46995: ('knownmer', 106, 102, 0.9622641509433962),
#  46998: ('knownmer', 106, 102, 0.9622641509433962),
#  46999: ('knownmer', 106, 102, 0.9622641509433962),
#  47002: ('knownmer', 274, 118, 0.4306569343065693),
#  47004: ('knownmer', 274, 118, 0.4306569343065693),
#  47010: ('knownmer', 101, 100, 0.9900990099009901),
#  47013: ('knownmer', 118, 104, 0.8813559322033898),
#  47018: ('knownmer', 118, 104, 0.8813559322033898),
#  47028: ('knownmer', 102, 101, 0.9901960784313726),
#  47031: ('knownmer', 106, 102, 0.9622641509433962),
#  47037: ('knownmer', 116, 102, 0.8793103448275862),
#  47041: ('knownmer', 116, 102, 0.8793103448275862),
#  47043: ('knownmer', 111, 107, 0.963963963963964),
#  47046: ('knownmer', 111, 107, 0.963963963963964),
#  47049: ('knownmer', 115527, 20442, 0.1769456490690488),
#  47056: ('knownmer', 30789, 20265, 0.658189613173536),
#  47061: ('knownmer', 1159, 111, 0.09577221742881795),
#  47062: ('knownmer', 1159, 111, 0.09577221742881795),
#  47067: ('knownmer', 1159, 111, 0.09577221742881795),
#  47071: ('knownmer', 41532, 20287, 0.4884667244534335),
#  47079: ('knownmer', 113, 100, 0.8849557522123894),
#  47080: ('knownmer', 113, 100, 0.8849557522123894),
#  47083: ('knownmer', 113, 100, 0.8849557522123894),
#  47088: ('knownmer', 111, 101, 0.9099099099099099),
#  47091: ('knownmer', 34761, 20308, 0.5842179453985789),
#  47094: ('knownmer', 34761, 20308, 0.5842179453985789),
#  47103: ('knownmer', 118, 103, 0.8728813559322034),
#  47104: ('knownmer', 118, 103, 0.8728813559322034),
#  47112: ('knownmer', 105, 101, 0.9619047619047619),
#  47118: ('knownmer', 227, 101, 0.44493392070484583),
#  47131: ('knownmer', 134, 105, 0.7835820895522388),
#  47133: ('knownmer', 158, 102, 0.6455696202531646),
#  47136: ('knownmer', 134, 105, 0.7835820895522388),
#  47148: ('knownmer', 161, 100, 0.6211180124223602),
#  47151: ('knownmer', 134, 102, 0.7611940298507462),
#  47154: ('knownmer', 134, 102, 0.7611940298507462),
#  47155: ('knownmer', 134, 102, 0.7611940298507462),
#  47157: ('knownmer', 118, 105, 0.8898305084745762),
#  47163: ('knownmer', 86189, 20738, 0.2406107507918644),
#  47166: ('knownmer', 86189, 20738, 0.2406107507918644),
#  47172: ('knownmer', 267, 103, 0.3857677902621723),
#  47173: ('knownmer', 267, 103, 0.3857677902621723),
#  47175: ('knownmer', 112, 112, 1.0),
#  47178: ('knownmer', 112, 112, 1.0),
#  47179: ('knownmer', 112, 112, 1.0),
#  47184: ('knownmer', 39955, 20424, 0.5111750719559505),
#  47187: ('knownmer', 105, 101, 0.9619047619047619),
#  47196: ('knownmer', 114, 101, 0.8859649122807017),
#  47199: ('knownmer', 102, 102, 1.0),
#  47202: ('knownmer', 102, 102, 1.0),
#  47203: ('knownmer', 102, 102, 1.0),
#  47205: ('knownmer', 175, 104, 0.5942857142857143),
#  47208: ('knownmer', 175, 104, 0.5942857142857143),
#  47221: ('knownmer', 104, 101, 0.9711538461538461),
#  47235: ('knownmer', 108, 102, 0.9444444444444444),
#  47250: ('knownmer', 203, 104, 0.5123152709359606),
#  47253: ('knownmer', 19897, 12818, 0.6442177212645123),
#  47256: ('knownmer', 19897, 12818, 0.6442177212645123),
#  47262: ('knownmer', 105, 101, 0.9619047619047619),
#  47277: ('knownmer', 104, 104, 1.0),
#  47283: ('knownmer', 133, 104, 0.7819548872180451),
#  47292: ('knownmer', 106, 101, 0.9528301886792453),
#  47298: ('knownmer', 104, 104, 1.0),
#  47304: ('knownmer', 103, 100, 0.970873786407767),
#  47307: ('knownmer', 125, 104, 0.832),
#  47310: ('knownmer', 125, 104, 0.832),
#  47313: ('knownmer', 109, 103, 0.944954128440367),
#  47316: ('knownmer', 109, 103, 0.944954128440367),
#  47322: ('knownmer', 101, 100, 0.9900990099009901),
#  47325: ('knownmer', 31664, 20539, 0.6486546235472461),
#  47331: ('knownmer', 30192, 20690, 0.6852808691043986),
#  47343: ('knownmer', 110, 103, 0.9363636363636364),
#  47352: ('knownmer', 101, 100, 0.9900990099009901),
#  47367: ('knownmer', 280, 112, 0.4),
#  47372: ('knownmer', 280, 112, 0.4),
#  47376: ('knownmer', 104, 104, 1.0),
#  47388: ('knownmer', 108, 103, 0.9537037037037037),
#  47394: ('knownmer', 131, 103, 0.7862595419847328),
#  47395: ('knownmer', 131, 103, 0.7862595419847328),
#  47396: ('knownmer', 131, 103, 0.7862595419847328),
#  47401: ('knownmer', 125, 103, 0.824),
#  47403: ('knownmer', 110, 107, 0.9727272727272728),
#  47407: ('knownmer', 110, 107, 0.9727272727272728),
#  47412: ('knownmer', 117, 102, 0.8717948717948718),
#  47424: ('knownmer', 164, 101, 0.6158536585365854),
#  47433: ('knownmer', 106, 105, 0.9905660377358491),
#  47436: ('knownmer', 106, 105, 0.9905660377358491),
#  47437: ('knownmer', 106, 105, 0.9905660377358491),
#  47439: ('knownmer', 153, 101, 0.6601307189542484),
#  47448: ('knownmer', 171, 106, 0.6198830409356725),
#  47457: ('knownmer', 101, 101, 1.0),
#  47460: ('knownmer', 101, 101, 1.0),
#  47472: ('knownmer', 102, 100, 0.9803921568627451),
#  47478: ('knownmer', 122, 103, 0.8442622950819673),
#  47484: ('knownmer', 168, 114, 0.6785714285714286),
#  47490: ('knownmer', 35019, 20768, 0.5930494874211143),
#  47496: ('knownmer', 29355, 20879, 0.7112587293476409),
#  47499: ('knownmer', 106, 103, 0.9716981132075472),
#  47502: ('knownmer', 106, 103, 0.9716981132075472),
#  47512: ('knownmer', 152, 109, 0.7171052631578947),
#  47524: ('knownmer', 37634, 20803, 0.5527714300898124),
#  47538: ('knownmer', 80385, 20838, 0.2592274678111588),
#  47544: ('knownmer', 107, 105, 0.9813084112149533),
#  47545: ('knownmer', 107, 105, 0.9813084112149533),
#  47547: ('knownmer', 115, 102, 0.8869565217391304),
#  47548: ('knownmer', 115, 102, 0.8869565217391304),
#  47553: ('knownmer', 323, 106, 0.3281733746130031),
#  47556: ('knownmer', 323, 106, 0.3281733746130031),
#  47562: ('knownmer', 103, 100, 0.970873786407767),
#  47568: ('knownmer', 131, 107, 0.816793893129771),
#  47571: ('knownmer', 111, 104, 0.9369369369369369),
#  47574: ('knownmer', 111, 104, 0.9369369369369369),
#  154195: ('nullomer', 6, 1, 0.16666666666666666),
#  140388: ('nullomer', 25, 0, 0.0),
#  129951: ('nullomer', 4, 0, 0.0),
#  130899: ('nullomer', 3, 0, 0.0),
#  131124: ('nullomer', 33, 0, 0.0),
#  131869: ('nullomer', 7, 0, 0.0),
#  133890: ('nullomer', 38, 0, 0.0),
#  134970: ('nullomer', 18, 0, 0.0),
#  163440: ('nullomer', 15, 0, 0.0),
#  145896: ('nullomer', 6, 0, 0.0),
#  136059: ('nullomer', 4, 0, 0.0),
#  136353: ('nullomer', 1, 0, 0.0),
#  129393: ('nullomer', 3, 0, 0.0),
#  137050: ('nullomer', 21, 0, 0.0),
#  140658: ('nullomer', 14, 0, 0.0),
#  138792: ('nullomer', 17, 0, 0.0),
#  138894: ('nullomer', 10, 0, 0.0),
#  151908: ('nullomer', 5, 0, 0.0),
#  162330: ('nullomer', 3, 0, 0.0),
#  152514: ('nullomer', 2, 0, 0.0),
#  141840: ('nullomer', 98, 0, 0.0),
#  136503: ('nullomer', 28, 0, 0.0),
#  142815: ('nullomer', 17, 0, 0.0),
#  144954: ('nullomer', 26, 0, 0.0),
#  142500: ('nullomer', 24, 0, 0.0),
#  144207: ('nullomer', 3, 0, 0.0),
#  143439: ('nullomer', 5, 0, 0.0),
#  135370: ('nullomer', 16, 0, 0.0),
#  146695: ('nullomer', 5, 0, 0.0),
#  158600: ('nullomer', 4, 1, 0.25),
#  144123: ('nullomer', 34, 0, 0.0),
#  146769: ('nullomer', 12, 0, 0.0),
#  147731: ('nullomer', 2, 0, 0.0),
#  148029: ('nullomer', 4, 0, 0.0),
#  147684: ('nullomer', 3, 0, 0.0),
#  133680: ('nullomer', 17, 0, 0.0),
#  161529: ('nullomer', 1, 0, 0.0),
#  136845: ('nullomer', 19, 0, 0.0),
#  152650: ('nullomer', 6, 0, 0.0),
#  147699: ('nullomer', 32, 0, 0.0),
#  155962: ('nullomer', 6, 0, 0.0),
#  157284: ('nullomer', 7, 0, 0.0),
#  157423: ('nullomer', 5, 0, 0.0),
#  157567: ('nullomer', 16, 0, 0.0),
#  158347: ('nullomer', 8, 1, 0.125),
#  155133: ('nullomer', 25, 0, 0.0),
#  159058: ('nullomer', 1, 0, 0.0),
#  151233: ('nullomer', 16, 0, 0.0),
#  160548: ('nullomer', 2, 0, 0.0),
#  138186: ('nullomer', 6, 0, 0.0),
#  161920: ('nullomer', 1, 1, 1.0),
#  137292: ('nullomer', 18, 0, 0.0),
#  150844: ('nullomer', 48, 0, 0.0),
#  159600: ('nullomer', 4, 2, 0.5),
#  128582: ('nullomer', 2, 0, 0.0),
#  164080: ('nullomer', 1, 0, 0.0)}

# %% [markdown]
# # blast stats

# %%
bdf.describe()
# Out:
#        query acc.ver    % identity  alignment length    mismatches  gap opens  \
# count   2.637984e+06  2.637984e+06      2.637984e+06  2.637984e+06  2637984.0
# mean    4.680245e+04  9.999998e+01      1.366109e+01  2.653541e-06        0.0
# std     1.684910e+03  1.086033e-02      1.301341e+00  1.628968e-03        0.0
# min     4.607700e+04  9.333300e+01      1.200000e+01  0.000000e+00        0.0
# 25%     4.647000e+04  1.000000e+02      1.200000e+01  0.000000e+00        0.0
# 50%     4.675300e+04  1.000000e+02      1.400000e+01  0.000000e+00        0.0
# 75%     4.704900e+04  1.000000e+02      1.500000e+01  0.000000e+00        0.0
# max     1.640800e+05  1.000000e+02      1.500000e+01  1.000000e+00        0.0
#
#            q. start        q. end      s. start        s. end        evalue  \
# count  2.637984e+06  2.637984e+06  2.637984e+06  2.637984e+06  2.637984e+06
# mean   1.592794e+00  1.425389e+01  4.587668e+07  4.587668e+07  1.417117e+02
# std    1.063947e+00  1.093455e+00  3.338991e+07  3.338991e+07  1.704364e+02
# min    1.000000e+00  1.200000e+01  1.000000e+00  1.000000e+00  6.400000e+00
# 25%    1.000000e+00  1.300000e+01  1.933850e+07  1.933850e+07  6.400000e+00
# 50%    1.000000e+00  1.500000e+01  3.822807e+07  3.822806e+07  2.500000e+01
# 75%    2.000000e+00  1.500000e+01  5.913308e+07  5.913307e+07  3.980000e+02
# max    4.000000e+00  1.500000e+01  2.488604e+08  2.488604e+08  3.980000e+02
#
#           bit score       ID_ORIG           len       len_dif
# count  2.637984e+06  2.637984e+06  2.637984e+06  2.637984e+06
# mean   2.756990e+01  4.680245e+04  1.499986e+01 -1.338769e+00
# std    2.555578e+00  1.684910e+03  1.670274e-02  1.301274e+00
# min    2.430000e+01  4.607700e+04  1.300000e+01 -3.000000e+00
# 25%    2.430000e+01  4.647000e+04  1.500000e+01 -3.000000e+00
# 50%    2.820000e+01  4.675300e+04  1.500000e+01 -1.000000e+00
# 75%    3.020000e+01  4.704900e+04  1.500000e+01  0.000000e+00
# max    3.020000e+01  1.640800e+05  1.500000e+01  0.000000e+00

# %% [markdown]
# # plot perfect hits

# %%
t = pd.DataFrame.from_dict(hit_dict).T

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
t
# Out:
#                0      1      2         3
# 46077   knownmer  31885  19545  0.612984
# 46086   knownmer  26361  19512  0.740184
# 46089   knownmer    111    107  0.963964
# 46095   knownmer    114    101  0.885965
# 46098   knownmer    114    101  0.885965
# ...          ...    ...    ...       ...
# 137292  nullomer     18      0       0.0
# 150844  nullomer     48      0       0.0
# 159600  nullomer      4      2       0.5
# 128582  nullomer      2      0       0.0
# 164080  nullomer      1      0       0.0
#
# [299 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize =(6,6))
sns.histplot(x = 3, data=t, hue=0)
ax.set(xlabel="fraction perfect matches",
      title = "% perfect blastn matches")
# Out:
# [Text(0.5, 0, 'fraction perfect matches'),
#  Text(0.5, 1.0, '% perfect blastn matches')]

# %%
fig, ax = plt.subplots(figsize =(6,6))
sns.boxplot(x = 0, y=1, data=t)
ax.set(
    xlabel="",
    ylabel="N total = perfect + partial matches",
      title = "N total blastn matches")
ax.axhline(1)
ax.set_yscale('log')

# %%
fig, ax = plt.subplots(figsize =(6,6))
sns.boxplot(x = 0, y=3, data=t)
ax.set(
    xlabel="",
    ylabel="% perfect matches",

      title = "% perfect blastn matches")
#ax.axhline(1)
#ax.set_yscale('log')
# Out:
# [Text(0.5, 0, ''),
#  Text(0, 0.5, '% perfect matches'),
#  Text(0.5, 1.0, '% perfect blastn matches')]
