# %%
#!/usr/bin/env python
# coding: utf-8
"""
sarahfong

Summary
    - count kmers per chromosome
    - split kmer into multiple files where the first N letters of the kmer is the "key"
    - one file per key will be written w/ counts of sequences associated w/ that key + value

Example
    Say we find an 11mer, GCGTACGTACG, that appears 15025 times on chrN. The key length is 4. 
        The key is the first 4 letters "GCGT". 
        The value, or other 7 letters, "ACGTACG" will be written to chrN.GCGT.csv
        The 11mer counts for GCGTACGTACG, will be written to chrN.GCGT.csv

        The resulting file will look like this:

        ./chrN.GCGT.csv
            ACGTACG, 15025
Limitations
    - Skips sequences with "Ns"
            
"""

import argparse
from Bio.SeqIO.FastaIO import SimpleFastaParser
from Bio.Seq import Seq
import glob
import gzip
from itertools import product
import numpy as np
import os, sys

from timeit import default_timer as timer
from functools import partial
"""
arg_parser = argparse.ArgumentParser()

arg_parser.add_argument("job_num", type=str, help='job number to look up in array.tsv')
arg_parser.add_argument("array", type=str, help='ARRAY file of job numbers, chromosome ids')
arg_parser.add_argument("directory", type=str, help='directory where chromosom.fa lives')
arg_parser.add_argument("length", type=int, help='kmer length')
arg_parser.add_argument("keysize", type=int, help='kmer key length for storing info')

args = arg_parser.parse_args()

JOB_NUM, ARRAY, PATH, WINDOW_SIZE, KEYSIZE = args.job_num, args.array, args.directory, args.length, args.keysize

"""
JOB_NUM=13 # 25 = chrY, 13=chr22
ARRAY = "/wynton/home/ahituv/fongsl/nullomers/bin-generate/arrays/chr_fa_array-hs1.tsv"
PATH = "/wynton/home/ahituv/fongsl/dna/hs1/"
WINDOW_SIZE = 12
KEYSIZE = 5


# make outdirectory for
OUTDIR = os.path.join(PATH, "kmers", f"{WINDOW_SIZE}mers")

print("OUTDIR", OUTDIR) 
if os.path.exists(OUTDIR) is False:
    os.mkdir(OUTDIR) 


###
# functions
###

def array_reader(array, job_number):
    """
    read array, return value matching job number
    """
    
    with open(array, "r") as reader:
        for line in reader:
            num, chr_num = line.strip("\n").split("\t")
            if int(num) == int(job_number):
                CHR_NUM = chr_num
            
    return CHR_NUM

# ## extract fa sequence
def extractFaSeq(chr_num, path):
    """
    get chr-specific sequence, reverse complement

    require
        Bio.SeqIO.FastaIO - SimpleFastaParser
        gzip

    input
        chr_num (str) - chromosome number e.g. 1,2,3,X,Y
        path (str) - path to .fa files

    method
        1. get fa.gz name
        2. open fa file
        3. get sequence w/ simpleFastaParser
        4. get reverse complement by turning seq into Seq object

    return 
        seq (seq record) - str of sequence (should be one per chromosome)
        rev (seq record) - str of reverse complement sequence (should be one per chromosome)
    """

    print("reading fa", str(chr_num) +".fa.gz")

    #1
    WYNTON_PATH = "/wynton/group/databases/goldenPath/hg38/chromosomes"
    fa = os.path.join(WYNTON_PATH, f"{chr_num}.fa.gz")

    #2 open
    with gzip.open(fa, "rt") as handle:

        #3  read using simpleFastaParser
        for val in SimpleFastaParser(handle):
            seq_id, seq = val
            print(seq_id)

            #4
            rev = str(Seq(seq).reverse_complement())

            print("sequence size forward, reverse", len(seq), len(rev))
    return seq, rev

# make key-mer universe

def makeKeys(keysize):
    """
    input
        keysize (int) - length of kmer-keys to create

    require
        itertools.product
        python list comprehension

    method
        itertools.product kmers -> join kmers into str -> make list


    return
        key_set (set) - list of strings. 
    """ 
    key_set = set()
    for item in product("ACGT", repeat=keysize):
        key_set.add("".join(item))


    return key_set

# ## retreive one kmer
# 
# ### !Major question! What to do about N's


def getOneKmer(sequence, windowsize, start):

    """
    get 1 kmer; break up sequence into equally sized kmers w sliding window of with windowsize, stepsize
    
    required packages
        - numpy
        
    inputs
        sequence (str) - sequence to break into kmers
        windowsize (int) - windowsize to make for sequence
        start (int) - index to get sequence

        
    method
        1. get kmer
        2. if kmer does not have N in sequence
    
    return 
        kmer (str) - windowsize from input sequence
        
    """
    #1
    kmer = sequence[start:start+windowsize].upper()

    #2
    if "N" not in kmer.upper(): # append sequence windows within range of possible windows

        return kmer
    
    else:
        return None
    
# ## count kmers in universe

def countKmersUniverse(kmer_list, keysize):
    
    """
    add kmer counts to chromosome universe dictionary:

    input
        kmer_list (list) - list of kmers in fasta sequence

    method
        1. build kmer-universe dict while parsing kmers
        2. add kmer counts to dictionary, removing NoneType instances. 
            2.1 get key-specific dictionary from universe dictionary
            2.2 if value sequence is not in key dictionary, add. 
            2.3 if value sequence has been seen, increase dictionary value count. 
        3. print timer

    return
        universe_dict (dictionary) - chromosome universe w/ kmer counts. 

    """

    universe_dict = {}


    start = timer()
    
    
    #2 count items in dictionary
    for i in kmer_list:

        if i is not None:

            key, value = i[:keysize], i[keysize:] # split string into key, value

            if key not in universe_dict: # if key is not in universe dictionary
                universe_dict[key]={}

            #2.1
            keydict = universe_dict[key]

            #2.2 handle cases when value is not in dictionary
            if value not in keydict:
                keydict[value] = 1
                
            else:
                keydict[value]+=1
               
        else:
            continue
            
    end = timer()

    print("Counting kmer instances:", end-start, "\n Writing dict")
    
    return universe_dict


# ## write dictionary

def writeDictionary(chr_num, outpath, windowsize, result_dict, keyset):
    """
    write kmer universe dictionary to outfile
    
    input
        chr_num (str) - chr number or all
        path (str) - path to write outfile
        windowsize (int) - size of window used for kmers
        results_dict (dictionary) - kmer universe w/ counts of kmer occurrences 
    
    method
        1. create the outfile as key of keys
        2. if not already written (log_key not in keyset), write key, value as comma-separated str to outfile
        3. close the outfile
        4. compress outfile
        5. write outfile log_key to the log
    
    return 
        query (str) - written file name w asterisks for the key
    
    """
    #print("writing keys", keyset)
    
    #1
    for key, value in result_dict.items():
        log_key = f"{chr_num}.{key}"
        
        # make the outfile for each key 
        out_file = os.path.join(outpath, f"{log_key}.csv")
        
        # write the values
        with open(out_file, "w") as writer:
            for secondkey, count in value.items():

                writer.write(f"{secondkey},{count}\n")
        #3
        writer.close()

        #4
        os.system(f"gzip {out_file}")

        #5 write outfile to log
        writeChrLog(log_key, outpath)
        
    query = os.path.join(outpath, f"{chr_num}.*.csv")
    
    return query


def readChrLog(path):
    """
    read chr.log and determine whether chromosome has already been summed into file dataset
    
   input
        chr_num (str) - chromosome number
        path (str) - path to directory to write log
        
    method
        1. make the log file
            1.1 if log file does not exist, return False (none of the chromosomes have been run) 
        2. open existing log file. 
        3. append chr_num to list
        4. check whether input chr_num is in list:
            4.1 if yes, return True (chromosome has been run)
            4.2 if no, return False (chromos dome has not been run)
    
    return
        empty set
        runset (set) - if key has been added to final nullomer count
    """
    
    #1
    out = os.path.join(path, "kmer.log")

    #2
    runset=set()
    if os.path.exists(out) is True:
    
        with open(out, "r") as chrlog:
        #3
            for line in chrlog.readlines():
                runset.add(str(line.split("\n")[0]))
        
    print("N chromosomes have been run already", len(runset))
    return runset
       
            
def writeChrLog(chr_num, path):
    """
    write log of chrs written to the all mer
    
    input
        chr_num (str) - chromosome number
        path (str) - path to directory to write log
        
    method
        1. make the log file
        2. open the log file
        3. append the chr_num to the log file
        4. close the file
    """
    #1
    out = os.path.join(path, "kmer.log")
    
    #2
    with open(out, "a") as chrlog:
        
        #3
        chrlog.write(f"{chr_num}\n")
    
    #4
    chrlog.close()
    
    #print(f"wrote {chr_num} to kmer.log", out)
    

###
# main
###

def main(argv):
   

 
    """
    per chromosome, write kmer count frequency dictionary as csv
    
    input
        chr_num (str) - chromozome number to process kmers for
        path (str) - path to fa files, and to write
        window_size (int) - size of window to consider for kmer
    
    method
        0. get chr num from job+num and array
        1. get sequence +/- from fa
        2. generate set of keys to write kmer-space to. Keys will be used to quantify the known-kmer space.
            2.1 check to make sure you haven't run this already. 
        3. start the timer. 
        4. set up to retrieve partial commands
        5. pool forward, reverse kmers from sequence
        6. extend and count kmers in genome
        7. write dictionary to .csv

    return
        outcsv (str) - csvs of kmer universe, separated by keys
    
    """
    
    #0
    CHR_NUM = array_reader(ARRAY, JOB_NUM)
    
    #1 get chr sequence, reverse complement 
    SEQ, REV = extractFaSeq(CHR_NUM, PATH)


    #2 get kmer key set, universe dict
    KEY_SET = makeKeys(KEYSIZE)
    
    CHR_KEYS = set([f"{CHR_NUM}.{key}" for key in KEY_SET])
    
    # 
    run_already = readChrLog(OUTDIR) # check whether key has been run already
    

    WRITE_KEYS = set(CHR_KEYS).difference(run_already) 


    #3 calculate the number of starting positions 
    STARTS = list(range(len(SEQ) - WINDOW_SIZE + 1))

    #4 setup partial command to retrieve kmers
    partial_seq = partial(getOneKmer, SEQ, WINDOW_SIZE)
    partial_rev = partial(getOneKmer, REV, WINDOW_SIZE)

    #5 get all kmers from chromosome
    result_multi = [partial_seq(start) for start in STARTS]
    result_multi_r = [partial_rev(start) for start in STARTS]

    #6 count knownmers in kmer universe
    result_multi.extend(result_multi_r) # make 2 lists into 1 big list

    # count items, add to dictionary
    genome_kmers = countKmersUniverse(result_multi, KEYSIZE)

    #7 write dictionary
    outcsv = writeDictionary(CHR_NUM, OUTDIR, WINDOW_SIZE, genome_kmers, WRITE_KEYS)

    print(outcsv)
    
if __name__ == '__main__':
    main(sys.argv[1:])
# Out:
# OUTDIR /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers
# reading fa chr21.fa.gz
# chr21
# sequence size forward, reverse 46709983 46709983
# N chromosomes have been run already 1025
# Counting kmer instances: 69.25911186495796
#  Writing dict
# writing keys {'chr21.TATAT', 'chr21.CTTTC', 'chr21.CCTTA', 'chr21.ATAGC', 'chr21.GGAAT', 'chr21.GGGAT', 'chr21.TGAGC', 'chr21.TACTT', 'chr21.GAATC', 'chr21.TCTAT', 'chr21.TCAAG', 'chr21.CGACA', 'chr21.TGCGT', 'chr21.GGCCT', 'chr21.ACTAC', 'chr21.TGATC', 'chr21.AGGAA', 'chr21.GACCA', 'chr21.AAGGT', 'chr21.ATGAC', 'chr21.CATGA', 'chr21.AATTG', 'chr21.GGCGT', 'chr21.ACTGG', 'chr21.CCCCC', 'chr21.ACGCG', 'chr21.TTGTG', 'chr21.CTCCC', 'chr21.CACGG', 'chr21.CTCAG', 'chr21.CCCGC', 'chr21.GCTAT', 'chr21.GTAAG', 'chr21.CCTGG', 'chr21.ATTGT', 'chr21.ATACT', 'chr21.TTGTT', 'chr21.GACGC', 'chr21.TGCTC', 'chr21.CTTCG', 'chr21.CCCAA', 'chr21.CATGT', 'chr21.CCCCT', 'chr21.AACCG', 'chr21.CTCAT', 'chr21.CCGTC', 'chr21.ATGAT', 'chr21.GTGGT', 'chr21.CTTTG', 'chr21.AGCCC', 'chr21.GACTG', 'chr21.TGTTA', 'chr21.CCTGT', 'chr21.GTTGT', 'chr21.AGAAT', 'chr21.CCTAT', 'chr21.GAAGA', 'chr21.GTTAA', 'chr21.ACGCT', 'chr21.TGAAA', 'chr21.CTGCG', 'chr21.GCGGC', 'chr21.GTTCC', 'chr21.CACCT', 'chr21.CGAAT', 'chr21.AACGC', 'chr21.GACCT', 'chr21.GAACT', 'chr21.CCAGG', 'chr21.CTCGT', 'chr21.TACGA', 'chr21.TCGAC', 'chr21.CAATC', 'chr21.ATCTT', 'chr21.TTGAA', 'chr21.ATAAG', 'chr21.AACGT', 'chr21.CCTAG', 'chr21.CATAG', 'chr21.TGTAA', 'chr21.GTTAC', 'chr21.AGTAG', 'chr21.TCGCT', 'chr21.GGCTC', 'chr21.ACATA', 'chr21.GCAAG', 'chr21.GGTGT', 'chr21.TGGGG', 'chr21.ACAAG', 'chr21.TAAAT', 'chr21.CTTCA', 'chr21.CGTTA', 'chr21.GATAG', 'chr21.GGGAA', 'chr21.TGCGC', 'chr21.GTGAA', 'chr21.ACACC', 'chr21.CCAGT', 'chr21.AGCCG', 'chr21.GTCGT', 'chr21.TAGCT', 'chr21.ACCTG', 'chr21.GACAA', 'chr21.CCGAC', 'chr21.CCAAC', 'chr21.TTAGT', 'chr21.AGCGG', 'chr21.ATCGA', 'chr21.TCTGA', 'chr21.ACAAA', 'chr21.CCTTT', 'chr21.CAGGA', 'chr21.AACTC', 'chr21.GCACT', 'chr21.GTGCG', 'chr21.CACAG', 'chr21.TAATT', 'chr21.CGCAT', 'chr21.GAGAG', 'chr21.GGTAA', 'chr21.TTAAT', 'chr21.CAGCG', 'chr21.ATGCA', 'chr21.TGACG', 'chr21.GGGTC', 'chr21.GCATA', 'chr21.TGTCT', 'chr21.TCACT', 'chr21.CGTGT', 'chr21.GGACC', 'chr21.AGTCG', 'chr21.CTACA', 'chr21.CGCAA', 'chr21.TCGAT', 'chr21.CTGTG', 'chr21.GGTCT', 'chr21.GGAAA', 'chr21.CAAAA', 'chr21.AGACT', 'chr21.CTCTA', 'chr21.TGGAG', 'chr21.CATCT', 'chr21.CGATG', 'chr21.AGCTA', 'chr21.GAGCT', 'chr21.CGAAA', 'chr21.TATCA', 'chr21.TTTTC', 'chr21.TTTGG', 'chr21.GCTTA', 'chr21.CATTC', 'chr21.AACCT', 'chr21.TATTT', 'chr21.CCCAC', 'chr21.GAGAA', 'chr21.CCCGT', 'chr21.TGAGA', 'chr21.CTCTG', 'chr21.TCCCG', 'chr21.AGCGA', 'chr21.CGTAT', 'chr21.GATGG', 'chr21.TTGCA', 'chr21.CCTTC', 'chr21.TTGTC', 'chr21.AAGCT', 'chr21.GGACG', 'chr21.TCACG', 'chr21.TCTAC', 'chr21.TTGAC', 'chr21.AGTTA', 'chr21.TGATG', 'chr21.TACTA', 'chr21.GCGAG', 'chr21.AATCA', 'chr21.AGATG', 'chr21.AGTTG', 'chr21.ACCTT', 'chr21.ACTCG', 'chr21.TTCTA', 'chr21.GAGTC', 'chr21.ACGCC', 'chr21.CTCGA', 'chr21.GGTGG', 'chr21.GGTTA', 'chr21.CGCCC', 'chr21.GACTC', 'chr21.CAGGC', 'chr21.AACGA', 'chr21.ATTCA', 'chr21.TAGCA', 'chr21.AAACT', 'chr21.AAACA', 'chr21.GCTAG', 'chr21.CAAAG', 'chr21.GGTAG', 'chr21.GATAA', 'chr21.AAAGT', 'chr21.CCCCG', 'chr21.TGTTT', 'chr21.TCCGT', 'chr21.CGCAG', 'chr21.ACAGC', 'chr21.CCGGT', 'chr21.GGGCG', 'chr21.TGCGG', 'chr21.CTGTC', 'chr21.CTACC', 'chr21.AGAGT', 'chr21.AGGAT', 'chr21.AACCA', 'chr21.ATGTA', 'chr21.GAGTG', 'chr21.CCCTC', 'chr21.CCAGA', 'chr21.GAAGG', 'chr21.TATAG', 'chr21.CTTTA', 'chr21.AGACC', 'chr21.TTCCA', 'chr21.TACAA', 'chr21.TCTTT', 'chr21.CAACC', 'chr21.AACAG', 'chr21.AAATC', 'chr21.GGCTA', 'chr21.TTCGC', 'chr21.ACAGG', 'chr21.TTCAA', 'chr21.CAACG', 'chr21.CGCTG', 'chr21.GTGCA', 'chr21.CTTCT', 'chr21.AACTA', 'chr21.GAACG', 'chr21.GCGGA', 'chr21.TAAGG', 'chr21.CCACC', 'chr21.CCTGC', 'chr21.GCCTT', 'chr21.ATTCG', 'chr21.GATCT', 'chr21.TTGTA', 'chr21.TCAGT', 'chr21.TCTCG', 'chr21.TTCCT', 'chr21.ATGGA', 'chr21.AGAGC', 'chr21.CAGGG', 'chr21.GGGGT', 'chr21.CGCGC', 'chr21.TGATA', 'chr21.GGTTC', 'chr21.AGGGA', 'chr21.ACCCG', 'chr21.TACCA', 'chr21.GGATG', 'chr21.GCCTG', 'chr21.TCCAA', 'chr21.GTGAC', 'chr21.TCGTG', 'chr21.TACAC', 'chr21.GCTCT', 'chr21.GCGCC', 'chr21.TCCAC', 'chr21.TCTT ...
# wrote chr21.GATCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATCCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCCAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCACC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CACCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACCCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCCGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCGCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGCCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCCTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCTTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTTGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTGGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGGCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGCCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCCTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCTCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTCCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCCTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCTAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTAAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAAAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAAGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAGTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGTGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTGCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGCTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCTGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTGGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGGGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGGAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGATT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GATTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATTAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTACA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TACAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACAGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAGGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGGTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGTGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTGTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGTTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTTAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTAGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAGCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGCCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCCAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CACCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACCAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCACG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CACGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACGTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGTCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTCCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCCAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCAGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAGCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGCTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCTGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTGTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTTAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTAAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAATT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AATTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATTTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTTTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTTTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTTAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTATT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TATTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATTTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTTAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAATA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AATAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATAAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAAGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAGAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGAAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAATG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AATGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATGAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGACA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GACAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACAGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAGAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGAGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAGTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGTGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTGAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGAGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAGGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGGGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGGCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGCCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCCAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCATC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CATCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATCAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCACT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CACTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACTGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAATG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATGAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGAAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAAGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAGCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCCAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCAGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAGTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGTGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGTTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTTGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTGCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGCTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCTCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTCAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCACA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CACAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACAGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAGCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGCCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTCCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCCCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCCCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCCTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTGGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGGTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGTCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTCAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CACTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACTTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTTTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTTTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTTGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTGTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGTGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTGAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGACT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GACTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACTGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTGAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAAGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAGGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGGCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGCAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCATG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CATGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATGTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGTGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGTTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTTCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTCAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCAGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAGGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGGCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGCAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCAAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAAGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAGAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGATT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GATTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATTGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTGTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTTGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTGGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGGGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGGTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGTGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTGGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGGCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGCTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTGTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGTTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTTTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTGTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGTCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTCTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCTTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTTCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTCTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTTCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTCCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGCTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCTCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTCGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCGGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGGCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCATG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CATGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATGGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGGAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGAAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAATA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AATAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATAGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCCTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCTGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGTGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTGGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGGGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGGGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGGAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGACC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GACCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACCTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCTAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTACT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TACTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACTCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTCTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCTGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTGGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGTCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTCCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCCCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCCAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCAGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAGGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGGGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGGAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGAGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAGCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGCTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCTAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGGGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGGGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGGCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTTTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTTCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTCTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCAGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAGCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGCAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCAGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGGAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGAAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAGGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGGCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGCTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCTCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCTGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTGCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGCCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCCCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTTGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAGCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCTCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCCTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCTGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTGGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGGAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGAGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCTGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTGCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGCGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCGGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGGAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGACG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GACGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACGGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGGCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGCAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCACC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CACCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACCTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCTGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTGCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTCAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAGAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGATG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GATGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACAGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAGTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGTTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTTAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTACT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TACTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACTTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTCCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCCCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCCTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCTAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTAGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAGGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGGTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGTAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTAGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAGTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGTCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTCTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTGCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGCAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATGTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGGGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCCCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAGGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGGAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGACT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACTGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTGGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGGTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGTTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTTCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTCTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCTCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTCTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCTAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTAAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAAGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCAAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAATG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AATGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAGGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGACA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAGAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGACA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAGAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGAAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAAAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAAAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAAAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAACC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AACCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACCAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCAAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAAAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAATT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AATTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATTCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGCCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCCAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAAAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAGTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGTTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTAAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAAAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAATA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATAGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGGTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGTTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTTTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TATTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCTGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTGAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGAGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAGCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCAAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAATA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAGAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGACC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GACCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACCAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATGGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGAAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAAAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AATAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATACA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAGTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCTTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTTAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTAAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGAGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAGAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGATC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATCCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCCCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCCGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCGAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGAGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGGAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAAGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTGCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGCAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCTGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAGGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGGCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGCGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCGGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGGTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTCAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCAGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TACAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACAAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAATT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATTTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTTGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTATG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TATGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATGTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGTAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTATT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTTGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTGAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGAGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAGAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGACG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACGGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGGAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGCTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCTTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTGTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGTCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTCGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCGCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGCCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCCCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGAGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGCAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCAGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGTGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGGCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGCGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCGTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGTGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTGAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGATC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GATCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATCTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCTCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGGCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCACC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CACCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACCGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCGCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGCAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAAGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAGCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTCCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCCGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCGCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGCGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCGTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGTTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTTCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTCCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCATT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CATTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCTCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGCCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCTCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTCAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGAGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAGTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGTAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTAGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GACTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACTAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTACA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGCGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCGCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCCCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGCCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CATGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATGCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTGGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGCTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCTAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTAAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTATA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TATAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATATT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTTAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTAGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAGTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTAGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAGAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACGGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGGGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGGGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGGTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTTCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACCGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCGTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGTGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGGAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGATG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GATGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATGGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGTCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTCTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCTCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTCAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCAAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAATC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AATCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTGAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACCTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCTCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTCGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCGTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATCCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCTCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCCAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCACT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CACTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACTCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGCAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCACA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CACAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AATTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATTGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTGTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGTAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# ...
# wrote chr21.CTATT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAAAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAACG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AACGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAGTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGACT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GACTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTAAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAGGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCCGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAGCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCGAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGAAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCCGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAAAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AACCT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TATGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAGCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCGTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGTAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTACT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TACTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGAAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACTTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTACG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TACGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACGAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTTAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TATCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATCAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATGTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAGCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGCGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCGCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACAAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAACC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AACCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGTCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTCGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAACG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AACGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAACC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CATCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CATCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATCGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCGCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGTAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTAGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTGAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGATA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TATTG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATAAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCCAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCATA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CATAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACGTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGTAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGTCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTAGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATTGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTGAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTACC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TACCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AACAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCATA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AATGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAGCA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGCGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTCGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCGAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CATAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATATG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TATGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AATCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATCGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTCCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATACG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTATG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACGGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CACGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACGTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAAGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCAAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCAAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACTCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATTCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AACGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACGAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATGAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGGTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACGAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GATTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTCGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTAAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAACC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CATTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCTAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTATG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GAGAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGCGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTTCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCCGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTATC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGCAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAAGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GATAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAGCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCGAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGATG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGGGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AACTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGATT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCGGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGGAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AAGTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AGTAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TATAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACTAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTATA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTTGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTCGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCGTC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCGTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGCCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTCTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTATA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TATTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATTAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATAGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TACCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGATA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GATAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGAAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATTAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGTAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGACA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATAAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAACT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGCTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AATTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TGACG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATTAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAGGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GATAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAGAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCGTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGTTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACGAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCGGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTTAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAGAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGCTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GACGC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TATCC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TATGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGAAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AACGG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCTAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CTATC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATCTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GACGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGGTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGACG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCGAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGTTT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ATCGT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GGTAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACTAA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TACTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TTAAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.AACTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTAAC to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAACA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGTAT to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GTCGA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CAACG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.ACTAG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GATCG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.GCATA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CGATA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TAACG to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.CCGTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# wrote chr21.TCGTA to kmer.log /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/kmer.log
# /wynton/home/ahituv/fongsl/dna/hs1/kmers/12mers/chr21.12mers.*.csv
