# %% [markdown]
# # overview
# 20231119
# sarahfong
#
#
# **Goal** - design liver MPRA for Ajam specific accessible regions in Ajam2 genome sequences
#
#
# **Design features**
#
# - Ajam-specific liver accessible sequences from Ajam v. EptFus atac-seq (N = 2218 loci),
#     - compared by liftingOver both atac-regions to hg38, require only 10% identity.
#     - Then, lifted sequences back to Ajam2 genome build
#
# - Tiles: 200bp long tiles
#
# - Step size: 20bp-step sliding window across loci
#
# - Shuffle: 300 dinucleotide shuffled elements randomly sampled from 2218 test loci
#
# - Controls: 350 HepG2 Synthetic positive (N=181) and negative (N=169) controls from Smith 2013
#
# - GC fraction: filter for 40-60% GC content
#
# - Reverse complement: assuming everything lifted from Hg38 to Ajam2 is in the forward position, so I will also make the reverse position
#
#
# ## results
#     Library_forward: N = 53298 or 52698 tiles + 300 shuffle + 350 positive/negative controls
#     Library_forward GC filtered = 23182 tiles or 22567 tiles + 300 shuffle + 315 positive/negative controls
#
#     Library_reverse: N = 53298 or 52698 tiles + 300 shuffle + 350 positive/negative controls
#     Library_reverse GC filtered = 23182 tiles or 22567 tiles + 300 shuffle + 315 positive/negative controls

# %%
from Bio.SeqIO.FastaIO import SimpleFastaParser
from Bio.Seq import reverse_complement, Seq
from Bio.SeqUtils import gc_fraction

import os, sys
import numpy as np
import pandas as pd
#import pybedtools as pbt
from random import shuffle
import matplotlib.pyplot as plt
import seaborn as sns

import config_readwrite as crw
import plot_params as pp
pp.fonts()
# Out:
# ('sans-serif', 'Arial', 18)

# %% [markdown]
# # config and params

# %%
cfn_file = os.path.join(os.getcwd(), "config.bat2.ini")

config, cfn = crw.read(cfn_file)

# %% [markdown]
# ## dataset params

# %%
# dataset params
TISSUE = "liver"
SPECIES = "ajam"
BUILD = "artjam2"
PATH =  config[TISSUE][f"{SPECIES}_path"]

LIVER_FASTA = config[TISSUE][f'{TISSUE}.{SPECIES}_specific.{BUILD}.fa']

# %% [markdown]
# ## mpra params

# %%
# mpra params
TILE_LEN = 200
STEP = 20
N_SHUF = 300  # number of randomly selected sequences to shuffle
GC_CONTENT_MIN = 0.4 # min fraction of GC content in the sequence
GC_CONTENT_MAX = 0.6 # max fraction of GC concent in the sequence
REVERSE = True  # bool, do you want reverse complement of sequence?

TEST = os.path.join(PATH, f"mpra.{TISSUE}.{SPECIES}_specific.wo.adapters.fa")
SHUFFLE = os.path.join(PATH, f"mpra.{TISSUE}.{SPECIES}_specific.wo.adapters.shuffle.fa")
META = os.path.join(PATH, f"mpra.{TISSUE}.{SPECIES}_specific.meta.txt")

# %% [markdown]
# ## positive and negative controls

# %%
CTRL_PATH = "/wynton/group/ahituv/fongsl/projects/MPRA_DESIGN/data/"
NEG_HEPG2_SYN = os.path.join(CTRL_PATH, "HepG2.negative.ctrl.noadapters.fa")
POS_HEPG2_SYN = os.path.join(CTRL_PATH, "HepG2.positive.ctrl.noadapters.fa")

# %%
section = "mpra"
crw.check(config, section)

config[section]["test_sequences"] = TEST
config[section]["shuffled_sequences"] = SHUFFLE
config[section]["tile_len"] = str(TILE_LEN)
config[section]["step_size"] = str(STEP)

config[section]["n_shuffles"] = str(N_SHUF)
config[section]["gc_content_min"] = str(GC_CONTENT_MIN)
config[section]["gc_content_max"] = str(GC_CONTENT_MAX)
config[section]["reverse_orientation"] = str(REVERSE)

# %% [markdown]
# # functions

# %%
def makeTile(seq, start_index, size):
    """return sequence slice from start to start+size"""

    start_index, size = int(start_index), int(size)
    stop_index = int(start_index) + size
    tile_sequence = seq[start_index:stop_index]

    if len(tile_sequence) != size:  # check if tile sequence is too short.
        tile_sequence = None

    return tile_sequence


def addAdaptors(tile_sequence):
    """add illumina adaptors to left and right of sequence"""

    adaptor5, adaptor3 = "AGGACCGGATCAACT", "CATTGCGTGAACCGA"
    adapted = adaptor5 + seq + adaptor3

    return adapted.upper()


def dinucScramble(seq, verbose):
    """dinucleotide scramble sequences"""

    n = 2  # pick size 2

    # split sequence into pairs
    splits = [seq[i:i+n] for i in range(0, len(seq), n)]
    shuf_splits = splits[::]

    shuffle(shuf_splits)  # from random library

    if verbose is True:
        print(np.unique(splits, return_counts=True))
        print(np.unique(shuf_splits, return_counts=True))

    return "".join(shuf_splits)


def checkLength(name, seq, tile_length):
    """check that sequence is the correct length in the dataframe"""

    
    if len(seq) != tile_length:
        
        print("length is wrong for", name,
              "\nactual lengh:", len(seq),
              "\ndesired length:", tile_length)
        return False
    else:
        return True

def writeFaDict(dict_, outfile):
    """write dictionary to fasta file"""

    # open the file
    with open(outfile, "w") as writer:

        # parse dictionary
        for name, seq in dict_.items():

            # add '>' if not in name
            if ">" not in name:
                print("add > to", name)
                name = ">" + name

            # write line
            writer.write(f"{name}\n{seq}\n")

# %% [markdown]
# # parse fasta

# %%
tile_dict = {} # dictionary to collect tiles
gc_dict={}  # dictionary to collect gc content info

with open(LIVER_FASTA, "r") as fa:  # open fasta
    for value in SimpleFastaParser(fa):  # parse fasta
        
        name, sequence = value  # get sequence data
        n_steps = 0
        
        # make tiles with step
        for step in np.arange(0, len(sequence), STEP): 
            
            # get tile sequence
            tile = makeTile(sequence, step, TILE_LEN)
            
            # add to dictionary
            if tile is not None:  # if None, tile exceeds end of sequence
                # compute the GC fraction
                gc_frac= int(gc_fraction(tile)*100)
            
                # name tile
                tilename = f">{name}.tile_{n_steps}.{BUILD}.{gc_frac}"
                
                # add tile to dictionary
                tile_dict[tilename] = tile
                gc_dict[tilename]=gc_fraction(tile)
            
            # increase step counter
            n_steps +=1

# %%
print(len(tile_dict.keys()))
# Out:
# 52698

# %% [markdown]
# ## inspect GC content

# %%
gc = pd.DataFrame(gc_dict.items(),columns=["name", "gc_frac"])
gc_filter = gc.loc[(gc["gc_frac"] >= GC_CONTENT_MIN)
                         & (gc["gc_frac"] <= GC_CONTENT_MAX)]

# %% [markdown]
# ### plot GC fraction

# %%
fig, ax=plt.subplots(figsize=(6,6))
sns.histplot(x="gc_frac", data=gc, color="blue", label="full", kde=True)
sns.histplot(x="gc_frac", data=gc_filter, color="orange", label="gc_filtered", kde=True)
ax.legend()

ax.set(title="Ajam-specific liver gc fraction")
plt.savefig(os.path.join(PATH, f"{TISSUE}.{SPECIES}_specific.gc_content.pdf"), bbox_inches="tight")

# %% [markdown]
# ## filter GC?

# %%
gc_filtered = set(gc.loc[(gc["gc_frac"] >= GC_CONTENT_MIN)
                         & (gc["gc_frac"] <= GC_CONTENT_MAX),
                         "name"]
                  )
print("after GC filtering, N tiles meet this criteria",
      len(gc_filtered),
      "\n% of all tiles",
      len(gc_filtered)/gc.shape[0])
# Out:
# after GC filtering, N tiles meet this criteria 22567
# % of all tiles 0.428232570496034

# %% [markdown]
# # dinucleotide shuffles

# %%
# sample tiles without replacement
random_selected = np.random.choice(list(tile_dict.keys()),
                                   size=N_SHUF,
                                   replace=False
                                   )  


shuf_dict = {}  # random shuffle dictionary

# shuffle random tiles
for n, tile_id in enumerate(random_selected):
    
    tile_seq = tile_dict[tile_id]  # get tile sequence
    
    # shuffle tile sequence
    tile_scram = dinucScramble(tile_seq, True if n ==0 else False)

    # make shuffled id
    shuf_id = tile_id + ".shuffle" 
    shuf_dict[shuf_id]= tile_scram
# Out:
# (array(['AC', 'AG', 'AT', 'CA', 'CC', 'CG', 'CT', 'GA', 'GC', 'GG', 'GT',
#        'Ga', 'TA', 'TC', 'TG', 'TT', 'aa', 'cc', 'ct', 'gg', 'tc', 'tt'],
#       dtype='<U2'), array([ 1, 13,  1, 12,  7,  1,  6,  6,  9,  9,  3,  1,  3,  7,  9,  2,  1,
#         5,  1,  1,  1,  1]))
# (array(['AC', 'AG', 'AT', 'CA', 'CC', 'CG', 'CT', 'GA', 'GC', 'GG', 'GT',
#        'Ga', 'TA', 'TC', 'TG', 'TT', 'aa', 'cc', 'ct', 'gg', 'tc', 'tt'],
#       dtype='<U2'), array([ 1, 13,  1, 12,  7,  1,  6,  6,  9,  9,  3,  1,  3,  7,  9,  2,  1,
#         5,  1,  1,  1,  1]))

# %% [markdown]
# ## shuffle random tiles - GC filtered

# %%
shuf_gc = {}

random_selected_gc = np.random.choice(list(gc_filtered),
                                      size=N_SHUF,
                                      replace=False
                                      )
for n, tile_id in enumerate(random_selected_gc):

    tile_seq = tile_dict[tile_id]  # get tile sequence

    # shuffle tile sequence
    tile_scram = dinucScramble(tile_seq, True if n == 0 else False)

    # make shuffled id
    shuf_id = tile_id + ".shuffle"
    shuf_gc[shuf_id] = tile_scram
# Out:
# (array(['AA', 'AC', 'AG', 'AT', 'CA', 'CC', 'CG', 'CT', 'GA', 'GC', 'GG',
#        'TA', 'TC', 'TG', 'TT', 'aC', 'ac', 'cc', 'cg', 'ct', 'gc', 'ta'],
#       dtype='<U2'), array([ 5,  3, 11,  2,  5,  7,  3,  6,  4,  7, 10,  3,  8,  5,  6,  1,  2,
#         8,  1,  1,  1,  1]))
# (array(['AA', 'AC', 'AG', 'AT', 'CA', 'CC', 'CG', 'CT', 'GA', 'GC', 'GG',
#        'TA', 'TC', 'TG', 'TT', 'aC', 'ac', 'cc', 'cg', 'ct', 'gc', 'ta'],
#       dtype='<U2'), array([ 5,  3, 11,  2,  5,  7,  3,  6,  4,  7, 10,  3,  8,  5,  6,  1,  2,
#         8,  1,  1,  1,  1]))

# %% [markdown]
# # positive, negative controls

# %% [markdown]
# ## negative control dictionary

# %%
neg_control = {}
with open(NEG_HEPG2_SYN, "r") as reader:
    for value in SimpleFastaParser(reader):
        name, seq = value
        neg_control[name] = seq

# %% [markdown]
# ## positive control dictionary

# %%
pos_control = {}
with open(POS_HEPG2_SYN, "r") as reader:
    for value in SimpleFastaParser(reader):
        name, seq = value
        pos_control[name] = seq

# %% [markdown]
# # combine sets, add adaptors

# %%
library, library_gc = {}, {}
dicts = [tile_dict, shuf_dict, neg_control, pos_control]
for d in dicts:
    for k, v in d.items():  # d.items() in Python 3+

        # I'm assuming everything is in the forward direction from the hg38 genome build
        k_plus = k + ".+"

        # check sequence length before adding adaptors
        length_check = checkLength(k, v, TILE_LEN)

        if length_check is True:

            # add adaptors
            library[k_plus] = addAdaptors(v)

            # filter gc content
            if k in gc_filtered:
                library_gc[k_plus] = addAdaptors(v)

            # add filtered positive and negative controls in
            elif "Smith" in k:
                # get GC fraction
                gc_frac = int(k.split(".")[-1])/100

                if gc_frac >= GC_CONTENT_MIN and gc_frac <= GC_CONTENT_MAX:
                    library_gc[k_plus] = addAdaptors(v)

# add shuffled GC_filtered elements to GC filtered dataset
for k, v in shuf_gc.items():
    # I'm assuming everything is in the forward direction from the hg38 genome build
    k_plus = k + ".+"

    # check sequence length before adding adaptors
    length_check = checkLength(k, v, TILE_LEN)

    if length_check is True:
        library_gc[k_plus] = addAdaptors(v)
print(len(library.keys()), len(library_gc.keys()))
# Out:
# 53348 23182

# %% [markdown]
# ## reverse complement?

# %%
library_rev, library_rev_gc = {}, {}  # collect results

dicts = [tile_dict, shuf_dict, neg_control, pos_control]

for d in dicts:
    for k, v in d.items():  # d.items() in Python 3+

        # I'm assuming everything is in the forward direction from the hg38 genome build
        k_minus = k + ".-"

        rev_v = reverse_complement(v)  # get reverse complement of sequence

        # check sequence length before adding adaptors
        length_check = checkLength(k, v, TILE_LEN)

        if length_check is True:
            # add adaptors
            library_rev[k_minus] = addAdaptors(rev_v)

            # filter gc content
            if k in gc_filtered:
                library_rev_gc[k_minus] = addAdaptors(rev_v)

            # add filtered positive and negative controls in
            elif "Smith" in k:
                # get GC fraction
                gc_frac = int(k.split(".")[-1])/100

                if gc_frac >= GC_CONTENT_MIN and gc_frac <= GC_CONTENT_MAX:
                    library_rev_gc[k_minus] = addAdaptors(rev_v)

# add shuffled GC_filtered elements to GC filtered dataset
for k, v in shuf_gc.items():

    # I'm assuming everything is in the forward direction from the hg38 genome build
    k_minus = k + ".-"

    rev_v = reverse_complement(v)  # get reverse complement of sequence

    # check sequence length before adding adaptors
    length_check = checkLength(k, v, TILE_LEN)

    if length_check is True:
        library_rev_gc[k_minus] = addAdaptors(rev_v)

print(len(library_rev.keys()), len(library_rev_gc.keys()))
# Out:
# 53348 23182

# %% [markdown]
# # write library fasta

# %%
to_write = {
    "library_forward":library, 
    "library_forward.gcfiltered":library_gc, 
    "library_reverse":library_rev, 
    "library_reverse.gcfiltered":library_rev_gc, 
}

results = {}
for name, d in to_write.items():
    
    library_file = os.path.join(PATH, f"{TISSUE}.{SPECIES}_specific.mpra.{name}.fa")
    library_file_meta = os.path.join(PATH, f"{TISSUE}.{SPECIES}_specific.mpra.{name}_metadata.tsv")
                                
    writeFaDict(d, library_file)
                                
    config[section][name] = library_file
    config[section][f"{name}.metadata"] = library_file_meta
                                

    # write library meta data
    arrays = {}  # collect dictionary information in array format
    for k, v in d.items():

        if len(k.split(".")) == 6:
            
            coor, name_, tile, build, gc, strand = k.split(".")
            other = "test"
            

        elif len(k.split(".")) == 7:
            coor, name_, tile, build, gc, other, strand = k.split(".")

        elif len(k.split(".")) == 5:
            coor, tile, build, gc, strand = k.split(".")
            other = "ctrl"

        if "NW" in k:
            coor = coor + "." + name_
        if ">" in coor:
            coor = coor.strip(">")
        
        arrays[k] = np.array([coor, tile, build, gc, other, strand])

    # make metadata into pandas dataframe
    cols = ["coor", "info", "build", "gc_frac", "type", "strand"]

    meta = pd.DataFrame(np.vstack(arrays.values()), columns=cols)

    print(meta.shape)
    
    meta["dataset"] = name
    meta["gc_within_40_60"] = False
    meta["gc_frac"] = meta["gc_frac"].astype(int)
    meta.loc[(meta["gc_frac"]<=(GC_CONTENT_MAX*100)) 
             &(meta["gc_frac"]>=(GC_CONTENT_MIN*100)), "gc_within_40_60"] =True
    
    # write metadata
    meta.to_csv(library_file_meta, sep='\t', index=False)
    
    results[name] = meta
crw.write(config, cfn)
# Out:
# add > to Smith:HepG2Negative-0.C:SLEA_hg18:chr2:210861483-210861650|10:V_XBP1_01:GTGATGACGTGTCCCAT;30:V_HNF4_Q6:AAGGTCCAG;42:V_HNF6_Q6:CAAAATCAATAA;57:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;79:V_HNF3ALPHA_Q6:TGTTTGCTTTG;93:V_Rxra_UP:GGCCGTGACCCCGTGAT;113:V_PPARA_02:CCGGGTCATTGGGGTCAGG;135:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC.hg18.50.+
# add > to Smith:HepG2Negative-1.C:SLEA_hg18:chr2:210861483-210861650|10:V_XBP1_01:GTGATGACGTGTCCCAT;30:V_HNF4_Q6:AAGGTCCAG;42:V_HNF6_Q6:CAAAATCAATAA;57:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;79:V_HNF3ALPHA_Q6:TGTTTGCTTTG;93:V_Rxra_UP:GGCCGTGACCCCGTGAT;113:V_PPARA_02:CCGGGTCATTGGGGTCAGG;135:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC_Reversed:.hg18.50.+
# add > to Smith:HepG2Negative-2.C:SLEA_hg18:chr2:210861483-210861650|10:V_XBP1_01:GTGATGACGTGTCCCAT;30:V_HNF4_Q6:AAGGTCCAG;42:V_Rxra_UP:GGCCGTGACCCCGTGAT;62:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;84:V_HNF3ALPHA_Q6:TGTTTGCTTTG;98:V_PPARA_02:CCGGGTCATTGGGGTCAGG;120:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;146:V_HNF6_Q6:CAAAATCAATAA.hg18.51.+
# add > to Smith:HepG2Negative-3.C:SLEA_hg18:chr2:210861483-210861650|10:V_XBP1_01:GTGATGACGTGTCCCAT;30:V_HNF4_Q6:AAGGTCCAG;42:V_Rxra_UP:GGCCGTGACCCCGTGAT;62:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;84:V_HNF3ALPHA_Q6:TGTTTGCTTTG;98:V_PPARA_02:CCGGGTCATTGGGGTCAGG;120:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;146:V_HNF6_Q6:CAAAATCAATAA_Reversed:.hg18.51.+
# add > to Smith:HepG2Negative-4.C:SLEA_hg18:chr2:210861483-210861650|103:V_HNF4_Q6:AAGGTCCAG;155:V_HNF4_Q6:AAGGTCCAG.hg18.42.+
# add > to Smith:HepG2Negative-5.C:SLEA_hg18:chr2:210861483-210861650|103:V_HNF4_Q6:AAGGTCCAG;155:V_HNF4_Q6:AAGGTCCAG_Reversed:.hg18.42.+
# add > to Smith:HepG2Negative-6.C:SLEA_hg18:chr2:210861483-210861650|103:V_HNF6_Q6:CAAAATCAATAA;155:V_HNF6_Q6:CAAAATCAATAA.hg18.37.+
# add > to Smith:HepG2Negative-7.C:SLEA_hg18:chr2:210861483-210861650|103:V_HNF6_Q6:CAAAATCAATAA;155:V_HNF6_Q6:CAAAATCAATAA_Reversed:.hg18.37.+
# add > to Smith:HepG2Negative-8.C:SLEA_hg18:chr2:210861483-210861650|113:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC.hg18.42.+
# add > to Smith:HepG2Negative-9.C:SLEA_hg18:chr2:210861483-210861650|113:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC_Reversed:.hg18.42.+
# add > to Smith:HepG2Negative-10.C:SLEA_hg18:chr2:210861483-210861650|113:V_HNF1_C:AGTTAATGATTAACCAA.hg18.36.+
# add > to Smith:HepG2Negative-11.C:SLEA_hg18:chr2:210861483-210861650|113:V_HNF1_C:AGTTAATGATTAACCAA_Reversed:.hg18.36.+
# add > to Smith:HepG2Negative-12.C:SLEA_hg18:chr2:210861483-210861650|15:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;134:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC.hg18.48.+
# add > to Smith:HepG2Negative-13.C:SLEA_hg18:chr2:210861483-210861650|15:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;134:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC_Reversed:.hg18.48.+
# add > to Smith:HepG2Negative-14.C:SLEA_hg18:chr2:210861483-210861650|16:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;55:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;94:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;133:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC.hg18.58.+
# add > to Smith:HepG2Negative-15.C:SLEA_hg18:chr2:210861483-210861650|16:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;55:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;94:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;133:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC_Reversed:.hg18.58.+
# add > to Smith:HepG2Negative-16.C:SLEA_hg18:chr2:210861483-210861650|17:V_XBP1_01:GTGATGACGTGTCCCAT;37:V_PPARA_02:CCGGGTCATTGGGGTCAGG;59:V_HNF6_Q6:CAAAATCAATAA;74:V_Rxra_UP:GGCCGTGACCCCGTGAT;94:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;116:V_HNF4_Q6:AAGGTCCAG;128:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC.hg18.54.+
# add > to Smith:HepG2Negative-17.C:SLEA_hg18:chr2:210861483-210861650|17:V_XBP1_01:GTGATGACGTGTCCCAT;37:V_PPARA_02:CCGGGTCATTGGGGTCAGG;59:V_HNF6_Q6:CAAAATCAATAA;74:V_Rxra_UP:GGCCGTGACCCCGTGAT;94:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;116:V_HNF4_Q6:AAGGTCCAG;128:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC_Reversed:.hg18.54.+
# add > to Smith:HepG2Negative-18.C:SLEA_hg18:chr2:210861483-210861650|18:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;83:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC.hg18.46.+
# add > to Smith:HepG2Negative-19.C:SLEA_hg18:chr2:210861483-210861650|18:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;83:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC_Reversed:.hg18.46.+
# add > to Smith:HepG2Negative-20.C:SLEA_hg18:chr2:210861483-210861650|18:V_GATA4_Q3:AGATAACAGGGA;83:V_GATA4_Q3:AGATAACAGGGA.hg18.40.+
# add > to Smith:HepG2Negative-21.C:SLEA_hg18:chr2:210861483-210861650|18:V_GATA4_Q3:AGATAACAGGGA;83:V_GATA4_Q3:AGATAACAGGGA_Reversed:.hg18.40.+
# add > to Smith:HepG2Negative-22.C:SLEA_hg18:chr2:210861483-210861650|19:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;62:V_HNF6_Q6:CAAAATCAATAA;94:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;137:V_HNF6_Q6:CAAAATCAATAA.hg18.46.+
# add > to Smith:HepG2Negative-23.C:SLEA_hg18:chr2:210861483-210861650|19:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;62:V_HNF6_Q6:CAAAATCAATAA;94:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;137:V_HNF6_Q6:CAAAATCAATAA_Reversed:.hg18.46.+
# add > to Smith:HepG2Negative-24.C:SLEA_hg18:chr2:210861483-210861650|20:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;53:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;75:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;120:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC.hg18.54.+
# add > to Smith:HepG2Negative-25.C:SLEA_hg18:chr2:210861483-210861650|20:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;53:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;75:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;120:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC_Reversed:.hg18.54.+
# add > to Smith:HepG2Negative-26.C:SLEA_hg18:chr2:210861483-210861650|20:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;46:V_HNF6_Q6:CAAAATCAATAA;61:V_XBP1_01:GTGATGACGTGTCCCAT;81:V_PPARA_02:CCGGGTCATTGGGGTCAGG;103:V_HNF4_Q6:AAGGTCCAG;115:V_HNF3ALPHA_Q6:TGTTTGCTTTG;129:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC.hg18.53.+
# add > to Smith:HepG2Negative-27.C:SLEA_hg18:chr2:210861483-210861650|20:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;46:V_HNF6_Q6:CAAAATCAATAA;61:V_XBP1_01:GTGATGACGTGTCCCAT;81:V_PPARA_02:CCGGGTCATTGGGGTCAGG;103:V_HNF4_Q6:AAGGTCCAG;115:V_HNF3ALPHA_Q6:TGTTTGCTTTG;129:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC_Reversed:.hg18.53.+
# add > to Smith:HepG2Negative-28.C:SLEA_hg18:chr2:210861483-210861650|20:V_HNF6_Q6:CAAAATCAATAA;35:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;61:V_HNF4_Q6:AAGGTCCAG;73:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;95:V_Rxra_UP:GGCCGTGACCCCGTGAT;115:V_HNF3ALPHA_Q6:TGTTTGCTTTG;129:V_PPARA_02:CCGGGTCATTGGGGTCAGG.hg18.53.+
# add > to Smith:HepG2Negative-29.C:SLEA_hg18:chr2:210861483-210861650|20:V_HNF6_Q6:CAAAATCAATAA;35:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;61:V_HNF4_Q6:AAGGTCCAG;73:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;95:V_Rxra_UP:GGCCGTGACCCCGTGAT;115:V_HNF3ALPHA_Q6:TGTTTGCTTTG;129:V_PPARA_02:CCGGGTCATTGGGGTCAGG_Reversed:.hg18.53.+
# add > to Smith:HepG2Negative-30.C:SLEA_hg18:chr2:210861483-210861650|21:V_HNF3ALPHA_Q6:TGTTTGCTTTG;34:V_HNF3ALPHA_Q6:TGTTTGCTTTG;47:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;68:V_HNF3ALPHA_Q6:TGTTTGCTTTG;81:V_HNF3ALPHA_Q6:TGTTTGCTTTG;94:V_HNF3ALPHA_Q6:TGTTTGCTTTG;107:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;128:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC.hg18.52.+
# add > to Smith:HepG2Negative-31.C:SLEA_hg18:chr2:210861483-210861650|21:V_HNF3ALPHA_Q6:TGTTTGCTTTG;34:V_HNF3ALPHA_Q6:TGTTTGCTTTG;47:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;68:V_HNF3ALPHA_Q6:TGTTTGCTTTG;81:V_HNF3ALPHA_Q6:TGTTTGCTTTG;94:V_HNF3ALPHA_Q6:TGTTTGCTTTG;107:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;128:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC_Reversed:.hg18.52.+
# add > to Smith:HepG2Negative-32.C:SLEA_hg18:chr2:210861483-210861650|22:V_Rxra_UP:GGCCGTGACCCCGTGAT;43:V_Rxra_UP:GGCCGTGACCCCGTGAT;64:V_Rxra_UP:GGCCGTGACCCCGTGAT;85:V_AP2GAMMA_01:GCCCGGGGG;98:V_AP2GAMMA_01:GCCCGGGGG;111:V_AP2GAMMA_01:GCCCGGGGG;124:V_AP2GAMMA_01:GCCCGGGGG;137:V_AP2GAMMA_01:GCCCGGGGG.hg18.62.+
# add > to Smith:HepG2Negative-33.C:SLEA_hg18:chr2:210861483-210861650|22:V_Rxra_UP:GGCCGTGACCCCGTGAT;43:V_Rxra_UP:GGCCGTGACCCCGTGAT;64:V_Rxra_UP:GGCCGTGACCCCGTGAT;85:V_AP2GAMMA_01:GCCCGGGGG;98:V_AP2GAMMA_01:GCCCGGGGG;111:V_AP2GAMMA_01:GCCCGGGGG;124:V_AP2GAMMA_01:GCCCGGGGG;137:V_AP2GAMMA_01:GCCCGGGGG_Reversed:.hg18.62.+
# add > to Smith:HepG2Negative-34.C:SLEA_hg18:chr2:210861483-210861650|24:V_HNF3ALPHA_Q6:TGTTTGCTTTG;55:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;94:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;133:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.50.+
# add > to Smith:HepG2Negative-35.C:SLEA_hg18:chr2:210861483-210861650|24:V_HNF3ALPHA_Q6:TGTTTGCTTTG;55:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;94:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;133:V_HNF3ALPHA_Q6:TGTTTGCTTTG_Reversed:.hg18.50.+
# add > to Smith:HepG2Negative-36.C:SLEA_hg18:chr2:210861483-210861650|24:V_PPARA_02:CCGGGTCATTGGGGTCAGG;63:V_PPARA_02:CCGGGTCATTGGGGTCAGG;102:V_HNF3ALPHA_Q6:TGTTTGCTTTG;133:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.47.+
# add > to Smith:HepG2Negative-37.C:SLEA_hg18:chr2:210861483-210861650|24:V_PPARA_02:CCGGGTCATTGGGGTCAGG;63:V_PPARA_02:CCGGGTCATTGGGGTCAGG;102:V_HNF3ALPHA_Q6:TGTTTGCTTTG;133:V_HNF3ALPHA_Q6:TGTTTGCTTTG_Reversed:.hg18.47.+
# add > to Smith:HepG2Negative-38.C:SLEA_hg18:chr2:210861483-210861650|25:V_PPARA_02:CCGGGTCATTGGGGTCAGG;46:V_HNF3ALPHA_Q6:TGTTTGCTTTG;59:V_HNF3ALPHA_Q6:TGTTTGCTTTG;72:V_PPARA_02:CCGGGTCATTGGGGTCAGG;93:V_HNF3ALPHA_Q6:TGTTTGCTTTG;106:V_HNF3ALPHA_Q6:TGTTTGCTTTG;119:V_HNF3ALPHA_Q6:TGTTTGCTTTG;132:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.44.+
# add > to Smith:HepG2Negative-39.C:SLEA_hg18:chr2:210861483-210861650|25:V_PPARA_02:CCGGGTCATTGGGGTCAGG;46:V_HNF3ALPHA_Q6:TGTTTGCTTTG;59:V_HNF3ALPHA_Q6:TGTTTGCTTTG;72:V_PPARA_02:CCGGGTCATTGGGGTCAGG;93:V_HNF3ALPHA_Q6:TGTTTGCTTTG;106:V_HNF3ALPHA_Q6:TGTTTGCTTTG;119:V_HNF3ALPHA_Q6:TGTTTGCTTTG;132:V_HNF3ALPHA_Q6:TGTTTGCTTTG_Reversed:.hg18.44.+
# add > to Smith:HepG2Negative-40.C:SLEA_hg18:chr2:210861483-210861650|27:V_HNF4_Q6:AAGGTCCAG;144:V_HNF4_Q6:AAGGTCCAG.hg18.40.+
# add > to Smith:HepG2Negative-41.C:SLEA_hg18:chr2:210861483-210861650|27:V_HNF4_Q6:AAGGTCCAG;144:V_HNF4_Q6:AAGGTCCAG_Reversed:.hg18.40.+
# add > to Smith:HepG2Negative-42.C:SLEA_hg18:chr2:210861483-210861650|27:V_HNF6_Q6:CAAAATCAATAA;144:V_HNF6_Q6:CAAAATCAATAA.hg18.35.+
# add > to Smith:HepG2Negative-43.C:SLEA_hg18:chr2:210861483-210861650|27:V_HNF6_Q6:CAAAATCAATAA;144:V_HNF6_Q6:CAAAATCAATAA_Reversed:.hg18.35.+
# add > to Smith:HepG2Negative-44.C:SLEA_hg18:chr2:210861483-210861650|28:V_AP2GAMMA_01:GCCCGGGGG;57:V_AP2GAMMA_01:GCCCGGGGG;86:V_Rxra_UP:GGCCGTGACCCCGTGAT;123:V_Rxra_UP:GGCCGTGACCCCGTGAT.hg18.49.+
# add > to Smith:HepG2Negative-45.C:SLEA_hg18:chr2:210861483-210861650|28:V_AP2GAMMA_01:GCCCGGGGG;57:V_AP2GAMMA_01:GCCCGGGGG;86:V_Rxra_UP:GGCCGTGACCCCGTGAT;123:V_Rxra_UP:GGCCGTGACCCCGTGAT_Reversed:.hg18.49.+
# add > to Smith:HepG2Negative-46.C:SLEA_hg18:chr2:210861483-210861650|28:V_GATA4_Q3:AGATAACAGGGA;60:V_GATA4_Q3:AGATAACAGGGA;92:V_XBP1_01:GTGATGACGTGTCCCAT;129:V_GATA4_Q3:AGATAACAGGGA.hg18.41.+
# add > to Smith:HepG2Negative-47.C:SLEA_hg18:chr2:210861483-210861650|28:V_GATA4_Q3:AGATAACAGGGA;60:V_GATA4_Q3:AGATAACAGGGA;92:V_XBP1_01:GTGATGACGTGTCCCAT;129:V_GATA4_Q3:AGATAACAGGGA_Reversed:.hg18.41.+
# add > to Smith:HepG2Negative-48.C:SLEA_hg18:chr2:210861483-210861650|28:V_Rxra_UP:GGCCGTGACCCCGTGAT;65:V_AP2GAMMA_01:GCCCGGGGG;94:V_AP2GAMMA_01:GCCCGGGGG;123:V_Rxra_UP:GGCCGTGACCCCGTGAT.hg18.48.+
# add > to Smith:HepG2Negative-49.C:SLEA_hg18:chr2:210861483-210861650|28:V_Rxra_UP:GGCCGTGACCCCGTGAT;65:V_AP2GAMMA_01:GCCCGGGGG;94:V_AP2GAMMA_01:GCCCGGGGG;123:V_Rxra_UP:GGCCGTGACCCCGTGAT_Reversed:.hg18.48.+
# add > to Smith:HepG2Negative-50.C:SLEA_hg18:chr2:210861483-210861650|34:V_Rxra_UP:GGCCGTGACCCCGTGAT;54:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;80:V_PPARA_02:CCGGGTCATTGGGGTCAGG;102:V_HNF6_Q6:CAAAATCAATAA;117:V_XBP1_01:GTGATGACGTGTCCCAT.hg18.47.+
# add > to Smith:HepG2Negative-51.C:SLEA_hg18:chr2:210861483-210861650|34:V_Rxra_UP:GGCCGTGACCCCGTGAT;54:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;80:V_PPARA_02:CCGGGTCATTGGGGTCAGG;102:V_HNF6_Q6:CAAAATCAATAA;117:V_XBP1_01:GTGATGACGTGTCCCAT_Reversed:.hg18.47.+
# add > to Smith:HepG2Negative-52.C:SLEA_hg18:chr2:210861483-210861650|36:V_HNF6_Q6:CAAAATCAATAA;48:V_HNF6_Q6:CAAAATCAATAA;60:V_HNF6_Q6:CAAAATCAATAA;72:V_HNF6_Q6:CAAAATCAATAA;84:V_HNF6_Q6:CAAAATCAATAA;96:V_HNF6_Q6:CAAAATCAATAA;108:V_HNF6_Q6:CAAAATCAATAA;120:V_HNF6_Q6:CAAAATCAATAA.hg18.27.+
# add > to Smith:HepG2Negative-53.C:SLEA_hg18:chr2:210861483-210861650|36:V_HNF6_Q6:CAAAATCAATAA;48:V_HNF6_Q6:CAAAATCAATAA;60:V_HNF6_Q6:CAAAATCAATAA;72:V_HNF6_Q6:CAAAATCAATAA;84:V_HNF6_Q6:CAAAATCAATAA;96:V_HNF6_Q6:CAAAATCAATAA;108:V_HNF6_Q6:CAAAATCAATAA;120:V_HNF6_Q6:CAAAATCAATAA_Reversed:.hg18.27.+
# add > to Smith:HepG2Negative-54.C:SLEA_hg18:chr2:210861483-210861650|41:V_HNF3ALPHA_Q6:TGTTTGCTTTG;135:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.38.+
# add > to Smith:HepG2Negative-55.C:SLEA_hg18:chr2:210861483-210861650|41:V_HNF3ALPHA_Q6:TGTTTGCTTTG;135:V_HNF3ALPHA_Q6:TGTTTGCTTTG_Reversed:.hg18.38.+
# add > to Smith:HepG2Negative-56.C:SLEA_hg18:chr2:210861483-210861650|44:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;70:V_PPARA_02:CCGGGTCATTGGGGTCAGG;92:V_Rxra_UP:GGCCGTGACCCCGTGAT;112:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.47.+
# add > to Smith:HepG2Negative-57.C:SLEA_hg18:chr2:210861483-210861650|44:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;70:V_PPARA_02:CCGGGTCATTGGGGTCAGG;92:V_Rxra_UP:GGCCGTGACCCCGTGAT;112:V_HNF3ALPHA_Q6:TGTTTGCTTTG_Reversed:.hg18.47.+
# add > to Smith:HepG2Negative-58.C:SLEA_hg18:chr2:210861483-210861650|45:V_Rxra_UP:GGCCGTGACCCCGTGAT;67:V_HNF3ALPHA_Q6:TGTTTGCTTTG;83:V_Rxra_UP:GGCCGTGACCCCGTGAT;105:V_Rxra_UP:GGCCGTGACCCCGTGAT.hg18.48.+
# add > to Smith:HepG2Negative-59.C:SLEA_hg18:chr2:210861483-210861650|45:V_Rxra_UP:GGCCGTGACCCCGTGAT;67:V_HNF3ALPHA_Q6:TGTTTGCTTTG;83:V_Rxra_UP:GGCCGTGACCCCGTGAT;105:V_Rxra_UP:GGCCGTGACCCCGTGAT_Reversed:.hg18.48.+
# add > to Smith:HepG2Negative-60.C:SLEA_hg18:chr2:210861483-210861650|46:V_PPARA_02:CCGGGTCATTGGGGTCAGG;70:V_HNF6_Q6:CAAAATCAATAA;87:V_PPARA_02:CCGGGTCATTGGGGTCAGG;111:V_HNF6_Q6:CAAAATCAATAA.hg18.42.+
# add > to Smith:HepG2Negative-61.C:SLEA_hg18:chr2:210861483-210861650|46:V_PPARA_02:CCGGGTCATTGGGGTCAGG;70:V_HNF6_Q6:CAAAATCAATAA;87:V_PPARA_02:CCGGGTCATTGGGGTCAGG;111:V_HNF6_Q6:CAAAATCAATAA_Reversed:.hg18.42.+
# add > to Smith:HepG2Negative-62.C:SLEA_hg18:chr2:210861483-210861650|47:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;71:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;95:V_HNF3ALPHA_Q6:TGTTTGCTTTG;111:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.46.+
# add > to Smith:HepG2Negative-63.C:SLEA_hg18:chr2:210861483-210861650|47:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;71:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;95:V_HNF3ALPHA_Q6:TGTTTGCTTTG;111:V_HNF3ALPHA_Q6:TGTTTGCTTTG_Reversed:.hg18.46.+
# add > to Smith:HepG2Negative-64.C:SLEA_hg18:chr2:210861483-210861650|47:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;75:V_HNF6_Q6:CAAAATCAATAA;92:V_HNF6_Q6:CAAAATCAATAA;109:V_HNF6_Q6:CAAAATCAATAA.hg18.38.+
# add > to Smith:HepG2Negative-65.C:SLEA_hg18:chr2:210861483-210861650|47:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;75:V_HNF6_Q6:CAAAATCAATAA;92:V_HNF6_Q6:CAAAATCAATAA;109:V_HNF6_Q6:CAAAATCAATAA_Reversed:.hg18.38.+
# add > to Smith:HepG2Negative-66.C:SLEA_hg18:chr2:210861483-210861650|47:V_HNF6_Q6:CAAAATCAATAA;64:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;92:V_HNF6_Q6:CAAAATCAATAA;109:V_HNF6_Q6:CAAAATCAATAA.hg18.39.+
# add > to Smith:HepG2Negative-67.C:SLEA_hg18:chr2:210861483-210861650|47:V_HNF6_Q6:CAAAATCAATAA;64:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;92:V_HNF6_Q6:CAAAATCAATAA;109:V_HNF6_Q6:CAAAATCAATAA_Reversed:.hg18.39.+
# add > to Smith:HepG2Negative-68.C:SLEA_hg18:chr2:210861483-210861650|48:V_HNF3ALPHA_Q6:TGTTTGCTTTG;69:V_HNF3ALPHA_Q6:TGTTTGCTTTG;90:V_HNF3ALPHA_Q6:TGTTTGCTTTG;111:V_HNF4_Q6:AAGGTCCAG.hg18.40.+
# add > to Smith:HepG2Negative-69.C:SLEA_hg18:chr2:210861483-210861650|48:V_HNF3ALPHA_Q6:TGTTTGCTTTG;69:V_HNF3ALPHA_Q6:TGTTTGCTTTG;90:V_HNF3ALPHA_Q6:TGTTTGCTTTG;111:V_HNF4_Q6:AAGGTCCAG_Reversed:.hg18.40.+
# add > to Smith:HepG2Negative-70.C:SLEA_hg18:chr2:210861483-210861650|49:V_HNF4_Q6:AAGGTCCAG;68:V_HNF3ALPHA_Q6:TGTTTGCTTTG;89:V_HNF3ALPHA_Q6:TGTTTGCTTTG;110:V_HNF4_Q6:AAGGTCCAG.hg18.40.+
# add > to Smith:HepG2Negative-71.C:SLEA_hg18:chr2:210861483-210861650|49:V_HNF4_Q6:AAGGTCCAG;68:V_HNF3ALPHA_Q6:TGTTTGCTTTG;89:V_HNF3ALPHA_Q6:TGTTTGCTTTG;110:V_HNF4_Q6:AAGGTCCAG_Reversed:.hg18.40.+
# add > to Smith:HepG2Negative-72.C:SLEA_hg18:chr2:210861483-210861650|50:V_AP2GAMMA_01:GCCCGGGGG;64:V_Rxra_UP:GGCCGTGACCCCGTGAT;86:V_AP2GAMMA_01:GCCCGGGGG;100:V_Rxra_UP:GGCCGTGACCCCGTGAT.hg18.50.+
# add > to Smith:HepG2Negative-73.C:SLEA_hg18:chr2:210861483-210861650|50:V_AP2GAMMA_01:GCCCGGGGG;64:V_Rxra_UP:GGCCGTGACCCCGTGAT;86:V_AP2GAMMA_01:GCCCGGGGG;100:V_Rxra_UP:GGCCGTGACCCCGTGAT_Reversed:.hg18.50.+
# add > to Smith:HepG2Negative-74.C:SLEA_hg18:chr2:210861483-210861650|51:V_AP2GAMMA_01:GCCCGGGGG;65:V_AP2GAMMA_01:GCCCGGGGG;79:V_Rxra_UP:GGCCGTGACCCCGTGAT;101:V_Rxra_UP:GGCCGTGACCCCGTGAT.hg18.51.+
# add > to Smith:HepG2Negative-75.C:SLEA_hg18:chr2:210861483-210861650|51:V_AP2GAMMA_01:GCCCGGGGG;65:V_AP2GAMMA_01:GCCCGGGGG;79:V_Rxra_UP:GGCCGTGACCCCGTGAT;101:V_Rxra_UP:GGCCGTGACCCCGTGAT_Reversed:.hg18.51.+
# add > to Smith:HepG2Negative-76.C:SLEA_hg18:chr2:210861483-210861650|53:V_CEBP_Q2_01:ATTGCACAATCC;70:V_CEBP_Q2_01:ATTGCACAATCC;87:V_HNF6_Q6:CAAAATCAATAA;104:V_CEBP_Q2_01:ATTGCACAATCC.hg18.40.+
# add > to Smith:HepG2Negative-77.C:SLEA_hg18:chr2:210861483-210861650|53:V_CEBP_Q2_01:ATTGCACAATCC;70:V_CEBP_Q2_01:ATTGCACAATCC;87:V_HNF6_Q6:CAAAATCAATAA;104:V_CEBP_Q2_01:ATTGCACAATCC_Reversed:.hg18.40.+
# add > to Smith:HepG2Negative-78.C:SLEA_hg18:chr2:210861483-210861650|54:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;76:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;102:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.48.+
# add > to Smith:HepG2Negative-79.C:SLEA_hg18:chr2:210861483-210861650|54:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;76:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;102:V_HNF3ALPHA_Q6:TGTTTGCTTTG_Reversed:.hg18.48.+
# add > to Smith:HepG2Negative-80.C:SLEA_hg18:chr2:210861483-210861650|56:V_HNF3ALPHA_Q6:TGTTTGCTTTG;70:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;96:V_XBP1_01:GTGATGACGTGTCCCAT.hg18.46.+
# add > to Smith:HepG2Negative-81.C:SLEA_hg18:chr2:210861483-210861650|56:V_HNF3ALPHA_Q6:TGTTTGCTTTG;70:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;96:V_XBP1_01:GTGATGACGTGTCCCAT_Reversed:.hg18.46.+
# add > to Smith:HepG2Negative-82.C:SLEA_hg18:chr2:210861483-210861650|56:V_HNF6_Q6:CAAAATCAATAA;88:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC.hg18.43.+
# add > to Smith:HepG2Negative-83.C:SLEA_hg18:chr2:210861483-210861650|56:V_HNF6_Q6:CAAAATCAATAA;88:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC_Reversed:.hg18.43.+
# add > to Smith:HepG2Negative-84.C:SLEA_hg18:chr2:210861483-210861650|57:V_HNF3ALPHA_Q6:TGTTTGCTTTG;88:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC.hg18.44.+
# add > to Smith:HepG2Negative-85.C:SLEA_hg18:chr2:210861483-210861650|57:V_HNF3ALPHA_Q6:TGTTTGCTTTG;88:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC_Reversed:.hg18.44.+
# add > to Smith:HepG2Negative-86.C:SLEA_hg18:chr2:210861483-210861650|57:V_HNF4_Q6:AAGGTCCAG;69:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;91:V_PPARA_02:CCGGGTCATTGGGGTCAGG.hg18.47.+
# add > to Smith:HepG2Negative-87.C:SLEA_hg18:chr2:210861483-210861650|57:V_HNF4_Q6:AAGGTCCAG;69:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;91:V_PPARA_02:CCGGGTCATTGGGGTCAGG_Reversed:.hg18.47.+
# add > to Smith:HepG2Negative-88.C:SLEA_hg18:chr2:210861483-210861650|58:V_HNF3ALPHA_Q6:TGTTTGCTTTG;72:V_Rxra_UP:GGCCGTGACCCCGTGAT;92:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC.hg18.45.+
# add > to Smith:HepG2Negative-89.C:SLEA_hg18:chr2:210861483-210861650|58:V_HNF3ALPHA_Q6:TGTTTGCTTTG;72:V_Rxra_UP:GGCCGTGACCCCGTGAT;92:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC_Reversed:.hg18.45.+
# add > to Smith:HepG2Negative-90.C:SLEA_hg18:chr2:210861483-210861650|59:V_HNF4_Q6:AAGGTCCAG;71:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;97:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.43.+
# add > to Smith:HepG2Negative-91.C:SLEA_hg18:chr2:210861483-210861650|59:V_HNF4_Q6:AAGGTCCAG;71:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;97:V_HNF3ALPHA_Q6:TGTTTGCTTTG_Reversed:.hg18.43.+
# add > to Smith:HepG2Negative-92.C:SLEA_hg18:chr2:210861483-210861650|6:V_AP2GAMMA_01:GCCCGGGGG;105:V_AP2GAMMA_01:GCCCGGGGG;118:V_AP2GAMMA_01:GCCCGGGGG;146:V_AP2GAMMA_01:GCCCGGGGG.hg18.48.+
# add > to Smith:HepG2Negative-93.C:SLEA_hg18:chr2:210861483-210861650|6:V_AP2GAMMA_01:GCCCGGGGG;105:V_AP2GAMMA_01:GCCCGGGGG;118:V_AP2GAMMA_01:GCCCGGGGG;146:V_AP2GAMMA_01:GCCCGGGGG_Reversed:.hg18.48.+
# add > to Smith:HepG2Negative-94.C:SLEA_hg18:chr2:210861483-210861650|62:V_HNF3ALPHA_Q6:TGTTTGCTTTG;73:V_HNF3ALPHA_Q6:TGTTTGCTTTG;84:V_HNF3ALPHA_Q6:TGTTTGCTTTG;95:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.37.+
# add > to Smith:HepG2Negative-95.C:SLEA_hg18:chr2:210861483-210861650|62:V_HNF3ALPHA_Q6:TGTTTGCTTTG;73:V_HNF3ALPHA_Q6:TGTTTGCTTTG;84:V_HNF3ALPHA_Q6:TGTTTGCTTTG;95:V_HNF3ALPHA_Q6:TGTTTGCTTTG_Reversed:.hg18.37.+
# add > to Smith:HepG2Negative-96.C:SLEA_hg18:chr2:210861483-210861650|63:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;87:V_HNF1_C:AGTTAATGATTAACCAA.hg18.40.+
# add > to Smith:HepG2Negative-97.C:SLEA_hg18:chr2:210861483-210861650|63:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;87:V_HNF1_C:AGTTAATGATTAACCAA_Reversed:.hg18.40.+
# add > to Smith:HepG2Negative-98.C:SLEA_hg18:chr2:210861483-210861650|64:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;92:V_HNF6_Q6:CAAAATCAATAA.hg18.40.+
# add > to Smith:HepG2Negative-99.C:SLEA_hg18:chr2:210861483-210861650|64:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;92:V_HNF6_Q6:CAAAATCAATAA_Reversed:.hg18.40.+
# add > to Smith:HepG2Negative-100.C:SLEA_hg18:chr2:210861483-210861650|64:V_HNF3ALPHA_Q6:TGTTTGCTTTG;95:V_HNF4_Q6:AAGGTCCAG.hg18.38.+
# add > to Smith:HepG2Negative-101.C:SLEA_hg18:chr2:210861483-210861650|64:V_HNF3ALPHA_Q6:TGTTTGCTTTG;95:V_HNF4_Q6:AAGGTCCAG_Reversed:.hg18.38.+
# add > to Smith:HepG2Negative-102.C:SLEA_hg18:chr2:210861483-210861650|65:V_XBP1_01:GTGATGACGTGTCCCAT;86:V_Rxra_UP:GGCCGTGACCCCGTGAT.hg18.41.+
# add > to Smith:HepG2Negative-103.C:SLEA_hg18:chr2:210861483-210861650|65:V_XBP1_01:GTGATGACGTGTCCCAT;86:V_Rxra_UP:GGCCGTGACCCCGTGAT_Reversed:.hg18.41.+
# add > to Smith:HepG2Negative-104.C:SLEA_hg18:chr2:210861483-210861650|66:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;90:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.42.+
# add > to Smith:HepG2Negative-105.C:SLEA_hg18:chr2:210861483-210861650|66:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;90:V_HNF3ALPHA_Q6:TGTTTGCTTTG_Reversed:.hg18.42.+
# add > to Smith:HepG2Negative-106.C:SLEA_hg18:chr2:210861483-210861650|66:V_HNF4_Q6:AAGGTCCAG;75:V_HNF4_Q6:AAGGTCCAG;84:V_HNF4_Q6:AAGGTCCAG;93:V_HNF4_Q6:AAGGTCCAG.hg18.40.+
# add > to Smith:HepG2Negative-107.C:SLEA_hg18:chr2:210861483-210861650|66:V_HNF4_Q6:AAGGTCCAG;75:V_HNF4_Q6:AAGGTCCAG;84:V_HNF4_Q6:AAGGTCCAG;93:V_HNF4_Q6:AAGGTCCAG_Reversed:.hg18.40.+
# add > to Smith:HepG2Negative-108.C:SLEA_hg18:chr2:210861483-210861650|67:V_CEBP_Q2_01:ATTGCACAATCC;84:V_XBP1_01:GTGATGACGTGTCCCAT.hg18.39.+
# add > to Smith:HepG2Negative-109.C:SLEA_hg18:chr2:210861483-210861650|67:V_CEBP_Q2_01:ATTGCACAATCC;84:V_XBP1_01:GTGATGACGTGTCCCAT_Reversed:.hg18.39.+
# add > to Smith:HepG2Negative-110.C:SLEA_hg18:chr2:210861483-210861650|67:V_PPARA_02:CCGGGTCATTGGGGTCAGG;88:V_HNF6_Q6:CAAAATCAATAA.hg18.40.+
# add > to Smith:HepG2Negative-111.C:SLEA_hg18:chr2:210861483-210861650|67:V_PPARA_02:CCGGGTCATTGGGGTCAGG;88:V_HNF6_Q6:CAAAATCAATAA_Reversed:.hg18.40.+
# add > to Smith:HepG2Negative-112.C:SLEA_hg18:chr2:210861483-210861650|69:V_AP2GAMMA_01:GCCCGGGGG;82:V_XBP1_01:GTGATGACGTGTCCCAT.hg18.42.+
# add > to Smith:HepG2Negative-113.C:SLEA_hg18:chr2:210861483-210861650|69:V_AP2GAMMA_01:GCCCGGGGG;82:V_XBP1_01:GTGATGACGTGTCCCAT_Reversed:.hg18.42.+
# add > to Smith:HepG2Negative-114.C:SLEA_hg18:chr2:210861483-210861650|71:V_HNF4_Q6:AAGGTCCAG;85:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.39.+
# add > to Smith:HepG2Negative-115.C:SLEA_hg18:chr2:210861483-210861650|71:V_HNF4_Q6:AAGGTCCAG;85:V_HNF3ALPHA_Q6:TGTTTGCTTTG_Reversed:.hg18.39.+
# add > to Smith:HepG2Negative-116.C:SLEA_hg18:chr2:210861483-210861650|73:V_AP2GAMMA_01:GCCCGGGGG;87:V_AP2GAMMA_01:GCCCGGGGG.hg18.44.+
# add > to Smith:HepG2Negative-117.C:SLEA_hg18:chr2:210861483-210861650|73:V_AP2GAMMA_01:GCCCGGGGG;87:V_AP2GAMMA_01:GCCCGGGGG_Reversed:.hg18.44.+
# add > to Smith:HepG2Negative-118.C:SLEA_hg18:chr2:210861483-210861650|73:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC.hg18.42.+
# add > to Smith:HepG2Negative-119.C:SLEA_hg18:chr2:210861483-210861650|73:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC_Reversed:.hg18.42.+
# add > to Smith:HepG2Negative-120.C:SLEA_hg18:chr9:82902419-82902586|10:V_HNF1_C:AGTTAATGATTAACCAA;30:V_Rxra_UP:GGCCGTGACCCCGTGAT;50:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;76:V_PPARA_02:CCGGGTCATTGGGGTCAGG;98:V_HNF4_Q6:AAGGTCCAG;110:V_HNF3ALPHA_Q6:TGTTTGCTTTG;124:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;146:V_HNF6_Q6:CAAAATCAATAA.hg18.53.+
# add > to Smith:HepG2Negative-121.C:SLEA_hg18:chr9:82902419-82902586|10:V_HNF1_C:AGTTAATGATTAACCAA;30:V_Rxra_UP:GGCCGTGACCCCGTGAT;50:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;76:V_PPARA_02:CCGGGTCATTGGGGTCAGG;98:V_HNF4_Q6:AAGGTCCAG;110:V_HNF3ALPHA_Q6:TGTTTGCTTTG;124:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;146:V_HNF6_Q6:CAAAATCAATAA_Reversed:.hg18.53.+
# add > to Smith:HepG2Negative-122.C:SLEA_hg18:chr9:82902419-82902586|103:V_PPARA_02:CCGGGTCATTGGGGTCAGG;135:V_PPARA_02:CCGGGTCATTGGGGTCAGG.hg18.48.+
# add > to Smith:HepG2Negative-123.C:SLEA_hg18:chr9:82902419-82902586|103:V_PPARA_02:CCGGGTCATTGGGGTCAGG;135:V_PPARA_02:CCGGGTCATTGGGGTCAGG_Reversed:.hg18.48.+
# add > to Smith:HepG2Negative-124.C:SLEA_hg18:chr9:82902419-82902586|12:V_HNF4_Q6:AAGGTCCAG;31:V_HNF4_Q6:AAGGTCCAG;50:V_HNF4_Q6:AAGGTCCAG;69:V_HNF4_Q6:AAGGTCCAG;88:V_HNF4_Q6:AAGGTCCAG;107:V_HNF4_Q6:AAGGTCCAG;126:V_HNF3ALPHA_Q6:TGTTTGCTTTG;147:V_HNF4_Q6:AAGGTCCAG.hg18.46.+
# add > to Smith:HepG2Negative-125.C:SLEA_hg18:chr9:82902419-82902586|12:V_HNF4_Q6:AAGGTCCAG;31:V_HNF4_Q6:AAGGTCCAG;50:V_HNF4_Q6:AAGGTCCAG;69:V_HNF4_Q6:AAGGTCCAG;88:V_HNF4_Q6:AAGGTCCAG;107:V_HNF4_Q6:AAGGTCCAG;126:V_HNF3ALPHA_Q6:TGTTTGCTTTG;147:V_HNF4_Q6:AAGGTCCAG_Reversed:.hg18.46.+
# add > to Smith:HepG2Negative-126.C:SLEA_hg18:chr9:82902419-82902586|13:V_HNF3ALPHA_Q6:TGTTTGCTTTG;27:V_XBP1_01:GTGATGACGTGTCCCAT;47:V_Rxra_UP:GGCCGTGACCCCGTGAT;67:V_PPARA_02:CCGGGTCATTGGGGTCAGG;89:V_HNF1_C:AGTTAATGATTAACCAA;109:V_HNF6_Q6:CAAAATCAATAA;124:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;146:V_HNF4_Q6:AAGGTCCAG.hg18.51.+
# add > to Smith:HepG2Negative-127.C:SLEA_hg18:chr9:82902419-82902586|13:V_HNF3ALPHA_Q6:TGTTTGCTTTG;27:V_XBP1_01:GTGATGACGTGTCCCAT;47:V_Rxra_UP:GGCCGTGACCCCGTGAT;67:V_PPARA_02:CCGGGTCATTGGGGTCAGG;89:V_HNF1_C:AGTTAATGATTAACCAA;109:V_HNF6_Q6:CAAAATCAATAA;124:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;146:V_HNF4_Q6:AAGGTCCAG_Reversed:.hg18.51.+
# add > to Smith:HepG2Negative-128.C:SLEA_hg18:chr9:82902419-82902586|17:V_PPARA_02:CCGGGTCATTGGGGTCAGG;39:V_HNF6_Q6:CAAAATCAATAA;54:V_XBP1_01:GTGATGACGTGTCCCAT;74:V_Rxra_UP:GGCCGTGACCCCGTGAT;94:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;116:V_HNF4_Q6:AAGGTCCAG;128:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC.hg18.57.+
# add > to Smith:HepG2Negative-129.C:SLEA_hg18:chr9:82902419-82902586|17:V_PPARA_02:CCGGGTCATTGGGGTCAGG;39:V_HNF6_Q6:CAAAATCAATAA;54:V_XBP1_01:GTGATGACGTGTCCCAT;74:V_Rxra_UP:GGCCGTGACCCCGTGAT;94:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;116:V_HNF4_Q6:AAGGTCCAG;128:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC_Reversed:.hg18.57.+
# add > to Smith:HepG2Negative-130.C:SLEA_hg18:chr9:82902419-82902586|2:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;26:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;50:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;74:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;98:V_HNF3ALPHA_Q6:TGTTTGCTTTG;114:V_HNF3ALPHA_Q6:TGTTTGCTTTG;130:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;154:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.59.+
# add > to Smith:HepG2Negative-131.C:SLEA_hg18:chr9:82902419-82902586|20:V_CEBP_Q2_01:ATTGCACAATCC;37:V_CEBP_Q2_01:ATTGCACAATCC;54:V_AP2GAMMA_01:GCCCGGGGG;68:V_CEBP_Q2_01:ATTGCACAATCC;85:V_CEBP_Q2_01:ATTGCACAATCC;102:V_CEBP_Q2_01:ATTGCACAATCC;119:V_CEBP_Q2_01:ATTGCACAATCC;136:V_CEBP_Q2_01:ATTGCACAATCC.hg18.46.+
# add > to Smith:HepG2Negative-132.C:SLEA_hg18:chr9:82902419-82902586|20:V_CEBP_Q2_01:ATTGCACAATCC;37:V_CEBP_Q2_01:ATTGCACAATCC;54:V_AP2GAMMA_01:GCCCGGGGG;68:V_CEBP_Q2_01:ATTGCACAATCC;85:V_CEBP_Q2_01:ATTGCACAATCC;102:V_CEBP_Q2_01:ATTGCACAATCC;119:V_CEBP_Q2_01:ATTGCACAATCC;136:V_CEBP_Q2_01:ATTGCACAATCC_Reversed:.hg18.46.+
# add > to Smith:HepG2Negative-133.C:SLEA_hg18:chr9:82902419-82902586|23:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;45:V_Rxra_UP:GGCCGTGACCCCGTGAT;65:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;91:V_PPARA_02:CCGGGTCATTGGGGTCAGG;113:V_HNF6_Q6:CAAAATCAATAA;128:V_XBP1_01:GTGATGACGTGTCCCAT.hg18.55.+
# add > to Smith:HepG2Negative-134.C:SLEA_hg18:chr9:82902419-82902586|23:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;45:V_Rxra_UP:GGCCGTGACCCCGTGAT;65:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;91:V_PPARA_02:CCGGGTCATTGGGGTCAGG;113:V_HNF6_Q6:CAAAATCAATAA;128:V_XBP1_01:GTGATGACGTGTCCCAT_Reversed:.hg18.55.+
# add > to Smith:HepG2Negative-135.C:SLEA_hg18:chr9:82902419-82902586|23:V_HNF6_Q6:CAAAATCAATAA;55:V_PPARA_02:CCGGGTCATTGGGGTCAGG;94:V_PPARA_02:CCGGGTCATTGGGGTCAGG;133:V_HNF6_Q6:CAAAATCAATAA.hg18.44.+
# add > to Smith:HepG2Negative-136.C:SLEA_hg18:chr9:82902419-82902586|23:V_HNF6_Q6:CAAAATCAATAA;55:V_PPARA_02:CCGGGTCATTGGGGTCAGG;94:V_PPARA_02:CCGGGTCATTGGGGTCAGG;133:V_HNF6_Q6:CAAAATCAATAA_Reversed:.hg18.44.+
# add > to Smith:HepG2Negative-137.C:SLEA_hg18:chr9:82902419-82902586|28:V_HNF3ALPHA_Q6:TGTTTGCTTTG;59:V_HNF3ALPHA_Q6:TGTTTGCTTTG;90:V_PPARA_02:CCGGGTCATTGGGGTCAGG;129:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.43.+
# add > to Smith:HepG2Negative-138.C:SLEA_hg18:chr9:82902419-82902586|28:V_HNF3ALPHA_Q6:TGTTTGCTTTG;59:V_HNF3ALPHA_Q6:TGTTTGCTTTG;90:V_PPARA_02:CCGGGTCATTGGGGTCAGG;129:V_HNF3ALPHA_Q6:TGTTTGCTTTG_Reversed:.hg18.43.+
# add > to Smith:HepG2Negative-139.C:SLEA_hg18:chr9:82902419-82902586|33:V_XBP1_01:GTGATGACGTGTCCCAT;55:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;83:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;111:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC.hg18.56.+
# add > to Smith:HepG2Negative-140.C:SLEA_hg18:chr9:82902419-82902586|35:V_HNF4_Q6:AAGGTCCAG;64:V_HNF4_Q6:AAGGTCCAG;93:V_HNF4_Q6:AAGGTCCAG;122:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.46.+
# add > to Smith:HepG2Negative-141.C:SLEA_hg18:chr9:82902419-82902586|35:V_XBP1_01:GTGATGACGTGTCCCAT;55:V_HNF1_C:AGTTAATGATTAACCAA;75:V_HNF4_Q6:AAGGTCCAG;87:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;113:V_PPARA_02:CCGGGTCATTGGGGTCAGG.hg18.51.+
# add > to Smith:HepG2Negative-142.C:SLEA_hg18:chr9:82902419-82902586|4:V_AP2GAMMA_01:GCCCGGGGG;16:V_AP2GAMMA_01:GCCCGGGGG;64:V_AP2GAMMA_01:GCCCGGGGG;119:V_AP2GAMMA_01:GCCCGGGGG.hg18.53.+
# add > to Smith:HepG2Negative-143.C:SLEA_hg18:chr9:82902419-82902586|4:V_HNF6_Q6:CAAAATCAATAA;25:V_HNF6_Q6:CAAAATCAATAA;46:V_HNF6_Q6:CAAAATCAATAA;67:V_CEBP_Q2_01:ATTGCACAATCC;88:V_CEBP_Q2_01:ATTGCACAATCC;109:V_HNF6_Q6:CAAAATCAATAA;130:V_CEBP_Q2_01:ATTGCACAATCC;151:V_CEBP_Q2_01:ATTGCACAATCC.hg18.34.+
# add > to Smith:HepG2Negative-144.C:SLEA_hg18:chr9:82902419-82902586|40:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;109:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC.hg18.51.+
# add > to Smith:HepG2Negative-145.C:SLEA_hg18:chr9:82902419-82902586|41:V_PPARA_02:CCGGGTCATTGGGGTCAGG;135:V_PPARA_02:CCGGGTCATTGGGGTCAGG.hg18.50.+
# add > to Smith:HepG2Negative-146.C:SLEA_hg18:chr9:82902419-82902586|42:V_PPARA_02:CCGGGTCATTGGGGTCAGG;66:V_PPARA_02:CCGGGTCATTGGGGTCAGG;90:V_PPARA_02:CCGGGTCATTGGGGTCAGG;114:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.52.+
# add > to Smith:HepG2Negative-147.C:SLEA_hg18:chr9:82902419-82902586|42:V_PPARA_02:CCGGGTCATTGGGGTCAGG;66:V_PPARA_02:CCGGGTCATTGGGGTCAGG;90:V_PPARA_02:CCGGGTCATTGGGGTCAGG;114:V_HNF6_Q6:CAAAATCAATAA.hg18.51.+
# add > to Smith:HepG2Negative-148.C:SLEA_hg18:chr9:82902419-82902586|44:V_PPARA_02:CCGGGTCATTGGGGTCAGG;66:V_HNF4_Q6:AAGGTCCAG;78:V_HNF3ALPHA_Q6:TGTTTGCTTTG;92:V_Rxra_UP:GGCCGTGACCCCGTGAT;112:V_HNF6_Q6:CAAAATCAATAA.hg18.49.+
# add > to Smith:HepG2Negative-149.C:SLEA_hg18:chr9:82902419-82902586|44:V_Rxra_UP:GGCCGTGACCCCGTGAT;64:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;90:V_PPARA_02:CCGGGTCATTGGGGTCAGG;112:V_HNF6_Q6:CAAAATCAATAA.hg18.51.+
# add > to Smith:HepG2Negative-150.C:SLEA_hg18:chr9:82902419-82902586|46:V_XBP1_01:GTGATGACGTGTCCCAT;66:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;88:V_HNF3ALPHA_Q6:TGTTTGCTTTG;102:V_PPARA_02:CCGGGTCATTGGGGTCAGG.hg18.49.+
# add > to Smith:HepG2Negative-151.C:SLEA_hg18:chr9:82902419-82902586|47:V_CEBP_Q2_01:ATTGCACAATCC;109:V_CEBP_Q2_01:ATTGCACAATCC.hg18.42.+
# add > to Smith:HepG2Negative-152.C:SLEA_hg18:chr9:82902419-82902586|48:V_HNF3ALPHA_Q6:TGTTTGCTTTG;62:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;88:V_HNF6_Q6:CAAAATCAATAA;103:V_Rxra_UP:GGCCGTGACCCCGTGAT.hg18.47.+
# add > to Smith:HepG2Negative-153.C:SLEA_hg18:chr9:82902419-82902586|49:V_HNF4_Q6:AAGGTCCAG;61:V_HNF6_Q6:CAAAATCAATAA;76:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;102:V_Rxra_UP:GGCCGTGACCCCGTGAT.hg18.48.+
# add > to Smith:HepG2Negative-154.C:SLEA_hg18:chr9:82902419-82902586|49:V_Rxra_UP:GGCCGTGACCCCGTGAT;71:V_HNF3ALPHA_Q6:TGTTTGCTTTG;87:V_HNF3ALPHA_Q6:TGTTTGCTTTG;103:V_Rxra_UP:GGCCGTGACCCCGTGAT.hg18.47.+
# add > to Smith:HepG2Negative-155.C:SLEA_hg18:chr9:82902419-82902586|50:V_GATA4_Q3:AGATAACAGGGA;67:V_GATA4_Q3:AGATAACAGGGA;84:V_XBP1_01:GTGATGACGTGTCCCAT;106:V_GATA4_Q3:AGATAACAGGGA.hg18.45.+
# add > to Smith:HepG2Negative-156.C:SLEA_hg18:chr9:82902419-82902586|50:V_HNF3ALPHA_Q6:TGTTTGCTTTG;66:V_HNF3ALPHA_Q6:TGTTTGCTTTG;82:V_HNF3ALPHA_Q6:TGTTTGCTTTG;98:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC.hg18.45.+
# add > to Smith:HepG2Negative-157.C:SLEA_hg18:chr9:82902419-82902586|50:V_PPARA_02:CCGGGTCATTGGGGTCAGG;71:V_PPARA_02:CCGGGTCATTGGGGTCAGG;92:V_HNF6_Q6:CAAAATCAATAA;106:V_HNF6_Q6:CAAAATCAATAA.hg18.47.+
# add > to Smith:HepG2Negative-158.C:SLEA_hg18:chr9:82902419-82902586|53:V_CEBP_Q2_01:ATTGCACAATCC;70:V_CEBP_Q2_01:ATTGCACAATCC;87:V_CEBP_Q2_01:ATTGCACAATCC;104:V_HNF6_Q6:CAAAATCAATAA.hg18.41.+
# add > to Smith:HepG2Negative-159.C:SLEA_hg18:chr9:82902419-82902586|56:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;95:V_HNF1_C:AGTTAATGATTAACCAA.hg18.46.+
# add > to Smith:HepG2Negative-160.C:SLEA_hg18:chr9:82902419-82902586|56:V_AP2GAMMA_01:GCCCGGGGG;70:V_AP2GAMMA_01:GCCCGGGGG;84:V_CEBP_Q2_01:ATTGCACAATCC;101:V_CEBP_Q2_01:ATTGCACAATCC.hg18.49.+
# add > to Smith:HepG2Negative-161.C:SLEA_hg18:chr9:82902419-82902586|57:V_HNF6_Q6:CAAAATCAATAA;72:V_Rxra_UP:GGCCGTGACCCCGTGAT;92:V_PPARA_02:CCGGGTCATTGGGGTCAGG.hg18.48.+
# add > to Smith:HepG2Negative-162.C:SLEA_hg18:chr9:82902419-82902586|58:V_HNF3ALPHA_Q6:TGTTTGCTTTG;72:V_Rxra_UP:GGCCGTGACCCCGTGAT;92:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC.hg18.50.+
# add > to Smith:HepG2Negative-163.C:SLEA_hg18:chr9:82902419-82902586|58:V_HNF6_Q6:CAAAATCAATAA;73:V_XBP1_01:GTGATGACGTGTCCCAT;93:V_Rxra_UP:GGCCGTGACCCCGTGAT.hg18.46.+
# add > to Smith:HepG2Negative-164.C:SLEA_hg18:chr9:82902419-82902586|59:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;81:V_Rxra_UP:GGCCGTGACCCCGTGAT;101:V_HNF4_Q6:AAGGTCCAG.hg18.49.+
# add > to Smith:HepG2Negative-165.C:SLEA_hg18:chr9:82902419-82902586|59:V_GATA4_Q3:AGATAACAGGGA;91:V_XBP1_01:GTGATGACGTGTCCCAT.hg18.44.+
# add > to Smith:HepG2Negative-166.C:SLEA_hg18:chr9:82902419-82902586|6:V_HNF3ALPHA_Q6:TGTTTGCTTTG;27:V_HNF3ALPHA_Q6:TGTTTGCTTTG;48:V_HNF3ALPHA_Q6:TGTTTGCTTTG;69:V_HNF3ALPHA_Q6:TGTTTGCTTTG;90:V_HNF4_Q6:AAGGTCCAG;109:V_HNF3ALPHA_Q6:TGTTTGCTTTG;130:V_HNF3ALPHA_Q6:TGTTTGCTTTG;151:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.39.+
# add > to Smith:HepG2Negative-167.C:SLEA_hg18:chr9:82902419-82902586|67:V_PPARA_02:CCGGGTCATTGGGGTCAGG;88:V_HNF6_Q6:CAAAATCAATAA.hg18.44.+
# add > to Smith:HepG2Negative-168.C:SLEA_hg18:chr9:82902419-82902586|80:V_HNF4_Q6:AAGGTCCAG.hg18.43.+
# add > to Smith:HepG2Positive-0.C:SLEA_hg18:chr2:210861483-210861650|10:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;36:V_HNF3ALPHA_Q6:TGTTTGCTTTG;50:V_HNF6_Q6:CAAAATCAATAA;65:V_HNF4_Q6:AAGGTCCAG;77:V_PPARA_02:CCGGGTCATTGGGGTCAGG;99:V_XBP1_01:GTGATGACGTGTCCCAT;119:V_HNF1_C:AGTTAATGATTAACCAA;139:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC.hg18.49.+
# add > to Smith:HepG2Positive-1.C:SLEA_hg18:chr2:210861483-210861650|10:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;36:V_HNF3ALPHA_Q6:TGTTTGCTTTG;50:V_HNF6_Q6:CAAAATCAATAA;65:V_HNF4_Q6:AAGGTCCAG;77:V_PPARA_02:CCGGGTCATTGGGGTCAGG;99:V_XBP1_01:GTGATGACGTGTCCCAT;119:V_HNF1_C:AGTTAATGATTAACCAA;139:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC_Reversed:.hg18.49.+
# add > to Smith:HepG2Positive-2.C:SLEA_hg18:chr2:210861483-210861650|10:V_HNF3ALPHA_Q6:TGTTTGCTTTG;24:V_HNF6_Q6:CAAAATCAATAA;39:V_Rxra_UP:GGCCGTGACCCCGTGAT;59:V_PPARA_02:CCGGGTCATTGGGGTCAGG;81:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;103:V_HNF1_C:AGTTAATGATTAACCAA;123:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;149:V_HNF4_Q6:AAGGTCCAG.hg18.52.+
# add > to Smith:HepG2Positive-3.C:SLEA_hg18:chr2:210861483-210861650|10:V_HNF3ALPHA_Q6:TGTTTGCTTTG;24:V_HNF6_Q6:CAAAATCAATAA;39:V_Rxra_UP:GGCCGTGACCCCGTGAT;59:V_PPARA_02:CCGGGTCATTGGGGTCAGG;81:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;103:V_HNF1_C:AGTTAATGATTAACCAA;123:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;149:V_HNF4_Q6:AAGGTCCAG_Reversed:.hg18.52.+
# add > to Smith:HepG2Positive-4.C:SLEA_hg18:chr2:210861483-210861650|10:V_HNF4_Q6:AAGGTCCAG;22:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;44:V_PPARA_02:CCGGGTCATTGGGGTCAGG;66:V_HNF6_Q6:CAAAATCAATAA;81:V_HNF1_C:AGTTAATGATTAACCAA;101:V_HNF3ALPHA_Q6:TGTTTGCTTTG;115:V_XBP1_01:GTGATGACGTGTCCCAT;135:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC.hg18.50.+
# add > to Smith:HepG2Positive-5.C:SLEA_hg18:chr2:210861483-210861650|10:V_HNF4_Q6:AAGGTCCAG;22:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;44:V_PPARA_02:CCGGGTCATTGGGGTCAGG;66:V_HNF6_Q6:CAAAATCAATAA;81:V_HNF1_C:AGTTAATGATTAACCAA;101:V_HNF3ALPHA_Q6:TGTTTGCTTTG;115:V_XBP1_01:GTGATGACGTGTCCCAT;135:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC_Reversed:.hg18.50.+
# add > to Smith:HepG2Positive-6.C:SLEA_hg18:chr2:210861483-210861650|10:V_HNF6_Q6:CAAAATCAATAA;25:V_PPARA_02:CCGGGTCATTGGGGTCAGG;47:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;69:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;95:V_HNF3ALPHA_Q6:TGTTTGCTTTG;109:V_XBP1_01:GTGATGACGTGTCCCAT;129:V_HNF4_Q6:AAGGTCCAG;141:V_HNF1_C:AGTTAATGATTAACCAA.hg18.49.+
# add > to Smith:HepG2Positive-7.C:SLEA_hg18:chr2:210861483-210861650|10:V_HNF6_Q6:CAAAATCAATAA;25:V_PPARA_02:CCGGGTCATTGGGGTCAGG;47:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;69:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;95:V_HNF3ALPHA_Q6:TGTTTGCTTTG;109:V_XBP1_01:GTGATGACGTGTCCCAT;129:V_HNF4_Q6:AAGGTCCAG;141:V_HNF1_C:AGTTAATGATTAACCAA_Reversed:.hg18.49.+
# add > to Smith:HepG2Positive-8.C:SLEA_hg18:chr2:210861483-210861650|11:V_HNF3ALPHA_Q6:TGTTTGCTTTG;25:V_XBP1_01:GTGATGACGTGTCCCAT;45:V_Rxra_UP:GGCCGTGACCCCGTGAT;65:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;87:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;113:V_HNF1_C:AGTTAATGATTAACCAA;133:V_HNF6_Q6:CAAAATCAATAA;148:V_HNF4_Q6:AAGGTCCAG.hg18.49.+
# add > to Smith:HepG2Positive-9.C:SLEA_hg18:chr2:210861483-210861650|11:V_HNF3ALPHA_Q6:TGTTTGCTTTG;25:V_XBP1_01:GTGATGACGTGTCCCAT;45:V_Rxra_UP:GGCCGTGACCCCGTGAT;65:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;87:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;113:V_HNF1_C:AGTTAATGATTAACCAA;133:V_HNF6_Q6:CAAAATCAATAA;148:V_HNF4_Q6:AAGGTCCAG_Reversed:.hg18.49.+
# add > to Smith:HepG2Positive-10.C:SLEA_hg18:chr2:210861483-210861650|11:V_HNF4_Q6:AAGGTCCAG;23:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;49:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;71:V_HNF3ALPHA_Q6:TGTTTGCTTTG;85:V_Rxra_UP:GGCCGTGACCCCGTGAT;105:V_XBP1_01:GTGATGACGTGTCCCAT;125:V_HNF6_Q6:CAAAATCAATAA;140:V_HNF1_C:AGTTAATGATTAACCAA.hg18.49.+
# add > to Smith:HepG2Positive-11.C:SLEA_hg18:chr2:210861483-210861650|11:V_HNF4_Q6:AAGGTCCAG;23:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;49:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;71:V_HNF3ALPHA_Q6:TGTTTGCTTTG;85:V_Rxra_UP:GGCCGTGACCCCGTGAT;105:V_XBP1_01:GTGATGACGTGTCCCAT;125:V_HNF6_Q6:CAAAATCAATAA;140:V_HNF1_C:AGTTAATGATTAACCAA_Reversed:.hg18.49.+
# add > to Smith:HepG2Positive-12.C:SLEA_hg18:chr2:210861483-210861650|11:V_HNF4_Q6:AAGGTCCAG;23:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;49:V_HNF1_C:AGTTAATGATTAACCAA;69:V_HNF3ALPHA_Q6:TGTTTGCTTTG;83:V_Rxra_UP:GGCCGTGACCCCGTGAT;103:V_HNF6_Q6:CAAAATCAATAA;118:V_XBP1_01:GTGATGACGTGTCCCAT;138:V_PPARA_02:CCGGGTCATTGGGGTCAGG.hg18.48.+
# add > to Smith:HepG2Positive-13.C:SLEA_hg18:chr2:210861483-210861650|11:V_HNF4_Q6:AAGGTCCAG;23:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;49:V_HNF1_C:AGTTAATGATTAACCAA;69:V_HNF3ALPHA_Q6:TGTTTGCTTTG;83:V_Rxra_UP:GGCCGTGACCCCGTGAT;103:V_HNF6_Q6:CAAAATCAATAA;118:V_XBP1_01:GTGATGACGTGTCCCAT;138:V_PPARA_02:CCGGGTCATTGGGGTCAGG_Reversed:.hg18.48.+
# add > to Smith:HepG2Positive-14.C:SLEA_hg18:chr2:210861483-210861650|12:V_XBP1_01:GTGATGACGTGTCCCAT;33:V_CEBP_Q2_01:ATTGCACAATCC;49:V_XBP1_01:GTGATGACGTGTCCCAT;70:V_CEBP_Q2_01:ATTGCACAATCC;86:V_CEBP_Q2_01:ATTGCACAATCC;102:V_XBP1_01:GTGATGACGTGTCCCAT;123:V_CEBP_Q2_01:ATTGCACAATCC;139:V_XBP1_01:GTGATGACGTGTCCCAT.hg18.46.+
# add > to Smith:HepG2Positive-15.C:SLEA_hg18:chr2:210861483-210861650|12:V_XBP1_01:GTGATGACGTGTCCCAT;33:V_CEBP_Q2_01:ATTGCACAATCC;49:V_XBP1_01:GTGATGACGTGTCCCAT;70:V_CEBP_Q2_01:ATTGCACAATCC;86:V_CEBP_Q2_01:ATTGCACAATCC;102:V_XBP1_01:GTGATGACGTGTCCCAT;123:V_CEBP_Q2_01:ATTGCACAATCC;139:V_XBP1_01:GTGATGACGTGTCCCAT_Reversed:.hg18.46.+
# add > to Smith:HepG2Positive-16.C:SLEA_hg18:chr2:210861483-210861650|13:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;39:V_XBP1_01:GTGATGACGTGTCCCAT;59:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;81:V_HNF3ALPHA_Q6:TGTTTGCTTTG;95:V_PPARA_02:CCGGGTCATTGGGGTCAGG;117:V_HNF1_C:AGTTAATGATTAACCAA;137:V_Rxra_UP:GGCCGTGACCCCGTGAT.hg18.53.+
# add > to Smith:HepG2Positive-17.C:SLEA_hg18:chr2:210861483-210861650|13:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;39:V_XBP1_01:GTGATGACGTGTCCCAT;59:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;81:V_HNF3ALPHA_Q6:TGTTTGCTTTG;95:V_PPARA_02:CCGGGTCATTGGGGTCAGG;117:V_HNF1_C:AGTTAATGATTAACCAA;137:V_Rxra_UP:GGCCGTGACCCCGTGAT_Reversed:.hg18.53.+
# add > to Smith:HepG2Positive-18.C:SLEA_hg18:chr2:210861483-210861650|16:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;38:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;64:V_HNF6_Q6:CAAAATCAATAA;79:V_XBP1_01:GTGATGACGTGTCCCAT;99:V_HNF3ALPHA_Q6:TGTTTGCTTTG;113:V_PPARA_02:CCGGGTCATTGGGGTCAGG;135:V_HNF1_C:AGTTAATGATTAACCAA.hg18.49.+
# add > to Smith:HepG2Positive-19.C:SLEA_hg18:chr2:210861483-210861650|16:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;38:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;64:V_HNF6_Q6:CAAAATCAATAA;79:V_XBP1_01:GTGATGACGTGTCCCAT;99:V_HNF3ALPHA_Q6:TGTTTGCTTTG;113:V_PPARA_02:CCGGGTCATTGGGGTCAGG;135:V_HNF1_C:AGTTAATGATTAACCAA_Reversed:.hg18.49.+
# add > to Smith:HepG2Positive-20.C:SLEA_hg18:chr2:210861483-210861650|17:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;39:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;65:V_HNF6_Q6:CAAAATCAATAA;80:V_XBP1_01:GTGATGACGTGTCCCAT;100:V_Rxra_UP:GGCCGTGACCCCGTGAT;120:V_HNF3ALPHA_Q6:TGTTTGCTTTG;134:V_HNF1_C:AGTTAATGATTAACCAA.hg18.50.+
# add > to Smith:HepG2Positive-21.C:SLEA_hg18:chr2:210861483-210861650|17:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;39:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;65:V_HNF6_Q6:CAAAATCAATAA;80:V_XBP1_01:GTGATGACGTGTCCCAT;100:V_Rxra_UP:GGCCGTGACCCCGTGAT;120:V_HNF3ALPHA_Q6:TGTTTGCTTTG;134:V_HNF1_C:AGTTAATGATTAACCAA_Reversed:.hg18.50.+
# add > to Smith:HepG2Positive-22.C:SLEA_hg18:chr2:210861483-210861650|17:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;39:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;65:V_XBP1_01:GTGATGACGTGTCCCAT;85:V_HNF6_Q6:CAAAATCAATAA;100:V_Rxra_UP:GGCCGTGACCCCGTGAT;120:V_HNF3ALPHA_Q6:TGTTTGCTTTG;134:V_HNF1_C:AGTTAATGATTAACCAA.hg18.50.+
# add > to Smith:HepG2Positive-23.C:SLEA_hg18:chr2:210861483-210861650|17:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;39:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;65:V_XBP1_01:GTGATGACGTGTCCCAT;85:V_HNF6_Q6:CAAAATCAATAA;100:V_Rxra_UP:GGCCGTGACCCCGTGAT;120:V_HNF3ALPHA_Q6:TGTTTGCTTTG;134:V_HNF1_C:AGTTAATGATTAACCAA_Reversed:.hg18.50.+
# add > to Smith:HepG2Positive-24.C:SLEA_hg18:chr2:210861483-210861650|17:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;43:V_PPARA_02:CCGGGTCATTGGGGTCAGG;65:V_HNF6_Q6:CAAAATCAATAA;80:V_XBP1_01:GTGATGACGTGTCCCAT;100:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;122:V_HNF4_Q6:AAGGTCCAG;134:V_HNF1_C:AGTTAATGATTAACCAA.hg18.50.+
# add > to Smith:HepG2Positive-25.C:SLEA_hg18:chr2:210861483-210861650|17:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;43:V_PPARA_02:CCGGGTCATTGGGGTCAGG;65:V_HNF6_Q6:CAAAATCAATAA;80:V_XBP1_01:GTGATGACGTGTCCCAT;100:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;122:V_HNF4_Q6:AAGGTCCAG;134:V_HNF1_C:AGTTAATGATTAACCAA_Reversed:.hg18.50.+
# add > to Smith:HepG2Positive-26.C:SLEA_hg18:chr2:210861483-210861650|17:V_PPARA_02:CCGGGTCATTGGGGTCAGG;39:V_HNF4_Q6:AAGGTCCAG;51:V_HNF3ALPHA_Q6:TGTTTGCTTTG;65:V_HNF1_C:AGTTAATGATTAACCAA;85:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;111:V_XBP1_01:GTGATGACGTGTCCCAT;131:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC.hg18.52.+
# add > to Smith:HepG2Positive-27.C:SLEA_hg18:chr2:210861483-210861650|17:V_PPARA_02:CCGGGTCATTGGGGTCAGG;39:V_HNF4_Q6:AAGGTCCAG;51:V_HNF3ALPHA_Q6:TGTTTGCTTTG;65:V_HNF1_C:AGTTAATGATTAACCAA;85:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;111:V_XBP1_01:GTGATGACGTGTCCCAT;131:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC_Reversed:.hg18.52.+
# add > to Smith:HepG2Positive-28.C:SLEA_hg18:chr2:210861483-210861650|17:V_Rxra_UP:GGCCGTGACCCCGTGAT;37:V_HNF6_Q6:CAAAATCAATAA;52:V_PPARA_02:CCGGGTCATTGGGGTCAGG;74:V_HNF3ALPHA_Q6:TGTTTGCTTTG;88:V_XBP1_01:GTGATGACGTGTCCCAT;108:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;134:V_HNF1_C:AGTTAATGATTAACCAA.hg18.49.+
# add > to Smith:HepG2Positive-29.C:SLEA_hg18:chr2:210861483-210861650|17:V_Rxra_UP:GGCCGTGACCCCGTGAT;37:V_HNF6_Q6:CAAAATCAATAA;52:V_PPARA_02:CCGGGTCATTGGGGTCAGG;74:V_HNF3ALPHA_Q6:TGTTTGCTTTG;88:V_XBP1_01:GTGATGACGTGTCCCAT;108:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;134:V_HNF1_C:AGTTAATGATTAACCAA_Reversed:.hg18.49.+
# add > to Smith:HepG2Positive-30.C:SLEA_hg18:chr2:210861483-210861650|18:V_PPARA_02:CCGGGTCATTGGGGTCAGG;40:V_XBP1_01:GTGATGACGTGTCCCAT;60:V_Rxra_UP:GGCCGTGACCCCGTGAT;80:V_HNF3ALPHA_Q6:TGTTTGCTTTG;94:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;120:V_HNF4_Q6:AAGGTCCAG;132:V_HNF1_C:AGTTAATGATTAACCAA.hg18.48.+
# add > to Smith:HepG2Positive-31.C:SLEA_hg18:chr2:210861483-210861650|18:V_PPARA_02:CCGGGTCATTGGGGTCAGG;40:V_XBP1_01:GTGATGACGTGTCCCAT;60:V_Rxra_UP:GGCCGTGACCCCGTGAT;80:V_HNF3ALPHA_Q6:TGTTTGCTTTG;94:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;120:V_HNF4_Q6:AAGGTCCAG;132:V_HNF1_C:AGTTAATGATTAACCAA_Reversed:.hg18.48.+
# add > to Smith:HepG2Positive-32.C:SLEA_hg18:chr2:210861483-210861650|18:V_Rxra_UP:GGCCGTGACCCCGTGAT;38:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;64:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;86:V_HNF1_C:AGTTAATGATTAACCAA;106:V_XBP1_01:GTGATGACGTGTCCCAT;126:V_HNF4_Q6:AAGGTCCAG;138:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.50.+
# add > to Smith:HepG2Positive-33.C:SLEA_hg18:chr2:210861483-210861650|18:V_Rxra_UP:GGCCGTGACCCCGTGAT;38:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;64:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;86:V_HNF1_C:AGTTAATGATTAACCAA;106:V_XBP1_01:GTGATGACGTGTCCCAT;126:V_HNF4_Q6:AAGGTCCAG;138:V_HNF3ALPHA_Q6:TGTTTGCTTTG_Reversed:.hg18.50.+
# add > to Smith:HepG2Positive-34.C:SLEA_hg18:chr2:210861483-210861650|18:V_Rxra_UP:GGCCGTGACCCCGTGAT;38:V_HNF6_Q6:CAAAATCAATAA;53:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;75:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;101:V_HNF1_C:AGTTAATGATTAACCAA;121:V_XBP1_01:GTGATGACGTGTCCCAT;141:V_HNF4_Q6:AAGGTCCAG.hg18.49.+
# add > to Smith:HepG2Positive-35.C:SLEA_hg18:chr2:210861483-210861650|18:V_Rxra_UP:GGCCGTGACCCCGTGAT;38:V_HNF6_Q6:CAAAATCAATAA;53:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;75:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;101:V_HNF1_C:AGTTAATGATTAACCAA;121:V_XBP1_01:GTGATGACGTGTCCCAT;141:V_HNF4_Q6:AAGGTCCAG_Reversed:.hg18.49.+
# add > to Smith:HepG2Positive-36.C:SLEA_hg18:chr2:210861483-210861650|19:V_HNF3ALPHA_Q6:TGTTTGCTTTG;33:V_HNF6_Q6:CAAAATCAATAA;48:V_HNF1_C:AGTTAATGATTAACCAA;68:V_Rxra_UP:GGCCGTGACCCCGTGAT;88:V_XBP1_01:GTGATGACGTGTCCCAT;108:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;130:V_PPARA_02:CCGGGTCATTGGGGTCAGG.hg18.49.+
# add > to Smith:HepG2Positive-37.C:SLEA_hg18:chr2:210861483-210861650|19:V_HNF3ALPHA_Q6:TGTTTGCTTTG;33:V_HNF6_Q6:CAAAATCAATAA;48:V_HNF1_C:AGTTAATGATTAACCAA;68:V_Rxra_UP:GGCCGTGACCCCGTGAT;88:V_XBP1_01:GTGATGACGTGTCCCAT;108:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;130:V_PPARA_02:CCGGGTCATTGGGGTCAGG_Reversed:.hg18.49.+
# add > to Smith:HepG2Positive-38.C:SLEA_hg18:chr2:210861483-210861650|19:V_PPARA_02:CCGGGTCATTGGGGTCAGG;41:V_XBP1_01:GTGATGACGTGTCCCAT;61:V_Rxra_UP:GGCCGTGACCCCGTGAT;81:V_HNF3ALPHA_Q6:TGTTTGCTTTG;95:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;121:V_HNF1_C:AGTTAATGATTAACCAA;141:V_HNF4_Q6:AAGGTCCAG.hg18.50.+
# add > to Smith:HepG2Positive-39.C:SLEA_hg18:chr2:210861483-210861650|19:V_PPARA_02:CCGGGTCATTGGGGTCAGG;41:V_XBP1_01:GTGATGACGTGTCCCAT;61:V_Rxra_UP:GGCCGTGACCCCGTGAT;81:V_HNF3ALPHA_Q6:TGTTTGCTTTG;95:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;121:V_HNF1_C:AGTTAATGATTAACCAA;141:V_HNF4_Q6:AAGGTCCAG_Reversed:.hg18.50.+
# add > to Smith:HepG2Positive-40.C:SLEA_hg18:chr2:210861483-210861650|2:V_HNF1_C:AGTTAATGATTAACCAA;23:V_HNF1_C:AGTTAATGATTAACCAA;44:V_HNF1_C:AGTTAATGATTAACCAA;65:V_HNF1_C:AGTTAATGATTAACCAA;86:V_Rxra_UP:GGCCGTGACCCCGTGAT;107:V_HNF1_C:AGTTAATGATTAACCAA;128:V_Rxra_UP:GGCCGTGACCCCGTGAT;149:V_HNF1_C:AGTTAATGATTAACCAA.hg18.36.+
# add > to Smith:HepG2Positive-41.C:SLEA_hg18:chr2:210861483-210861650|2:V_HNF1_C:AGTTAATGATTAACCAA;23:V_HNF1_C:AGTTAATGATTAACCAA;44:V_HNF1_C:AGTTAATGATTAACCAA;65:V_HNF1_C:AGTTAATGATTAACCAA;86:V_Rxra_UP:GGCCGTGACCCCGTGAT;107:V_HNF1_C:AGTTAATGATTAACCAA;128:V_Rxra_UP:GGCCGTGACCCCGTGAT;149:V_HNF1_C:AGTTAATGATTAACCAA_Reversed:.hg18.36.+
# ...
# add > to Smith:HepG2Positive-128.C:SLEA_hg18:chr9:82902419-82902586|11:V_HNF4_Q6:AAGGTCCAG;23:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;49:V_HNF1_C:AGTTAATGATTAACCAA;69:V_HNF3ALPHA_Q6:TGTTTGCTTTG;83:V_Rxra_UP:GGCCGTGACCCCGTGAT;103:V_HNF6_Q6:CAAAATCAATAA;118:V_XBP1_01:GTGATGACGTGTCCCAT;138:V_PPARA_02:CCGGGTCATTGGGGTCAGG.hg18.51.-
# add > to Smith:HepG2Positive-129.C:SLEA_hg18:chr9:82902419-82902586|11:V_HNF4_Q6:AAGGTCCAG;23:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;49:V_HNF1_C:AGTTAATGATTAACCAA;69:V_HNF3ALPHA_Q6:TGTTTGCTTTG;83:V_Rxra_UP:GGCCGTGACCCCGTGAT;103:V_HNF6_Q6:CAAAATCAATAA;118:V_XBP1_01:GTGATGACGTGTCCCAT;138:V_PPARA_02:CCGGGTCATTGGGGTCAGG_Reversed:.hg18.51.-
# add > to Smith:HepG2Positive-130.C:SLEA_hg18:chr9:82902419-82902586|11:V_Rxra_UP:GGCCGTGACCCCGTGAT;31:V_HNF3ALPHA_Q6:TGTTTGCTTTG;45:V_XBP1_01:GTGATGACGTGTCCCAT;65:V_PPARA_02:CCGGGTCATTGGGGTCAGG;87:V_HNF4_Q6:AAGGTCCAG;99:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;125:V_HNF6_Q6:CAAAATCAATAA;140:V_HNF1_C:AGTTAATGATTAACCAA.hg18.50.-
# add > to Smith:HepG2Positive-131.C:SLEA_hg18:chr9:82902419-82902586|11:V_Rxra_UP:GGCCGTGACCCCGTGAT;31:V_HNF3ALPHA_Q6:TGTTTGCTTTG;45:V_XBP1_01:GTGATGACGTGTCCCAT;65:V_PPARA_02:CCGGGTCATTGGGGTCAGG;87:V_HNF4_Q6:AAGGTCCAG;99:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;125:V_HNF6_Q6:CAAAATCAATAA;140:V_HNF1_C:AGTTAATGATTAACCAA_Reversed:.hg18.50.-
# add > to Smith:HepG2Positive-132.C:SLEA_hg18:chr9:82902419-82902586|13:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;35:V_HNF1_C:AGTTAATGATTAACCAA;55:V_HNF4_Q6:AAGGTCCAG;67:V_PPARA_02:CCGGGTCATTGGGGTCAGG;89:V_HNF3ALPHA_Q6:TGTTTGCTTTG;103:V_Rxra_UP:GGCCGTGACCCCGTGAT;123:V_HNF6_Q6:CAAAATCAATAA;138:V_XBP1_01:GTGATGACGTGTCCCAT.hg18.51.-
# add > to Smith:HepG2Positive-133.C:SLEA_hg18:chr9:82902419-82902586|13:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;35:V_HNF1_C:AGTTAATGATTAACCAA;55:V_HNF4_Q6:AAGGTCCAG;67:V_PPARA_02:CCGGGTCATTGGGGTCAGG;89:V_HNF3ALPHA_Q6:TGTTTGCTTTG;103:V_Rxra_UP:GGCCGTGACCCCGTGAT;123:V_HNF6_Q6:CAAAATCAATAA;138:V_XBP1_01:GTGATGACGTGTCCCAT_Reversed:.hg18.51.-
# add > to Smith:HepG2Positive-134.C:SLEA_hg18:chr9:82902419-82902586|13:V_HNF6_Q6:CAAAATCAATAA;28:V_PPARA_02:CCGGGTCATTGGGGTCAGG;50:V_XBP1_01:GTGATGACGTGTCCCAT;70:V_Rxra_UP:GGCCGTGACCCCGTGAT;90:V_HNF3ALPHA_Q6:TGTTTGCTTTG;104:V_HNF4_Q6:AAGGTCCAG;116:V_HNF1_C:AGTTAATGATTAACCAA;136:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC.hg18.53.-
# add > to Smith:HepG2Positive-135.C:SLEA_hg18:chr9:82902419-82902586|13:V_HNF6_Q6:CAAAATCAATAA;28:V_PPARA_02:CCGGGTCATTGGGGTCAGG;50:V_XBP1_01:GTGATGACGTGTCCCAT;70:V_Rxra_UP:GGCCGTGACCCCGTGAT;90:V_HNF3ALPHA_Q6:TGTTTGCTTTG;104:V_HNF4_Q6:AAGGTCCAG;116:V_HNF1_C:AGTTAATGATTAACCAA;136:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC_Reversed:.hg18.53.-
# add > to Smith:HepG2Positive-136.C:SLEA_hg18:chr9:82902419-82902586|17:V_HNF3ALPHA_Q6:TGTTTGCTTTG;31:V_Rxra_UP:GGCCGTGACCCCGTGAT;51:V_PPARA_02:CCGGGTCATTGGGGTCAGG;73:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;95:V_HNF1_C:AGTTAATGATTAACCAA;115:V_HNF4_Q6:AAGGTCCAG;127:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC.hg18.54.-
# add > to Smith:HepG2Positive-137.C:SLEA_hg18:chr9:82902419-82902586|17:V_HNF3ALPHA_Q6:TGTTTGCTTTG;31:V_Rxra_UP:GGCCGTGACCCCGTGAT;51:V_PPARA_02:CCGGGTCATTGGGGTCAGG;73:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;95:V_HNF1_C:AGTTAATGATTAACCAA;115:V_HNF4_Q6:AAGGTCCAG;127:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC_Reversed:.hg18.54.-
# add > to Smith:HepG2Positive-138.C:SLEA_hg18:chr9:82902419-82902586|17:V_Rxra_UP:GGCCGTGACCCCGTGAT;37:V_HNF6_Q6:CAAAATCAATAA;52:V_HNF1_C:AGTTAATGATTAACCAA;72:V_PPARA_02:CCGGGTCATTGGGGTCAGG;94:V_HNF3ALPHA_Q6:TGTTTGCTTTG;108:V_XBP1_01:GTGATGACGTGTCCCAT;128:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC.hg18.51.-
# add > to Smith:HepG2Positive-139.C:SLEA_hg18:chr9:82902419-82902586|17:V_Rxra_UP:GGCCGTGACCCCGTGAT;37:V_HNF6_Q6:CAAAATCAATAA;52:V_HNF1_C:AGTTAATGATTAACCAA;72:V_PPARA_02:CCGGGTCATTGGGGTCAGG;94:V_HNF3ALPHA_Q6:TGTTTGCTTTG;108:V_XBP1_01:GTGATGACGTGTCCCAT;128:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC_Reversed:.hg18.51.-
# add > to Smith:HepG2Positive-140.C:SLEA_hg18:chr9:82902419-82902586|18:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;40:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;66:V_HNF3ALPHA_Q6:TGTTTGCTTTG;80:V_HNF1_C:AGTTAATGATTAACCAA;100:V_PPARA_02:CCGGGTCATTGGGGTCAGG;122:V_XBP1_01:GTGATGACGTGTCCCAT;142:V_HNF4_Q6:AAGGTCCAG.hg18.54.-
# add > to Smith:HepG2Positive-141.C:SLEA_hg18:chr9:82902419-82902586|18:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;40:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;66:V_HNF3ALPHA_Q6:TGTTTGCTTTG;80:V_HNF1_C:AGTTAATGATTAACCAA;100:V_PPARA_02:CCGGGTCATTGGGGTCAGG;122:V_XBP1_01:GTGATGACGTGTCCCAT;142:V_HNF4_Q6:AAGGTCCAG_Reversed:.hg18.54.-
# add > to Smith:HepG2Positive-142.C:SLEA_hg18:chr9:82902419-82902586|18:V_HNF4_Q6:AAGGTCCAG;30:V_Rxra_UP:GGCCGTGACCCCGTGAT;50:V_HNF1_C:AGTTAATGATTAACCAA;70:V_HNF6_Q6:CAAAATCAATAA;85:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;107:V_XBP1_01:GTGATGACGTGTCCCAT;127:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC.hg18.51.-
# add > to Smith:HepG2Positive-143.C:SLEA_hg18:chr9:82902419-82902586|18:V_HNF4_Q6:AAGGTCCAG;30:V_Rxra_UP:GGCCGTGACCCCGTGAT;50:V_HNF1_C:AGTTAATGATTAACCAA;70:V_HNF6_Q6:CAAAATCAATAA;85:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;107:V_XBP1_01:GTGATGACGTGTCCCAT;127:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC_Reversed:.hg18.51.-
# add > to Smith:HepG2Positive-144.C:SLEA_hg18:chr9:82902419-82902586|2:V_HNF1_C:AGTTAATGATTAACCAA;23:V_Rxra_UP:GGCCGTGACCCCGTGAT;44:V_Rxra_UP:GGCCGTGACCCCGTGAT;65:V_HNF1_C:AGTTAATGATTAACCAA;86:V_Rxra_UP:GGCCGTGACCCCGTGAT;107:V_Rxra_UP:GGCCGTGACCCCGTGAT;128:V_HNF1_C:AGTTAATGATTAACCAA;149:V_HNF1_C:AGTTAATGATTAACCAA.hg18.46.-
# add > to Smith:HepG2Positive-145.C:SLEA_hg18:chr9:82902419-82902586|2:V_HNF1_C:AGTTAATGATTAACCAA;23:V_Rxra_UP:GGCCGTGACCCCGTGAT;44:V_Rxra_UP:GGCCGTGACCCCGTGAT;65:V_HNF1_C:AGTTAATGATTAACCAA;86:V_Rxra_UP:GGCCGTGACCCCGTGAT;107:V_Rxra_UP:GGCCGTGACCCCGTGAT;128:V_HNF1_C:AGTTAATGATTAACCAA;149:V_Rxra_UP:GGCCGTGACCCCGTGAT.hg18.50.-
# add > to Smith:HepG2Positive-146.C:SLEA_hg18:chr9:82902419-82902586|2:V_Rxra_UP:GGCCGTGACCCCGTGAT;23:V_Rxra_UP:GGCCGTGACCCCGTGAT;44:V_Rxra_UP:GGCCGTGACCCCGTGAT;65:V_HNF1_C:AGTTAATGATTAACCAA;86:V_Rxra_UP:GGCCGTGACCCCGTGAT;107:V_HNF1_C:AGTTAATGATTAACCAA;128:V_HNF1_C:AGTTAATGATTAACCAA;149:V_Rxra_UP:GGCCGTGACCCCGTGAT.hg18.50.-
# add > to Smith:HepG2Positive-147.C:SLEA_hg18:chr9:82902419-82902586|2:V_Rxra_UP:GGCCGTGACCCCGTGAT;23:V_XBP1_01:GTGATGACGTGTCCCAT;44:V_Rxra_UP:GGCCGTGACCCCGTGAT;65:V_Rxra_UP:GGCCGTGACCCCGTGAT;86:V_XBP1_01:GTGATGACGTGTCCCAT;107:V_Rxra_UP:GGCCGTGACCCCGTGAT;128:V_XBP1_01:GTGATGACGTGTCCCAT;149:V_XBP1_01:GTGATGACGTGTCCCAT.hg18.56.-
# add > to Smith:HepG2Positive-148.C:SLEA_hg18:chr9:82902419-82902586|20:V_Rxra_UP:GGCCGTGACCCCGTGAT;40:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;62:V_PPARA_02:CCGGGTCATTGGGGTCAGG;84:V_HNF6_Q6:CAAAATCAATAA;99:V_XBP1_01:GTGATGACGTGTCCCAT;119:V_HNF1_C:AGTTAATGATTAACCAA;139:V_HNF4_Q6:AAGGTCCAG.hg18.50.-
# add > to Smith:HepG2Positive-149.C:SLEA_hg18:chr9:82902419-82902586|20:V_Rxra_UP:GGCCGTGACCCCGTGAT;40:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;62:V_PPARA_02:CCGGGTCATTGGGGTCAGG;84:V_HNF6_Q6:CAAAATCAATAA;99:V_XBP1_01:GTGATGACGTGTCCCAT;119:V_HNF1_C:AGTTAATGATTAACCAA;139:V_HNF4_Q6:AAGGTCCAG_Reversed:.hg18.50.-
# add > to Smith:HepG2Positive-150.C:SLEA_hg18:chr9:82902419-82902586|21:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;43:V_HNF6_Q6:CAAAATCAATAA;58:V_HNF1_C:AGTTAATGATTAACCAA;78:V_HNF3ALPHA_Q6:TGTTTGCTTTG;92:V_XBP1_01:GTGATGACGTGTCCCAT;112:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;138:V_HNF4_Q6:AAGGTCCAG.hg18.49.-
# add > to Smith:HepG2Positive-151.C:SLEA_hg18:chr9:82902419-82902586|21:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;43:V_HNF6_Q6:CAAAATCAATAA;58:V_HNF1_C:AGTTAATGATTAACCAA;78:V_HNF3ALPHA_Q6:TGTTTGCTTTG;92:V_XBP1_01:GTGATGACGTGTCCCAT;112:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;138:V_HNF4_Q6:AAGGTCCAG_Reversed:.hg18.49.-
# add > to Smith:HepG2Positive-152.C:SLEA_hg18:chr9:82902419-82902586|21:V_HNF4_Q6:AAGGTCCAG;33:V_XBP1_01:GTGATGACGTGTCCCAT;53:V_HNF3ALPHA_Q6:TGTTTGCTTTG;67:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;89:V_HNF6_Q6:CAAAATCAATAA;104:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;130:V_HNF1_C:AGTTAATGATTAACCAA.hg18.50.-
# add > to Smith:HepG2Positive-153.C:SLEA_hg18:chr9:82902419-82902586|21:V_HNF4_Q6:AAGGTCCAG;33:V_XBP1_01:GTGATGACGTGTCCCAT;53:V_HNF3ALPHA_Q6:TGTTTGCTTTG;67:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;89:V_HNF6_Q6:CAAAATCAATAA;104:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;130:V_HNF1_C:AGTTAATGATTAACCAA_Reversed:.hg18.50.-
# add > to Smith:HepG2Positive-154.C:SLEA_hg18:chr9:82902419-82902586|21:V_PPARA_02:CCGGGTCATTGGGGTCAGG;43:V_HNF3ALPHA_Q6:TGTTTGCTTTG;57:V_HNF6_Q6:CAAAATCAATAA;72:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;98:V_HNF4_Q6:AAGGTCCAG;110:V_HNF1_C:AGTTAATGATTAACCAA;130:V_XBP1_01:GTGATGACGTGTCCCAT.hg18.48.-
# add > to Smith:HepG2Positive-155.C:SLEA_hg18:chr9:82902419-82902586|21:V_PPARA_02:CCGGGTCATTGGGGTCAGG;43:V_HNF3ALPHA_Q6:TGTTTGCTTTG;57:V_HNF6_Q6:CAAAATCAATAA;72:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;98:V_HNF4_Q6:AAGGTCCAG;110:V_HNF1_C:AGTTAATGATTAACCAA;130:V_XBP1_01:GTGATGACGTGTCCCAT_Reversed:.hg18.48.-
# add > to Smith:HepG2Positive-156.C:SLEA_hg18:chr9:82902419-82902586|22:V_HNF4_Q6:AAGGTCCAG;34:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;60:V_HNF3ALPHA_Q6:TGTTTGCTTTG;74:V_Rxra_UP:GGCCGTGACCCCGTGAT;94:V_XBP1_01:GTGATGACGTGTCCCAT;114:V_HNF6_Q6:CAAAATCAATAA;129:V_HNF1_C:AGTTAATGATTAACCAA.hg18.48.-
# add > to Smith:HepG2Positive-157.C:SLEA_hg18:chr9:82902419-82902586|22:V_HNF4_Q6:AAGGTCCAG;34:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;60:V_HNF3ALPHA_Q6:TGTTTGCTTTG;74:V_Rxra_UP:GGCCGTGACCCCGTGAT;94:V_XBP1_01:GTGATGACGTGTCCCAT;114:V_HNF6_Q6:CAAAATCAATAA;129:V_HNF1_C:AGTTAATGATTAACCAA_Reversed:.hg18.48.-
# add > to Smith:HepG2Positive-158.C:SLEA_hg18:chr9:82902419-82902586|22:V_Rxra_UP:GGCCGTGACCCCGTGAT;42:V_HNF4_Q6:AAGGTCCAG;54:V_HNF1_C:AGTTAATGATTAACCAA;74:V_HNF6_Q6:CAAAATCAATAA;89:V_XBP1_01:GTGATGACGTGTCCCAT;109:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;135:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.49.-
# add > to Smith:HepG2Positive-159.C:SLEA_hg18:chr9:82902419-82902586|22:V_Rxra_UP:GGCCGTGACCCCGTGAT;42:V_HNF4_Q6:AAGGTCCAG;54:V_HNF1_C:AGTTAATGATTAACCAA;74:V_HNF6_Q6:CAAAATCAATAA;89:V_XBP1_01:GTGATGACGTGTCCCAT;109:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;135:V_HNF3ALPHA_Q6:TGTTTGCTTTG_Reversed:.hg18.49.-
# add > to Smith:HepG2Positive-160.C:SLEA_hg18:chr9:82902419-82902586|24:V_HNF4_Q6:AAGGTCCAG;36:V_HNF1_C:AGTTAATGATTAACCAA;56:V_HNF3ALPHA_Q6:TGTTTGCTTTG;70:V_Rxra_UP:GGCCGTGACCCCGTGAT;90:V_HNF6_Q6:CAAAATCAATAA;105:V_XBP1_01:GTGATGACGTGTCCCAT;125:V_PPARA_02:CCGGGTCATTGGGGTCAGG.hg18.47.-
# add > to Smith:HepG2Positive-161.C:SLEA_hg18:chr9:82902419-82902586|24:V_HNF4_Q6:AAGGTCCAG;36:V_HNF1_C:AGTTAATGATTAACCAA;56:V_HNF3ALPHA_Q6:TGTTTGCTTTG;70:V_Rxra_UP:GGCCGTGACCCCGTGAT;90:V_HNF6_Q6:CAAAATCAATAA;105:V_XBP1_01:GTGATGACGTGTCCCAT;125:V_PPARA_02:CCGGGTCATTGGGGTCAGG_Reversed:.hg18.47.-
# add > to Smith:HepG2Positive-162.C:SLEA_hg18:chr9:82902419-82902586|29:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;55:V_HNF4_Q6:AAGGTCCAG;67:V_XBP1_01:GTGATGACGTGTCCCAT;87:V_Rxra_UP:GGCCGTGACCCCGTGAT;107:V_HNF3ALPHA_Q6:TGTTTGCTTTG;121:V_HNF1_C:AGTTAATGATTAACCAA.hg18.51.-
# add > to Smith:HepG2Positive-163.C:SLEA_hg18:chr9:82902419-82902586|29:V_XBP1_01:GTGATGACGTGTCCCAT;49:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;75:V_HNF3ALPHA_Q6:TGTTTGCTTTG;89:V_HNF4_Q6:AAGGTCCAG;101:V_HNF1_C:AGTTAATGATTAACCAA;121:V_Rxra_UP:GGCCGTGACCCCGTGAT.hg18.50.-
# add > to Smith:HepG2Positive-164.C:SLEA_hg18:chr9:82902419-82902586|30:V_XBP1_01:GTGATGACGTGTCCCAT;50:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;72:V_HNF4_Q6:AAGGTCCAG;84:V_PPARA_02:CCGGGTCATTGGGGTCAGG;106:V_HNF6_Q6:CAAAATCAATAA;121:V_HNF1_C:AGTTAATGATTAACCAA.hg18.50.-
# add > to Smith:HepG2Positive-165.C:SLEA_hg18:chr9:82902419-82902586|35:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;57:V_HNF1_C:AGTTAATGATTAACCAA;77:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;103:V_HNF3ALPHA_Q6:TGTTTGCTTTG;117:V_XBP1_01:GTGATGACGTGTCCCAT.hg18.50.-
# add > to Smith:HepG2Positive-166.C:SLEA_hg18:chr9:82902419-82902586|38:V_HNF6_Q6:CAAAATCAATAA;53:V_HNF1_C:AGTTAATGATTAACCAA;73:V_HNF3ALPHA_Q6:TGTTTGCTTTG;87:V_XBP1_01:GTGATGACGTGTCCCAT;107:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC.hg18.46.-
# add > to Smith:HepG2Positive-167.C:SLEA_hg18:chr9:82902419-82902586|4:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;32:V_HNF3ALPHA_Q6:TGTTTGCTTTG;48:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;76:V_HNF3ALPHA_Q6:TGTTTGCTTTG;92:V_HNF3ALPHA_Q6:TGTTTGCTTTG;108:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;136:V_HNF3ALPHA_Q6:TGTTTGCTTTG;152:V_HNF3ALPHA_Q6:TGTTTGCTTTG.hg18.52.-
# add > to Smith:HepG2Positive-168.C:SLEA_hg18:chr9:82902419-82902586|42:V_HNF1_C:AGTTAATGATTAACCAA;64:V_HNF1_C:AGTTAATGATTAACCAA;86:V_Rxra_UP:GGCCGTGACCCCGTGAT;108:V_HNF1_C:AGTTAATGATTAACCAA.hg18.42.-
# add > to Smith:HepG2Positive-169.C:SLEA_hg18:chr9:82902419-82902586|44:V_HNF1_C:AGTTAATGATTAACCAA;65:V_Rxra_UP:GGCCGTGACCCCGTGAT;86:V_Rxra_UP:GGCCGTGACCCCGTGAT;107:V_HNF1_C:AGTTAATGATTAACCAA.hg18.46.-
# add > to Smith:HepG2Positive-170.C:SLEA_hg18:chr9:82902419-82902586|44:V_XBP1_01:GTGATGACGTGTCCCAT;65:V_HNF1_C:AGTTAATGATTAACCAA;86:V_HNF1_C:AGTTAATGATTAACCAA;107:V_XBP1_01:GTGATGACGTGTCCCAT.hg18.43.-
# add > to Smith:HepG2Positive-171.C:SLEA_hg18:chr9:82902419-82902586|46:V_HNF3ALPHA_Q6:TGTTTGCTTTG;60:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;86:V_HNF1_C:AGTTAATGATTAACCAA;106:V_XBP1_01:GTGATGACGTGTCCCAT.hg18.47.-
# add > to Smith:HepG2Positive-172.C:SLEA_hg18:chr9:82902419-82902586|6:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;28:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;54:V_HNF6_Q6:CAAAATCAATAA;69:V_XBP1_01:GTGATGACGTGTCCCAT;89:V_Rxra_UP:GGCCGTGACCCCGTGAT;109:V_HNF3ALPHA_Q6:TGTTTGCTTTG;123:V_PPARA_02:CCGGGTCATTGGGGTCAGG;145:V_HNF1_C:AGTTAATGATTAACCAA.hg18.54.-
# add > to Smith:HepG2Positive-173.C:SLEA_hg18:chr9:82902419-82902586|6:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;32:V_XBP1_01:GTGATGACGTGTCCCAT;52:V_HNF6_Q6:CAAAATCAATAA;67:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;89:V_HNF3ALPHA_Q6:TGTTTGCTTTG;103:V_PPARA_02:CCGGGTCATTGGGGTCAGG;125:V_HNF1_C:AGTTAATGATTAACCAA;145:V_Rxra_UP:GGCCGTGACCCCGTGAT.hg18.53.-
# add > to Smith:HepG2Positive-174.C:SLEA_hg18:chr9:82902419-82902586|6:V_PPARA_02:CCGGGTCATTGGGGTCAGG;28:V_Rxra_UP:GGCCGTGACCCCGTGAT;48:V_HNF6_Q6:CAAAATCAATAA;63:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;85:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;111:V_HNF3ALPHA_Q6:TGTTTGCTTTG;125:V_HNF1_C:AGTTAATGATTAACCAA;145:V_XBP1_01:GTGATGACGTGTCCCAT.hg18.52.-
# add > to Smith:HepG2Positive-175.C:SLEA_hg18:chr9:82902419-82902586|6:V_Rxra_UP:GGCCGTGACCCCGTGAT;26:V_PPARA_02:CCGGGTCATTGGGGTCAGG;48:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;70:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;96:V_HNF3ALPHA_Q6:TGTTTGCTTTG;110:V_HNF6_Q6:CAAAATCAATAA;125:V_HNF1_C:AGTTAATGATTAACCAA;145:V_XBP1_01:GTGATGACGTGTCCCAT.hg18.52.-
# add > to Smith:HepG2Positive-176.C:SLEA_hg18:chr9:82902419-82902586|7:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;29:V_XBP1_01:GTGATGACGTGTCCCAT;49:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;75:V_HNF4_Q6:AAGGTCCAG;87:V_HNF1_C:AGTTAATGATTAACCAA;107:V_Rxra_UP:GGCCGTGACCCCGTGAT;127:V_PPARA_02:CCGGGTCATTGGGGTCAGG;149:V_HNF6_Q6:CAAAATCAATAA.hg18.54.-
# add > to Smith:HepG2Positive-177.C:SLEA_hg18:chr9:82902419-82902586|8:V_HNF4_Q6:AAGGTCCAG;20:V_Rxra_UP:GGCCGTGACCCCGTGAT;40:V_HNF3ALPHA_Q6:TGTTTGCTTTG;54:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;76:V_PPARA_02:CCGGGTCATTGGGGTCAGG;98:V_HNF1_C:AGTTAATGATTAACCAA;118:V_XBP1_01:GTGATGACGTGTCCCAT;138:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC.hg18.55.-
# add > to Smith:HepG2Positive-178.C:SLEA_hg18:chr9:82902419-82902586|8:V_PPARA_02:CCGGGTCATTGGGGTCAGG;30:V_HNF1_C:AGTTAATGATTAACCAA;50:V_HNF3ALPHA_Q6:TGTTTGCTTTG;64:V_AHRARNT_02:GGGGATCGCGTGCCAGCCC;86:V_Rxra_UP:GGCCGTGACCCCGTGAT;106:V_XBP1_01:GTGATGACGTGTCCCAT;126:V_COUPTF_Q6:CCCCCTGACCTTTGCCCCCTGCC;152:V_HNF4_Q6:AAGGTCCAG.hg18.54.-
# add > to Smith:HepG2Positive-180.R:FOXA2-ChMod_chr6:53480537-53480650_[chr6:53480508-53480679]:033.hg18.40.-
# /scratch/fongsl/ipykernel_2413847/771321352.py:47: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   meta = pd.DataFrame(np.vstack(arrays.values()), columns=cols)
# (23182, 6)

# %% [markdown]
# # combine all meta data together

# %%
full_meta = pd.concat(results.values())

full_meta.head()
# Out:
#                              coor    info    build  gc_frac  type strand  \
# 0  NW_023558863.1:3214075-3215251  tile_0  artjam2       69  test      +
# 1  NW_023558863.1:3214075-3215251  tile_1  artjam2       69  test      +
# 2  NW_023558863.1:3214075-3215251  tile_2  artjam2       66  test      +
# 3  NW_023558863.1:3214075-3215251  tile_3  artjam2       65  test      +
# 4  NW_023558863.1:3214075-3215251  tile_4  artjam2       64  test      +
#
#            dataset  gc_within_40_60
# 0  library_forward            False
# 1  library_forward            False
# 2  library_forward            False
# 3  library_forward            False
# 4  library_forward            False

# %%
PATH
# Out:
# '/wynton/home/ahituv/fongsl/other_analyses/for-hai_bats/data/CallPeaks_results_for_Sarah/Artibeus_jamaicensis/liver/'

# %%
fig, ax = plt.subplots(figsize=(6, 6))
sns.kdeplot(x="gc_frac",
            data=full_meta.loc[full_meta["dataset"].str.contains("forward")],
            hue="type", common_norm=False)

ax.set(title=f"GC content\n{TISSUE}.{SPECIES}_specific.full_dataset")

plt.savefig(os.path.join(
    PATH, f"{TISSUE}.{SPECIES}_specific.gc_content.full.pdf"), bbox_inches="tight")

# %%
fig,ax=plt.subplots(figsize=(6,6))
sns.kdeplot(x="gc_frac", 
            data=full_meta.loc[
                (full_meta["dataset"].str.contains("forward"))
                &(full_meta["gc_within_40_60"]==True)
            ], 
            hue="type", common_norm=False)
ax.set(title=f"GC content\n{TISSUE}.{SPECIES}_specific.filtered_dataset")
plt.savefig(os.path.join(PATH, f"{TISSUE}.{SPECIES}_specific.gc_content.filtered.pdf"), bbox_inches="tight")

# %% [markdown]
# ## evaluate how many positive and negative controls passed gc filter

# %%
gc_ctrls = full_meta.loc[
                (full_meta["dataset"].str.contains("forward.gcfiltered"))
                &(full_meta["gc_within_40_60"]==True)
    &(full_meta["type"]=="ctrl")].drop_duplicates()
gc_ctrls
# Out:
#                           coor  \
# 22567    Smith:HepG2Negative-0
# 22568    Smith:HepG2Negative-1
# 22569    Smith:HepG2Negative-2
# 22570    Smith:HepG2Negative-3
# 22571    Smith:HepG2Negative-4
# ...                        ...
# 22877  Smith:HepG2Positive-175
# 22878  Smith:HepG2Positive-176
# 22879  Smith:HepG2Positive-177
# 22880  Smith:HepG2Positive-178
# 22881  Smith:HepG2Positive-180
#
#                                                     info build  gc_frac  type  \
# 22567  C:SLEA_hg18:chr2:210861483-210861650|10:V_XBP1...  hg18       50  ctrl
# 22568  C:SLEA_hg18:chr2:210861483-210861650|10:V_XBP1...  hg18       50  ctrl
# 22569  C:SLEA_hg18:chr2:210861483-210861650|10:V_XBP1...  hg18       51  ctrl
# 22570  C:SLEA_hg18:chr2:210861483-210861650|10:V_XBP1...  hg18       51  ctrl
# 22571  C:SLEA_hg18:chr2:210861483-210861650|103:V_HNF...  hg18       42  ctrl
# ...                                                  ...   ...      ...   ...
# 22877  C:SLEA_hg18:chr9:82902419-82902586|6:V_Rxra_UP...  hg18       52  ctrl
# 22878  C:SLEA_hg18:chr9:82902419-82902586|7:V_AHRARNT...  hg18       54  ctrl
# 22879  C:SLEA_hg18:chr9:82902419-82902586|8:V_HNF4_Q6...  hg18       55  ctrl
# 22880  C:SLEA_hg18:chr9:82902419-82902586|8:V_PPARA_0...  hg18       54  ctrl
# 22881  R:FOXA2-ChMod_chr6:53480537-53480650_[chr6:534...  hg18       40  ctrl
#
#       strand                     dataset  gc_within_40_60
# 22567      +  library_forward.gcfiltered             True
# 22568      +  library_forward.gcfiltered             True
# 22569      +  library_forward.gcfiltered             True
# 22570      +  library_forward.gcfiltered             True
# 22571      +  library_forward.gcfiltered             True
# ...      ...                         ...              ...
# 22877      +  library_forward.gcfiltered             True
# 22878      +  library_forward.gcfiltered             True
# 22879      +  library_forward.gcfiltered             True
# 22880      +  library_forward.gcfiltered             True
# 22881      +  library_forward.gcfiltered             True
#
# [315 rows x 8 columns]

# %%
gc_ctrls.loc[gc_ctrls["coor"].str.contains("Positive")].shape[0], gc_ctrls.loc[gc_ctrls["coor"].str.contains("Negative")].shape[0]
# Out:
# (172, 143)

# %% [markdown]
# ### gc filtering HepG2 controls
# - N = 172 positive
# - N = 143 negative

# %% [markdown]
# ## median of GC filtered HepG2 controls is 49%

# %%
gc_ctrls.describe()
# Out:
#           gc_frac
# count  315.000000
# mean    48.298413
# std      4.284452
# min     40.000000
# 25%     46.000000
# 50%     49.000000
# 75%     51.000000
# max     59.000000

# %% [markdown]
# ## median GC of filtered dataset is 54%

# %%
full_meta.loc[
                (full_meta["dataset"].str.contains("forward.gcfiltered"))
                &(full_meta["gc_within_40_60"]==True)].describe()
# Out:
#             gc_frac
# count  23182.000000
# mean      52.837805
# std        5.017876
# min       40.000000
# 25%       49.000000
# 50%       54.000000
# 75%       57.000000
# max       60.000000

# %% [markdown]
# ## median GC of the full dataset is 61%

# %%
full_meta.loc[
                (full_meta["dataset"]==("library_forward"))].describe()
# Out:
#             gc_frac
# count  53348.000000
# mean      60.886275
# std        9.263192
# min       27.000000
# 25%       55.000000
# 50%       61.000000
# 75%       67.000000
# max       88.000000
