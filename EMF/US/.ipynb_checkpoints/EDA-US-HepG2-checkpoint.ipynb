# %% [markdown]
# # objective
# 20230816
# sarahfong
#
# learn the features of the US MPRA dataset
#
# do some basic transformations and comparisons
#
# ## transformations
# - per replicate
#
#     - log2 normalize activity values
#     - explore standard scaling log2 values (rep ctrl 2 has wider variance than other replicates)
#
# - across replicates
#     - compute median, mean, sd of log2 values, standard scaling values
#
# ## questions
# - what is the variance between replicates?
# - How well do replicates correlate with one another?
#     - pearson between replicates?
#     - spearman between replicates?
# - what is the correlation across replicate means, medians within group?
#
# - is there are difference between log2 ratio and standard scaling activity?

# %%
import matplotlib.pyplot as plt
import numpy as np
import os, sys

import pandas as pd

import seaborn as sns
from scipy import stats
from sklearn.preprocessing import RobustScaler, StandardScaler

import sys

# %% [markdown]
# # Read, write to config

# %%
LOCAL = True
if LOCAL is True:
    sys.path.append("/Users/sarahfong/tools/py_")
    DATA_PATH = "/Users/sarahfong/Desktop/local_data/EMF/US"
import config_readwrite as crw
import plot_params as pp

# %%
pp.fonts()
# Out:
# ('sans-serif', 'Arial', 18)

# %%
# read
config, cfn = crw.read(os.path.join(os.path.dirname(os.getcwd()), "config.ini"))

# path
#DATA_PATH = config["local_path"]["data"]

# make dictionary of values to write to config
config_dict = {
    "HEPG2": os.path.join(DATA_PATH, "full_hepg2_MPRA.csv"),
    "HEPG2.clean": os.path.join(DATA_PATH, "full_hepg2_MPRA.clean.csv"),
    "HEPG2.clean.transformed": os.path.join(DATA_PATH, "full_hepg2_MPRA.clean.transformed.csv"),
    "HEPG2.clean.trans.scaled": os.path.join(DATA_PATH, "full_hepg2_MPRA.clean.transformed.standard.scaled.csv"),
    "BJ": os.path.join(DATA_PATH, "full_bj_MPRA.csv"),
    "BJ.clean": os.path.join(DATA_PATH, "full_bj_MPRA.clean.csv"),
    "BJ.clean.transformed": os.path.join(DATA_PATH, "full_bj_MPRA.clean.transformed.csv"),
    "BJ.clean.trans.scaled": os.path.join(DATA_PATH, "full_bj_MPRA.clean.transformed.standard.scaled.csv"),
    "FASTA":os.path.join(DATA_PATH, "ultrasound_final_no_adapter.fasta")
}

# make data section of config
section = "data"
crw.check(config, section)

# add dictionary to config
for key, value in config_dict.items():
    config[section][key] = value
    
# write to config    
crw.write(config, cfn)

# %% [markdown]
# # functions

# %% [markdown]
# ## mean, median, std

# %%
def computeStats(df, l2_ratios_list):
    """ compute median, mean, std of ctrl and ultrasound replicates per sequence"""
    print(l2_ratios_list[:3])
    df["l2.ratio.med.ctrl"] = df[l2_ratios_list[:3]].median(axis=1)
    df["l2.ratio.mean.ctrl"] = df[l2_ratios_list[:3]].mean(axis=1)
    df["l2.ratio.std.ctrl"] = df[l2_ratios_list[:3]].std(axis=1)

    df["l2.ratio.med.us"] = df[l2_ratios_list[3:]].median(axis=1)
    df["l2.ratio.mean.us"] = df[l2_ratios_list[3:]].mean(axis=1)
    df["l2.ratio.std.us"] = df[l2_ratios_list[3:]].std(axis=1)
    
    return df

# %% [markdown]
# ## l2 transform (RNA/DNA)

# %%
def log2Transform(df, ratios_list):
    """ log2 transform each ratio column"""
    
    for ratio in ratios_list:
        df[f"l2.{ratio}"] = np.log2(df[ratio])
    
    return df

# %% [markdown]
# ## get coordinates

# %%
def getCoordinates(df):
    """str split name to get genomic coordinates for endogenous sequences"""
    
    coordf = df.loc[df['name'].str.contains("chr")].copy()

    coordf["coor"] = coordf["name"].apply(
        lambda x: "chr"+x.split("chr")[1] if "chr" in x else None)

    # merge- add coordinates back to dataframe
    return pd.merge(df, coordf, how="left")

# %% [markdown]
#  ## compute fold change of medians

# %%
def computeDelta(df):
    """ compute delta of log2 median us - log2 median control"""
    
    df["delta.med"] = df["l2.ratio.med.us"]-df["l2.ratio.med.ctrl"]
    df["delta.mean"] = df["l2.ratio.mean.us"]-df["l2.ratio.mean.ctrl"]
    
    return df

# %%
def clOrigin(df, constants_list):
    """annotate which cl a sequence was designed from"""
    
    df["cl.origin"] = None

    for cl in constants_list:
        df.loc[df['name'].str.contains(cl), "cl.origin"] = cl
    
    return df

# %%
def ctrlAnnot(df, constants_list):
    """ annotate control type (pos, neg, test)"""
    
    df["type"] = "None"
    for ctrl in constants_list:
        df.loc[df['label'].str.contains(ctrl), "type"] = ctrl
    
    return df

# %%
def computePval(df, constants_list):
    """ compute per sequence ttest of ctrl v. ultrasound rep
        assume equal_var is False 
    """
    df["pval"] = None
    for i, row in df.iterrows():

        # get control replicates
        ctrls = row[constants_list[:3]]

         # get US replicates
        uss = row[constants_list[3:]]
        # t-test per sequence, no equal variance assumed. 
        t,p = stats.ttest_ind(list(ctrls), list(uss), equal_var=False)
        
        # update dataframe
        df.at[i,'pval'] = p
        
    return df

# %%
def callActive(df):
    """call active elements from ctrl, us MPRA as values > 95 of shuffled regions"""
    
    # get shuffles
    shufs = df.loc[df.name.str.contains("shuf")].copy()
    
    # get 97.5% of shuffle median score for ctrl, US treatment
    ctrl_975 = shufs['l2.ratio.med.ctrl'].quantile(0.975)
    us_975 = shufs['l2.ratio.med.us'].quantile(0.975)
    
    
    ctrl_025 = shufs['l2.ratio.med.ctrl'].quantile(0.025)
    us_025 = shufs['l2.ratio.med.us'].quantile(0.025)
    print(ctrl_975,ctrl_025, us_975, us_025)

    # create column to label active
    df['label.ctrl'], df['label.us']=0, 0
    
    # label active elements - has more activity than 97.5% shuffles
    df.loc[df['l2.ratio.med.ctrl']>ctrl_975, 'label.ctrl']=1
    df.loc[df['l2.ratio.med.us']>us_975, 'label.us']=1

    # label active elements - has less activity than 2.5% shuffles
    df.loc[df['l2.ratio.med.ctrl']<ctrl_025, 'label.ctrl']=-1
    df.loc[df['l2.ratio.med.us']<us_025, 'label.us']=-1
    
    return df

# %%
def callResponse(df):
    df["response"] = False
    
    df.loc[(df["pval"]<0.05)&
          (df['label.ctrl']!=df['label.us']),
           "response"
          ] = True
    
    return df

# %% [markdown]
# # test CL
#
# ## notes about this dataset
# - Activity score - median score was assigned per US|CTRL for each sequence
# - Active | inactive = test sequence score > 95% shuffled score. Both these scores are median score (above)
# - logFC
# - P-value

# %% [markdown]
# ### input data

# %%
CL= "HEPG2" #"BJ" #
DATA = config_dict[CL]
CLEAN = config_dict[f"{CL}.clean.transformed"]
SCALED =config_dict[f'{CL}.clean.trans.scaled']

# %% [markdown]
# ### constants dict

# %%
constants = {
    "NAMES" :['name',
         'label',
         'ratio.med.ctrl',
         'label.ctrl',
         'ratio.1.ctrl',
         'ratio.2.ctrl',
         'ratio.3.ctrl',
         'ratio.med.us',
         'label.us',
         'ratio.1.us',
         'ratio.2.us',
         'ratio.3.us',
         'pval',
              "p_adj", 
         'logFC',
         'response'],
    
    "CTRL_LIST" : ["NegCt", "PosCt", "Shuffle", "Synthetic", 'H3K27AC', "ATAC", "DEG", "non-diff"],
    
    "RATIOS": ['ratio.1.ctrl','ratio.2.ctrl', 'ratio.3.ctrl', 
          'ratio.1.us', 'ratio.2.us','ratio.3.us'],
    
    "L2RATIOS": ['l2.ratio.1.ctrl','l2.ratio.2.ctrl', 'l2.ratio.3.ctrl', 
          'l2.ratio.1.us', 'l2.ratio.2.us','l2.ratio.3.us'],
    "L2STD": ['l2.ratio.std.ctrl', 'l2.ratio.std.us'],
    
    "CL_LIST" :["k562", "hob", "bj", "hepg2"]
}

# %% [markdown]
# ### load data

# %%
#if os.path.exists(CLEAN) is False:
    # load .csv data, rename columns, skip row 1 (old column names)
    df_ = pd.read_csv(DATA, skiprows=1, names=constants["NAMES"], low_memory=False)

    # annotate cell line origin
    df = clOrigin(df_, constants["CL_LIST"])

    # annotate controls
    df = ctrlAnnot(df,constants["CTRL_LIST"])

    # coordinates
    df = getCoordinates(df)

    # log2 transform ratios - increase sensitivity for ratios <1
    df = log2Transform(df, constants["RATIOS"])

    # compute stats
    df = computeStats(df, constants["L2RATIOS"])

    # compute difference between scaled
    df = computeDelta(df)

    # recall active
    df = callActive(df)

    # re compute pvalues 
    df = computePval(df, constants["L2RATIOS"])

    # recall response
    df = callResponse(df)
    # write the file

    df.to_csv(CLEAN, sep='\t', index=False)
    print('wrote clean')
# Out:
# ['l2.ratio.1.ctrl', 'l2.ratio.2.ctrl', 'l2.ratio.3.ctrl']
# 0.25399016686818887 -1.1478228049124133 0.2762746225138841 -1.1550842208491383
# wrote clean

# %%
#else:
 #   df = pd.read_csv(CLEAN, sep='\t')

df.head()
# Out:
#                                                 name                 label  \
# 0  SYNTHETIC:_Added_GTTCGAGACCAG_CCCCCCCC_CAAGAGT...             Synthetic
# 1  SYNTHETIC:_Added_GTTCGAGACCAG_CACCTG_TATGACTCA...             Synthetic
# 2  SYNTHETIC:_Added_TATGACTCATA_ACACACACAC_CAGAGC...             Synthetic
# 3            hob_k27ac_down_chr3:153162778-153163047  Differential_H3K27ac
# 4  SYNTHETIC:_The_motif_GCGGGGGCGCGGCCCGGGGCGGCGG...             Synthetic
#
#    ratio.med.ctrl  label.ctrl  ratio.1.ctrl  ratio.2.ctrl  ratio.3.ctrl  \
# 0        0.571454           0      0.560525      0.558706      0.595131
# 1        0.566359           0      0.565983      0.591011      0.542084
# 2        0.902494           0      0.900963      0.902950      0.903569
# 3        0.540202           0      0.520008      0.550384      0.550215
# 4        0.513563           0      0.502254      0.531092      0.507341
#
#    ratio.med.us  label.us  ratio.1.us  ...  l2.ratio.2.us  l2.ratio.3.us  \
# 0      0.794991         0    0.792387  ...      -0.366600      -0.291630
# 1      0.836449         0    0.838998  ...      -0.289023      -0.231257
# 2      0.946210         0    0.943318  ...      -0.075159      -0.079973
# 3      0.387954        -1    0.389100  ...      -1.313271      -1.425254
# 4      0.359202        -1    0.379668  ...      -1.540681      -1.497305
#
#   l2.ratio.med.ctrl  l2.ratio.mean.ctrl  l2.ratio.std.ctrl  l2.ratio.med.us  \
# 0         -0.835150           -0.807903           0.051307        -0.335723
# 1         -0.821170           -0.821109           0.062334        -0.253261
# 2         -0.147282           -0.148012           0.002178        -0.079973
# 3         -0.861932           -0.888939           0.047161        -1.361785
# 4         -0.978971           -0.961816           0.042926        -1.497305
#
#   l2.ratio.mean.us l2.ratio.std.us delta.med  delta.mean
# 0        -0.331318        0.037679  0.499427    0.476586
# 1        -0.257847        0.029155  0.567909    0.563262
# 2        -0.079772        0.004516  0.067309    0.068240
# 3        -1.366770        0.056158 -0.499854   -0.477831
# 4        -1.478392        0.073591 -0.518334   -0.516576
#
# [5 rows x 33 columns]

# %%
df['type'].unique()
# Out:
# array(['Synthetic', 'None', 'ATAC', 'NegCt', 'Shuffle', 'DEG', 'PosCt'],
#       dtype=object)

# %% [markdown]
# ## QC old df v. new df

# %%
def harmonizeOldDf(df_):
    df_.loc[df_["label.ctrl"] == "inactive", "label.ctrl"] = False
    df_.loc[df_["label.ctrl"] == "active", "label.ctrl"] = True
    df_.loc[df_["label.us"] == "inactive", "label.us"] = False
    df_.loc[df_["label.us"] == "active", "label.us"] = True
    
    df_.loc[df_["response"] =="ultrasound-responsive", "response" ] = True
    df_.loc[df_["response"] =="unresponsive", "response" ] = False
    
    return df_

# %%
def checkCoor(old_df, new_df, col):
    """
    check correlations before and after log transforming data
    """
    old_col = 'old-'+col
    
    old = old_df[["name", col]].drop_duplicates()
    new = new_df[["name", col]].drop_duplicates()
    
    old = old.rename(columns={col:old_col})

    #print(list(old), list(new))
    
    m = pd.merge(old[["name", old_col]], 
                 new 
                )
    print(m[[old_col, col]].corr())
    
    return m

# %% [markdown]
# ### harmonize old df with bool

# %%
# load .csv data, rename columns, skip row 1 (old column names)
df_ = pd.read_csv(DATA, skiprows=1, names=constants["NAMES"], low_memory=False)

df_ = harmonizeOldDf(df_)

# %%
checkCoor(df_, df, "pval")  # calling activity in control
# Out:
#           old-pval
# old-pval       1.0
#                                                     name  old-pval  \
# 0      SYNTHETIC:_Added_GTTCGAGACCAG_CCCCCCCC_CAAGAGT...  0.000188
# 1      SYNTHETIC:_Added_GTTCGAGACCAG_CACCTG_TATGACTCA...  0.000206
# 2      SYNTHETIC:_Added_TATGACTCATA_ACACACACAC_CAGAGC...  0.000269
# 3                hob_k27ac_down_chr3:153162778-153163047  0.000377
# 4      SYNTHETIC:_The_motif_GCGGGGGCGCGGCCCGGGGCGGCGG...  0.000443
# ...                                                  ...       ...
# 58612             hepg2_atac_down_chr8:60473308-60473577  0.999889
# 58613  SYNTHETIC:_Added_CCCATAAAAC_CTGATAAGGA_GATAAAC...  0.999893
# 58614  SYNTHETIC:_The_motif_TATGAGTCATA_was_added_in_...  0.999901
# 58615             hob_k27ac_up_chr13:102873885-102874154  0.999937
# 58616               k562_atac_up_chr17:66414080-66414349  0.999962
#
#               pval
# 0      0.000336781
# 1       0.00101834
# 2      0.000218396
# 3      0.000412067
# 4       0.00134207
# ...            ...
# 58612     0.982009
# 58613     0.969145
# 58614     0.992995
# 58615     0.983383
# 58616     0.967443
#
# [58617 rows x 3 columns]

# %% [markdown]
# ### check label correlation - ctrl

# %%
checkCoor(df_, df, "label.ctrl")  # calling activity in control
# Out:
#             label.ctrl
# label.ctrl         1.0
#                                                     name old-label.ctrl  \
# 0      SYNTHETIC:_Added_GTTCGAGACCAG_CCCCCCCC_CAAGAGT...          False
# 1      SYNTHETIC:_Added_GTTCGAGACCAG_CACCTG_TATGACTCA...          False
# 2      SYNTHETIC:_Added_TATGACTCATA_ACACACACAC_CAGAGC...          False
# 3                hob_k27ac_down_chr3:153162778-153163047          False
# 4      SYNTHETIC:_The_motif_GCGGGGGCGCGGCCCGGGGCGGCGG...          False
# ...                                                  ...            ...
# 58612             hepg2_atac_down_chr8:60473308-60473577          False
# 58613  SYNTHETIC:_Added_CCCATAAAAC_CTGATAAGGA_GATAAAC...          False
# 58614  SYNTHETIC:_The_motif_TATGAGTCATA_was_added_in_...          False
# 58615             hob_k27ac_up_chr13:102873885-102874154          False
# 58616               k562_atac_up_chr17:66414080-66414349           True
#
#        label.ctrl
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 58612           0
# 58613           0
# 58614           0
# 58615           0
# 58616           1
#
# [58617 rows x 3 columns]

# %% [markdown]
# ### check label correlation - us

# %%
checkCoor(df_, df, "label.us")  # calling activity in US
# Out:
#           label.us
# label.us       1.0
#                                                     name old-label.us  \
# 0      SYNTHETIC:_Added_GTTCGAGACCAG_CCCCCCCC_CAAGAGT...        False
# 1      SYNTHETIC:_Added_GTTCGAGACCAG_CACCTG_TATGACTCA...        False
# 2      SYNTHETIC:_Added_TATGACTCATA_ACACACACAC_CAGAGC...        False
# 3                hob_k27ac_down_chr3:153162778-153163047        False
# 4      SYNTHETIC:_The_motif_GCGGGGGCGCGGCCCGGGGCGGCGG...        False
# ...                                                  ...          ...
# 58612             hepg2_atac_down_chr8:60473308-60473577        False
# 58613  SYNTHETIC:_Added_CCCATAAAAC_CTGATAAGGA_GATAAAC...        False
# 58614  SYNTHETIC:_The_motif_TATGAGTCATA_was_added_in_...        False
# 58615             hob_k27ac_up_chr13:102873885-102874154        False
# 58616               k562_atac_up_chr17:66414080-66414349         True
#
#        label.us
# 0             0
# 1             0
# 2             0
# 3            -1
# 4            -1
# ...         ...
# 58612         0
# 58613         0
# 58614         0
# 58615         0
# 58616         1
#
# [58617 rows x 3 columns]

# %%
checkCoor(df_, df, "response")
# Out:
#           response
# response       1.0
#                                                     name old-response  \
# 0      SYNTHETIC:_Added_GTTCGAGACCAG_CCCCCCCC_CAAGAGT...        False
# 1      SYNTHETIC:_Added_GTTCGAGACCAG_CACCTG_TATGACTCA...        False
# 2      SYNTHETIC:_Added_TATGACTCATA_ACACACACAC_CAGAGC...        False
# 3                hob_k27ac_down_chr3:153162778-153163047        False
# 4      SYNTHETIC:_The_motif_GCGGGGGCGCGGCCCGGGGCGGCGG...        False
# ...                                                  ...          ...
# 58612             hepg2_atac_down_chr8:60473308-60473577        False
# 58613  SYNTHETIC:_Added_CCCATAAAAC_CTGATAAGGA_GATAAAC...        False
# 58614  SYNTHETIC:_The_motif_TATGAGTCATA_was_added_in_...        False
# 58615             hob_k27ac_up_chr13:102873885-102874154        False
# 58616               k562_atac_up_chr17:66414080-66414349        False
#
#        response
# 0         False
# 1         False
# 2         False
# 3          True
# 4          True
# ...         ...
# 58612     False
# 58613     False
# 58614     False
# 58615     False
# 58616     False
#
# [58617 rows x 3 columns]

# %% [markdown]
# not sure if response column rules are correct. Correct according to methods.

# %% [markdown]
# ## Within group replicate correlation?

# %% [markdown]
# ### plot function

# %%
def plotCorrHeatMap(data,cols):
    """ plot pearson and spearman correlation between columns in a dataframe"""
    pearson = data[cols].corr()
    spearman = data[cols].corr(method="spearman")
    
    matrix_p = np.triu(pearson)
    matrix_s = np.triu(spearman)
    
    # pearson
    fig,ax=plt.subplots()
    sns.heatmap(pearson, 
                annot=True, 
                mask=matrix_p,
                center=0,
                cbar_kws={"label":"pearson"}) 

    # spearman
    fig,ax=plt.subplots()
    sns.heatmap(spearman, 
                annot=True,
                mask=matrix_s,
                center=0,
                cbar_kws={"label":"spearman"})

# %% [markdown]
# ### within replicates, Pearson, Spearman

# %%
ratios=constants["L2RATIOS"]

# %%
data = df
cols = ratios

plotCorrHeatMap(data,cols)

# %% [markdown]
# ### problem = control 2 has greater variance.

# %%
fig,ax=plt.subplots()

for col in ratios:
    color="orange"
    if "ctrl" in col:
        color="grey"
        
    sns.histplot(data[col].sample(frac=0.2), label=col, color=color, kde=True)
plt.legend()
ax.set(xlabel = 'log2(RNA/DNA)')
# Out:
# [Text(0.5, 0, 'log2(RNA/DNA)')]

# %% [markdown]
# # Standard scaling per replicate

# %%
if os.path.exists(SCALED) is False:
    X = df[ratios]

    transformer = StandardScaler()

    t = pd.DataFrame(transformer.fit_transform(X[ratios]))

    t.columns = ratios # rename columns 

    ### mean, median of standardized values

    t = computeStats(t, ratios)

    # compute delta
    t = computeDelta(t)

    ### compute p value on standardized scale
    t = computePval(t, ratios)

    # add back names
    t = pd.merge(df['name'], t, left_index=True,right_index=True)

    # recall active
    t = callActive(t)

    # recall response
    t = callResponse(t)

    # write
    t.to_csv(SCALED, sep='\t', index=False)


else:
    t= pd.read_csv(SCALED, sep='\t')
t.head()
# Out:
#                                                 name  l2.ratio.1.ctrl  \
# 0  SYNTHETIC:_Added_GTTCGAGACCAG_CCCCCCCC_CAAGAGT...        -1.540412
# 1  SYNTHETIC:_Added_GTTCGAGACCAG_CACCTG_TATGACTCA...        -1.509708
# 2  SYNTHETIC:_Added_TATGACTCATA_ACACACACAC_CAGAGC...        -0.036640
# 3            hob_k27ac_down_chr3:153162778-153163047        -1.778149
# 4  SYNTHETIC:_The_motif_GCGGGGGCGCGGCCCGGGGCGGCGG...        -1.888218
#
#    l2.ratio.2.ctrl  l2.ratio.3.ctrl  l2.ratio.1.us  l2.ratio.2.us  \
# 0        -1.753692        -1.435884      -0.448025      -0.520633
# 1        -1.557900        -1.746592      -0.268086      -0.346851
# 2        -0.081597        -0.046183       0.100852       0.132231
# 3        -1.805965        -1.697042      -2.686970      -2.641293
# 4        -1.930248        -1.967033      -2.764227      -3.150721
#
#    l2.ratio.3.us  l2.ratio.med.ctrl  l2.ratio.mean.ctrl  l2.ratio.std.ctrl  \
# 0      -0.379391          -1.540412           -1.576663           0.161975
# 1      -0.242349          -1.557900           -1.604734           0.125194
# 2       0.101054          -0.046183           -0.054807           0.023686
# 3      -2.952640          -1.778149           -1.760385           0.056592
# 4      -3.116190          -1.930248           -1.928500           0.039436
#
#    l2.ratio.med.us  l2.ratio.mean.us  l2.ratio.std.us  delta.med  delta.mean  \
# 0        -0.448025         -0.449349         0.070631   1.092388    1.127313
# 1        -0.268086         -0.285762         0.054447   1.289814    1.318972
# 2         0.101054          0.111379         0.018059   0.147238    0.166186
# 3        -2.686970         -2.760301         0.168129  -0.908821   -0.999916
# 4        -3.116190         -3.010379         0.213872  -1.185941   -1.081879
#
#        pval  label.ctrl  label.us  response
# 0  0.002392       False     False     False
# 1  0.000785       False     False     False
# 2  0.000888       False     False     False
# 3  0.005100       False      True     False
# 4  0.010768       False      True     False

# %%
data = t
cols = ratios

plotCorrHeatMap(data,cols)

# %% [markdown]
# ##### After transform, the correlations between the sets are still the same
# ##### but the values are scaled to account for variance between replicates

# %%
fig,ax=plt.subplots()
for col in ratios:
    color="orange"
    if "ctrl" in col:
        color="grey"
        
    sns.histplot(data[col].sample(frac=0.2), label=col, color=color, kde=True)
    
plt.legend()
ax.set(xlabel = 'log2(RNA/DNA)')
# Out:
# [Text(0.5, 0, 'log2(RNA/DNA)')]

# %% [markdown]
# ## standard deviation distribution

# %%
sns.histplot(x='l2.ratio.std.ctrl', data=df, label = 'ctrl-std')
sns.histplot(x='l2.ratio.std.us', data=df, label = 'us-std', color="orange")
plt.legend()

# %%
x='l2.ratio.std.ctrl'
y='l2.ratio.std.us'
sns.jointplot(x=x,y=y,data=df, kind="reg")
df[[x,y]].corr()
# Out:
#                    l2.ratio.std.ctrl  l2.ratio.std.us
# l2.ratio.std.ctrl           1.000000         0.400038
# l2.ratio.std.us             0.400038         1.000000

# %% [markdown]
# # US v. ctrl

# %% [markdown]
# ## mean / median correlations

# %%
data = df
cols = ['l2.ratio.mean.ctrl', 'l2.ratio.mean.us',
        'l2.ratio.med.ctrl','l2.ratio.med.us', 
        'l2.ratio.std.ctrl','l2.ratio.std.us']

plotCorrHeatMap(data,cols)

# %%
data[cols].describe()
# Out:
#        l2.ratio.mean.ctrl  l2.ratio.mean.us  l2.ratio.med.ctrl  \
# count        58617.000000      58617.000000       58617.000000
# mean            -0.124512         -0.129694          -0.124986
# std              0.421780          0.436655           0.423558
# min             -2.609631         -2.662481          -2.734379
# 25%             -0.363273         -0.381761          -0.364155
# 50%             -0.072062         -0.075828          -0.071163
# 75%              0.183656          0.195921           0.182420
# max              4.143272          4.105301           4.217376
#
#        l2.ratio.med.us  l2.ratio.std.ctrl  l2.ratio.std.us
# count     58617.000000       58617.000000     58617.000000
# mean         -0.129812           0.103441         0.099849
# std           0.439266           0.077142         0.075787
# min          -2.722746           0.000088         0.000390
# 25%          -0.382994           0.048835         0.046074
# 50%          -0.075376           0.084037         0.080843
# 75%           0.195352           0.136618         0.132098
# max           4.265282           0.943106         0.955030

# %% [markdown]
# ## scaled mean/ median  correlations

# %%
# transformed data
data = t

plotCorrHeatMap(data,cols)

# %%
data[cols].describe()
# Out:
#        l2.ratio.mean.ctrl  l2.ratio.mean.us  l2.ratio.med.ctrl  \
# count        5.861700e+04      5.861700e+04       58617.000000
# mean        -9.818647e-18      3.448648e-17          -0.000194
# std          9.710442e-01      9.737762e-01           0.976558
# min         -5.707030e+00     -5.650401e+00          -5.711654
# 25%         -5.500334e-01     -5.618558e-01          -0.550602
# 50%          1.205840e-01      1.201006e-01           0.123057
# 75%          7.086572e-01      7.265079e-01           0.707723
# max          9.852289e+00      9.443218e+00          10.277449
#
#        l2.ratio.med.us  l2.ratio.std.ctrl  l2.ratio.std.us
# count     58617.000000       58617.000000     58617.000000
# mean         -0.000348           0.232864         0.221988
# std           0.979038           0.177226         0.168482
# min          -5.656690           0.001231         0.000489
# 25%          -0.564096           0.107960         0.102531
# 50%           0.120320           0.187335         0.179571
# 75%           0.724231           0.308620         0.293354
# max           9.846393           2.049920         2.165076

# %%
ps = pd.merge(t[["name", 'pval']], df[["name", 'pval']], 
              right_on = "name", left_on="name", suffixes = ("_transformed", "_not_transformed"))

ps.head()
# Out:
#                                                 name  pval_transformed  \
# 0  SYNTHETIC:_Added_GTTCGAGACCAG_CCCCCCCC_CAAGAGT...          0.002392
# 1  SYNTHETIC:_Added_GTTCGAGACCAG_CACCTG_TATGACTCA...          0.000785
# 2  SYNTHETIC:_Added_TATGACTCATA_ACACACACAC_CAGAGC...          0.000888
# 3            hob_k27ac_down_chr3:153162778-153163047          0.005100
# 4  SYNTHETIC:_The_motif_GCGGGGGCGCGGCCCGGGGCGGCGG...          0.010768
#
#   pval_not_transformed
# 0          0.000336781
# 1           0.00101834
# 2          0.000218396
# 3          0.000412067
# 4           0.00134207

# %%
ps_cols =["pval_not_transformed", "pval_transformed"]
sns.jointplot(x=ps_cols[0], y=ps_cols[1], data=ps, kind='hist')

# %% [markdown]
# ## plots

# %% [markdown]
# ### logFC distribution of datatypes

# %%
col = "logFC"
fig, ax = plt.subplots()
sns.kdeplot(x=col, data=df, hue= "type", common_norm=False)
ax.legend(bbox_to_anchor=(1,1))
# Out:
# No handles with labels found to put in legend.

# %%
# add type information back into transformed dataframe
t = pd.merge(t, df[["name", 
                    "type"]])

# %%
cols = ["l2.ratio.med.us", "l2.ratio.med.ctrl"]
datas = [df, t]
for data in datas:
    for col in cols:
        fig, ax = plt.subplots()
        sns.kdeplot(x=col, data=data, 
                    #label = col, 
                    hue="type", common_norm=False)
        ax.legend(bbox_to_anchor=(1,1))
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# # correlation between ctrl x US
# - raw values. Need to be centered per ctrl/US condition?

# %%
data_dict = {"raw":(df, [-4,5]),
            'standardized': (t, [-6,9])}

# %% [markdown]
# ## median

# %%
sns.jointplot
# Out:
# <function seaborn.axisgrid.jointplot(*, x=None, y=None, data=None, kind='scatter', color=None, height=6, ratio=5, space=0.2, dropna=False, xlim=None, ylim=None, marginal_ticks=False, joint_kws=None, marginal_kws=None, hue=None, palette=None, hue_order=None, hue_norm=None, **kwargs)>

# %%
def jointPlot(x, y, data, id_):
    
    # pick color
    if "med" in x:
        color = "b"
    elif "mean" in x:
        color = "g"
    else:
        color="orange"
        
    data["sig"] = data["pval"].apply(lambda x: True if x <0.05 else False)
    hue = "sig"
    g = sns.jointplot(x=x,
                  y=y,
                  data=data,
                  color=color,
                  hue=hue,
                  marginal_ticks=True, 
                  alpha=0.4,
                  marginal_kws={"common_norm":False}, 
                      joint_kws={"legend":False}
             )


    # don't plot identity line when looking at fc
    #if "delta" not in y:
     #   plt.plot(id_,id_, c="k", ls="--")
    
    # axes
    plt.axhline(0, c="grey", ls="--")
    plt.axvline(0, c="grey", ls="--")
    
    plt.legend(["Sig", "Non-sig"])
    return g

# %%
# change datatype
df["pval"] = df["pval"].astype(float)
t["pval"] = t["pval"].astype(float)

df["-log10p"] = np.log10(df["pval"])*-1
t["-log10p"] = np.log10(t["pval"])*-1

# %%
x="l2.ratio.med.ctrl"
y="l2.ratio.med.us"

data, id_ = data_dict["standardized"]

jointPlot(x, y, data, id_)

# %% [markdown]
# ### activity x fold change

# %%
x= "delta.med"
y= "-log10p"

data, id_ = data_dict["raw"]

id_ = [1,3]
fig = jointPlot(x, y, data, id_)

out = os.path.join(DATA_PATH, f"{CL}.delta.median.logp.jpg")

plt.savefig(out, bbox_inches="tight", dpi=160)

# %% [markdown]
# # for Giannini fellowship

# %% [markdown]
# ## raw data

# %%
data, id_ = data_dict["raw"]
data["qual"] = "None"
data.loc[(data["sig"] == True) & (data["delta.med"]>0), "qual"] = "Activating"
data.loc[(data["sig"] == True) & (data["delta.med"]<0), "qual"] = "Silencing"

x= "delta.med"
y= "-log10p"
hue = "qual"
g = sns.jointplot(x=x,
              y=y,
              data=data,
              #color=color,
              hue=hue,
              hue_order=["Activating", 'Silencing', "None"],
              marginal_ticks=True, 
              alpha=0.4,
              marginal_kws={"common_norm":False}, 
              joint_kws={"legend":False}, 
              palette ="Set2",
              label = hue
         )



g.set_axis_labels("log2(RNA/DNA)\nDelta MPRA activity", '-log10p', fontsize=16)

g.fig.suptitle(f'{CL} MPRA', size=18)
g.fig.tight_layout()


out = os.path.join(DATA_PATH, f"{CL}.delta.median.logp.png")

plt.savefig(out, bbox_inches="tight", dpi=90)

# %%
data["qual"] = "None"
data.loc[(data["sig"] == True) & (data["delta.med"]>0), "qual"] = "Activating"
data.loc[(data["sig"] == True) & (data["delta.med"]<0), "qual"] = "Silencing"

x= "delta.med"
y= "-log10p"
hue = "qual"

fig, ax=plt.subplots(figsize=(4,4))
sns.scatterplot(x=x,
              y=y,
              data=data,
              #color=color,
              hue=hue,
              hue_order=["Activating", 'Silencing', "None"],
              #alpha=0.4,
              palette ="Set2",
              label = hue
         )

ax.set(xlabel="",
    #xlabel="log2(RNA/DNA)\nDelta MPRA activity", 
       ylabel='-log10p', 
       title=f'{CL} MPRA', 
      xlim=(-2,2))
ax.legend(['',"Activating", "Silencing", "None"],bbox_to_anchor=(1,1), frameon=False)

out = os.path.join(DATA_PATH, f"{CL}.delta.median.logp.scatter.png")

plt.savefig(out, bbox_inches="tight", dpi=90)

# %% [markdown]
# ## standard-scaled data

# %%
data, id_ = data_dict["standardized"]
data["qual"] = "None"
data.loc[(data["sig"] == True) & (data["delta.med"]>0), "qual"] = "Activating"
data.loc[(data["sig"] == True) & (data["delta.med"]<0), "qual"] = "Silencing"

x= "delta.med"
y= "-log10p"
hue = "qual"
g = sns.jointplot(x=x,
              y=y,
              data=data,
              #color=color,
              hue=hue,
              hue_order=["Activating", 'Silencing', "None"],
              marginal_ticks=True, 
              alpha=0.4,
              marginal_kws={"common_norm":False}, 
              joint_kws={"legend":False}, 
              palette ="Set2",
              label = hue
         )



g.set_axis_labels("log2(RNA/DNA)\nDelta MPRA activity", '-log10p', fontsize=16)

g.fig.suptitle(f'{CL} MPRA', size=18)
g.fig.tight_layout()


out = os.path.join(DATA_PATH, f"{CL}.delta.median.logp.standardized.png")

plt.savefig(out, bbox_inches="tight", dpi=90)

# %%
data["qual"] = "None"
data.loc[(data["sig"] == True) & (data["delta.med"]>0), "qual"] = "Activating"
data.loc[(data["sig"] == True) & (data["delta.med"]<0), "qual"] = "Silencing"

x= "delta.med"
y= "-log10p"
hue = "qual"

fig, ax=plt.subplots(figsize=(4,4))
sns.scatterplot(x=x,
              y=y,
              data=data,
              #color=color,
              hue=hue,
              hue_order=["Activating", 'Silencing', "None"],
              #alpha=0.4,
              palette ="Set2",
              label = hue
         )

ax.set(xlabel="",
    #xlabel="log2(RNA/DNA)\nDelta MPRA activity", 
       ylabel='-log10p', 
       title=f'{CL} MPRA', 
      xlim=(-2.8,2.8))
ax.legend(['',"Activating", "Silencing", "None"],bbox_to_anchor=(1,1), frameon=False)

out = os.path.join(DATA_PATH, f"{CL}.delta.median.logp.scatter.standard.png")

plt.savefig(out, bbox_inches="tight", dpi=90)

# %%
x="delta.med"
y= "-log10p"
data, id_ = data_dict["standardized"]
jointPlot(x, y, data, id_)

# %%
x= "l2.ratio.mean.ctrl"
y="l2.ratio.mean.us"

data, id_ = data_dict["raw"]

jointPlot(x, y, data, id_)

# %%
data, id_ = data_dict["standardized"]
jointPlot(x, y, data, id_)

# %%
x= "l2.ratio.std.ctrl"
y="l2.ratio.std.us"
data, id_ = data_dict["standardized"]
jointPlot(x, y, data, id_)

# %%
data, id_ = data_dict["standardized"] 
sns.jointplot(y="l2.ratio.mean.us", data=data.loc[data["response"]==True], x= "l2.ratio.mean.ctrl", 
                marginal_ticks=True, 
                hue_order = [True, False],
               hue='response')


#plt.plot(id_,id_, c="k", ls="--")
plt.axhline(0, c="b", ls="--")
plt.axvline(0, c="b", ls="--")

# %% [markdown]
# # peak-wise - non-transformed

# %%
# merge peaks with tiles

TRANSFORMED_SCORE = True

PEAK_ANNOT = "/Users/sarahfong/Desktop/local_data/EMF/US/tilenames.x.enh.id.tsv"
peaks = pd.read_csv(PEAK_ANNOT, sep='\t')
print(peaks.head())

if TRANSFORMED_SCORE is True:
    peaks = pd.merge(t, peaks)
    
    # files to write
    SIG_PEAK = os.path.join(DATA_PATH, f"{CL}.US_MPRA.sig_peak.dif.act.tiles.standardscale.tsv")
    SIG_PEAK_TILES = os.path.join(DATA_PATH, f"{CL}.US_MPRA.sig_peak.act.tiles.standardscale.tsv")
    out = os.path.join(DATA_PATH, f'{CL}.sig.peaks.standardscale.pdf')

else:    
    peaks = pd.merge(df, peaks)
    
    # files to write
    SIG_PEAK = os.path.join(DATA_PATH, f"{CL}.US_MPRA.sig_peak.dif.act.tiles.tsv")
    SIG_PEAK_TILES = os.path.join(DATA_PATH, f"{CL}.US_MPRA.sig_peak.act.tiles.tsv")
    out = os.path.join(DATA_PATH, f'{CL}.sig.peaks.pdf')

peaks["dif"] = None
peaks.loc[(peaks['label.us']==True) &
         (peaks["label.ctrl"]==False) &
          (peaks["delta.med"]<0), "dif"] = "US.more.off"
peaks.loc[(peaks['label.us']==True) &
         (peaks["label.ctrl"]==False) &
          (peaks["delta.med"]>0), "dif"] = "US.on"

peaks.loc[(peaks['label.us']==False) &
         (peaks["label.ctrl"]==True)&
          (peaks["delta.med"]<0), "dif"] = "US.off"
peaks.loc[(peaks['label.us']==False) &
         (peaks["label.ctrl"]==True)&
          (peaks["delta.med"]>0), "dif"] = "US.less.off"

peaks.loc[(peaks['label.us']==True) &
         (peaks["label.ctrl"]==True), "dif"] = "no.effect.on"
peaks.loc[(peaks['label.us']==False) &
         (peaks["label.ctrl"]==False), "dif"] = "no.effect.off"
# Out:
#                                 name              enh.id enh.name
# 0  hob_k27ac_down_chr1:826978-827247  chr1:826978-827704    enh.0
# 1  hob_k27ac_down_chr1:827110-827379  chr1:826978-827704    enh.0
# 2  hob_k27ac_down_chr1:827377-827646  chr1:826978-827704    enh.0
# 3  hob_k27ac_down_chr1:827435-827704  chr1:826978-827704    enh.0
# 4  hob_k27ac_down_chr1:827891-828160  chr1:827891-828160    enh.1

# %%
# remove shuffles, these will confound stats
print(peaks.shape)
peaks = peaks.loc[~peaks["name"].str.contains('shuffle')]
print(peaks.shape)
# Out:
# (26700, 26)
# (26582, 26)

# %%
peaks.loc[peaks["enh.id"]=="chr3:153162778-153163579"]
# Out:
#                                          name  l2.ratio.1.ctrl  \
# 0     hob_k27ac_down_chr3:153162778-153163047        -1.778149
# 9529  hob_k27ac_down_chr3:153163310-153163579         0.665914
#
#       l2.ratio.2.ctrl  l2.ratio.3.ctrl  l2.ratio.1.us  l2.ratio.2.us  \
# 0           -1.805965        -1.697042      -2.686970      -2.641293
# 9529         0.591423         0.638196       0.799933       0.526938
#
#       l2.ratio.3.us  l2.ratio.med.ctrl  l2.ratio.mean.ctrl  l2.ratio.std.ctrl  \
# 0         -2.952640          -1.778149           -1.760385           0.056592
# 9529       1.161322           0.638196            0.631844           0.037650
#
#       ...  label.ctrl  label.us  response  type   -log10p    sig       qual  \
# 0     ...       False      True     False  None  2.292438   True  Silencing
# 9529  ...       False     False     False  None  0.403615  False       None
#
#                         enh.id  enh.name            dif
# 0     chr3:153162778-153163579  enh.7775    US.more.off
# 9529  chr3:153162778-153163579  enh.7775  no.effect.off
#
# [2 rows x 26 columns]

# %%
def peakwise(enh_id, df):

    cols =["name",
        'l2.ratio.med.ctrl',
        'label.ctrl',
        'l2.ratio.1.ctrl',
        'l2.ratio.2.ctrl',
        'l2.ratio.3.ctrl',
        'l2.ratio.med.us',
        'label.us',
        'l2.ratio.1.us',
        'l2.ratio.2.us',
        'l2.ratio.3.us', 
        'delta.med', 
        "dif", "enh.id", "enh.name"]
    
    # dget dataframe of enhancer only
    enh = df.loc[df["enh.id"]==enh_id, cols].copy()
    
    # treat all measurements as
    ctrls = list(pd.melt(enh, 
                        value_vars = ['l2.ratio.1.ctrl',
                        'l2.ratio.2.ctrl',
                        'l2.ratio.3.ctrl'])["value"])
    us = list(pd.melt(enh, 
                    value_vars = [ 'l2.ratio.1.us',
                    'l2.ratio.2.us',
                    'l2.ratio.3.us', ])["value"])
    # two related samples t-test, https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_rel.html
    s, p = stats.ttest_rel(ctrls, us)
    enh["peak_p"], enh["peak_stat"] = p, s
        
    return s, p, enh

# %% [markdown]
# ## if peak is significant, get all differentially active tiles in peak.

# %%
sig_peaks = {}  # requires sig peak and categorical differential activity 
all_sig_peaks = {} # requires sig peak, DOES NOT REQUIRE categorical differential activity 
for enh_id in peaks["enh.id"].unique():
    
    # perform repeated values t-test
    s, p, enh = peakwise(enh_id, peaks)
    
    if p<0.05:  # filter significant
        on_off= ["US.on", "US.more.on", "US.off", "US.more.off"]
        enh["dif"] =enh["dif"].astype(str)
        all_sig_peaks[enh_id] = enh
        # only pick differences 
        if len(set(enh["dif"]).intersection(set(on_off)))>0:
            sig_peaks[enh_id] = enh.loc[enh["dif"]!="None", 
                                        ["name", 
                                          "label.ctrl", 
                                          "label.us",
                                          'l2.ratio.med.ctrl',
                                          'l2.ratio.med.us',
                                          "delta.med", "dif", 
                                          "peak_p", "peak_stat", "enh.id", "enh.name"]]
    

sig = pd.concat(sig_peaks.values())
sig_all = pd.concat(all_sig_peaks.values())

sig.head()
# Out:
#                                          name  label.ctrl  label.us  \
# 1      hob_k27ac_down_chr19:10193979-10194248        True     False
# 12       k562_atac_up_chr13:25406382-25406651       False      True
# 1362     k562_atac_up_chr13:25406316-25406585        True      True
# 17560    k562_atac_up_chr13:25406448-25406717       False      True
# 13      bj_atac_down_chr1:147640884-147641153        True     False
#
#        l2.ratio.med.ctrl  l2.ratio.med.us  delta.med           dif    peak_p  \
# 1               1.143076         0.789981  -0.353095        US.off  0.006079
# 12              0.819309         1.474867   0.655558         US.on  0.032139
# 1362            0.927769         1.193302   0.265533  no.effect.on  0.032139
# 17560           0.706624         0.940791   0.234168         US.on  0.032139
# 13              0.900257         0.007644  -0.892613        US.off  0.014330
#
#        peak_stat                    enh.id  enh.name
# 1      12.767168   chr19:10193979-10194780  enh.5124
# 12     -2.589484   chr13:25406316-25406717  enh.2618
# 1362   -2.589484   chr13:25406316-25406717  enh.2618
# 17560  -2.589484   chr13:25406316-25406717  enh.2618
# 13      3.115320  chr1:147640752-147641153   enh.608

# %%
sig.loc[sig["dif"].str.contains("US.more")].sort_values(by = "delta.med", ascending=False)
# Out:
#                                          name  label.ctrl  label.us  \
# 1058      hob_k27ac_up_chr1:84144423-84144692       False      True
# 962     hob_k27ac_up_chr8:109482760-109483029       False      True
# 1598    hob_k27ac_up_chr7:105101674-105101943       False      True
# 1020       bj_k27ac_up_chr2:10123826-10124095       False      True
# 1553    hob_k27ac_up_chr1:192539411-192539680       False      True
# 2743       hob_k27ac_up_chr11:9702364-9702633       False      True
# 2512     hob_atac_up_chr9:134388464-134388733       False      True
# 241    hob_k27ac_down_chr21:46298041-46298310       False      True
# 412   hob_k27ac_down_chr2:221572570-221572839       False      True
# 387    hob_k27ac_down_chr18:58862986-58863255       False      True
#
#       l2.ratio.med.ctrl  l2.ratio.med.us  delta.med          dif    peak_p  \
# 1058          -2.197355        -2.307032  -0.109677  US.more.off  0.027510
# 962           -2.095453        -2.294600  -0.199147  US.more.off  0.037147
# 1598          -2.054938        -2.326692  -0.271754  US.more.off  0.013414
# 1020          -2.244699        -2.544283  -0.299584  US.more.off  0.014534
# 1553          -1.967091        -2.267977  -0.300886  US.more.off  0.034242
# 2743          -1.908670        -2.278466  -0.369795  US.more.off  0.008114
# 2512          -2.200132        -2.837221  -0.637088  US.more.off  0.031420
# 241           -1.729617        -2.419300  -0.689683  US.more.off  0.043241
# 412           -1.575160        -2.308584  -0.733424  US.more.off  0.024381
# 387           -1.772971        -2.677432  -0.904461  US.more.off  0.049478
#
#       peak_stat                    enh.id   enh.name
# 1058   2.459982    chr1:84144024-84144825    enh.451
# 962    2.370079  chr8:109482628-109483429  enh.10474
# 1598   2.828224  chr7:105101674-105102475   enh.9952
# 1020   2.896561    chr2:10123826-10124627   enh.5549
# 1553   2.345721  chr1:192539279-192540080    enh.788
# 2743   3.082222     chr11:9702097-9702898   enh.1549
# 2512   2.962722  chr9:134388397-134388798  enh.11089
# 241    2.691116   chr21:46297642-46298443   enh.6969
# 412    6.286590  chr2:221572570-221573371   enh.6346
# 387    2.312728   chr18:58862719-58863520   enh.4922

# %% [markdown]
# ## write significant peaks and their differentially active tiles

# %%
sig_dif = sig.loc[sig["dif"].str.contains("US")].sort_values(by = "delta.med", ascending=False)
print(sig.shape, sig_dif.shape, sig_all.shape)
# Out:
# (475, 11) (191, 11) (1239, 17)

# %% [markdown]
# Standard scale -
#
#     (475, 11) (191, 11) (1239, 17)
#
# Not standardized -
#
#     (462, 11) (177, 11) (1360, 17)

# %%
sig_dif.to_csv(SIG_PEAK, sep='\t')  # only differentially active tiles 
sig_all.to_csv(SIG_PEAK_TILES, sep='\t') # all tiles

# %%
sig["-log10p"] = -1*np.log10(sig["peak_p"])

# %%
fig,ax = plt.subplots(figsize=(6,6))
sns.scatterplot(x='delta.med', y="-log10p", data=sig.loc[sig["dif"].str.contains("US")], hue="dif")
ax.set(title=f"{CL}-significant peaks")
plt.legend(bbox_to_anchor=(1,1))


plt.savefig(out, bbox_incehs="tight")
# Out:
# /Users/sarahfong/miniconda3/envs/base_venv/lib/python3.6/site-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox_incehs" which is no longer supported as of 3.3 and will become an error two minor releases later
#   import sys

# %% [markdown]
# # peak-wise - transformed v. not transformed

# %%
TRANS = os.path.join(DATA_PATH, f"{CL}.US_MPRA.sig_peak.dif.act.tiles.standardscale.tsv")
NOTRANS = os.path.join(DATA_PATH, f"{CL}.US_MPRA.sig_peak.dif.act.tiles.tsv")

t_names = pd.read_csv(TRANS, sep='\t', usecols =["name"])
nt_names = pd.read_csv(NOTRANS, sep='\t', usecols =["name"])

trans_names = set(t_names["name"])
notrans_names = set(nt_names["name"])

len(trans_names.intersection(notrans_names)), len(trans_names), len(notrans_names)
# Out:
# (143, 191, 177)

# %% [markdown]
# ## how many transformed, non-transformed elements overlap?
#
# - 143 tiles have same dif peak significance between transformed and untransformed scores.
# - This is 143/191 tiles' standard scale activity ratios
# - and 143/177 tiles' non-scaled activity ratios

# %% [markdown]
# # p-value distribution

# %%
df["pval"] = df["pval"].astype(float)

df["pval"].describe()
# Out:
# count    58617.000000
# mean         0.513894
# std          0.281251
# min          0.000218
# 25%          0.274017
# 50%          0.515647
# 75%          0.755967
# max          0.999992
# Name: pval, dtype: float64

# %%
sns.histplot(np.log10(df["pval"])*-1)
# Out:
# <AxesSubplot:xlabel='pval', ylabel='Count'>

# %% [markdown]
# ## how many peaks are statistically significantly different?

# %%
len(df.loc[df["pval"]<0.05])
# Out:
# 1933

# %%
import pylab

# %%
np.array(df["pval"])
# Out:
# array([3.36780530e-04, 1.01834464e-03, 2.18396449e-04, ...,
#        9.92994555e-01, 9.83383143e-01, 9.67442505e-01])

# %%
stats.probplot(np.array(df["pval"]), dist="norm", plot=pylab)
#pylab.show()
# Out:
# ((array([-4.2273126 , -4.02322668, -3.91202409, ...,  3.91202409,
#           4.02322668,  4.2273126 ]),
#   array([2.18396449e-04, 3.09760632e-04, 3.36780530e-04, ...,
#          9.99972301e-01, 9.99979796e-01, 9.99992272e-01])),
#  (0.2753256540891906, 0.513893931417723, 0.9788692230261664))

# %%
stats.probplot(np.array(t["pval"]), dist="norm", plot=pylab)
#pylab.show()
# Out:
# ((array([-4.2273126 , -4.02322668, -3.91202409, ...,  3.91202409,
#           4.02322668,  4.2273126 ]),
#   array([5.74168037e-05, 7.52251975e-05, 1.18744450e-04, ...,
#          9.99995114e-01, 9.99995441e-01, 9.99996294e-01])),
#  (0.2748407435900166, 0.515555944470798, 0.979181052430251))

# %%
# random measurements. 
measurements = np.random.normal(loc = 20, scale = 5, size=100)   
stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()

# %%
df.groupby("label").count()
# Out:
#                        name  ratio.med.ctrl  label.ctrl  ratio.1.ctrl  \
# label
# Differential_ATAC     11432           11432       11432         11432
# Differential_H3K27ac  14617           14617       14617         14617
# NegCtl_Ilias_MPRA        54              54          54            54
# NegCtl_Vikram_MPRA       93              93          93            93
# Non-differential        117             117         117           117
# PosCtk_Vikram_MPRA       70              70          70            70
# PosCtl_Ilias_MPRA        58              58          58            58
# PosCtl_bj_luciferase     18              18          18            18
# Promoter_DEG            235             235         235           235
# Shuffle                 304             304         304           304
# Synthetic             31619           31619       31619         31619
#
#                       ratio.2.ctrl  ratio.3.ctrl  ratio.med.us  label.us  \
# label
# Differential_ATAC            11432         11432         11432     11432
# Differential_H3K27ac         14617         14617         14617     14617
# NegCtl_Ilias_MPRA               54            54            54        54
# NegCtl_Vikram_MPRA              93            93            93        93
# Non-differential               117           117           117       117
# PosCtk_Vikram_MPRA              70            70            70        70
# PosCtl_Ilias_MPRA               58            58            58        58
# PosCtl_bj_luciferase            18            18            18        18
# Promoter_DEG                   235           235           235       235
# Shuffle                        304           304           304       304
# Synthetic                    31619         31619         31619     31619
#
#                       ratio.1.us  ratio.2.us  ...  l2.ratio.mean.ctrl  \
# label                                         ...
# Differential_ATAC          11432       11432  ...               11432
# Differential_H3K27ac       14617       14617  ...               14617
# NegCtl_Ilias_MPRA             54          54  ...                  54
# NegCtl_Vikram_MPRA            93          93  ...                  93
# Non-differential             117         117  ...                 117
# PosCtk_Vikram_MPRA            70          70  ...                  70
# PosCtl_Ilias_MPRA             58          58  ...                  58
# PosCtl_bj_luciferase          18          18  ...                  18
# Promoter_DEG                 235         235  ...                 235
# Shuffle                      304         304  ...                 304
# Synthetic                  31619       31619  ...               31619
#
#                       l2.ratio.std.ctrl  l2.ratio.med.us  l2.ratio.mean.us  \
# label
# Differential_ATAC                 11432            11432             11432
# Differential_H3K27ac              14617            14617             14617
# NegCtl_Ilias_MPRA                    54               54                54
# NegCtl_Vikram_MPRA                   93               93                93
# Non-differential                    117              117               117
# PosCtk_Vikram_MPRA                   70               70                70
# PosCtl_Ilias_MPRA                    58               58                58
# PosCtl_bj_luciferase                 18               18                18
# Promoter_DEG                        235              235               235
# Shuffle                             304              304               304
# Synthetic                         31619            31619             31619
#
#                       l2.ratio.std.us  delta.med  delta.mean  -log10p    sig  \
# label
# Differential_ATAC               11432      11432       11432    11432  11432
# Differential_H3K27ac            14617      14617       14617    14617  14617
# NegCtl_Ilias_MPRA                  54         54          54       54     54
# NegCtl_Vikram_MPRA                 93         93          93       93     93
# Non-differential                  117        117         117      117    117
# PosCtk_Vikram_MPRA                 70         70          70       70     70
# PosCtl_Ilias_MPRA                  58         58          58       58     58
# PosCtl_bj_luciferase               18         18          18       18     18
# Promoter_DEG                      235        235         235      235    235
# Shuffle                           304        304         304      304    304
# Synthetic                       31619      31619       31619    31619  31619
#
#                        qual
# label
# Differential_ATAC     11432
# Differential_H3K27ac  14617
# NegCtl_Ilias_MPRA        54
# NegCtl_Vikram_MPRA       93
# Non-differential        117
# PosCtk_Vikram_MPRA       70
# PosCtl_Ilias_MPRA        58
# PosCtl_bj_luciferase     18
# Promoter_DEG            235
# Shuffle                 304
# Synthetic             31619
#
# [11 rows x 35 columns]

# %%
11432 + 235 + 14617
# Out:
# 26284

# %%
54+93+117+304
# Out:
# 568
