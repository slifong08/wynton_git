# %%
from Bio.SeqIO.FastaIO import SimpleFastaParser as sfp
import os, sys
import numpy as np
import pandas as pd

import config_readwrite as crw

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

import warnings
warnings.filterwarnings("ignore")
import plot_params as pp

pp.fonts()
# Out:
# ('sans-serif', 'Arial', 18)

# %% [markdown]
# # config

# %%
# read
config, cfn = crw.read(os.path.join(os.path.dirname(os.getcwd()), "config.ini"))

# %%
CL = "HEPG2"
DATAHEPG2 = config["mpra"][f'{CL}.clean.transformed'] 

CL = "BJ"
DATABJ = config["mpra"][f'{CL}.clean.transformed'] 

FASTA = config["mpra"]["fasta"]

MEME = config["meme"]["src"]
FIMO = config["fimo"]["src"]
RESULTS = config["path"]["results"]
BED = config["mpra"]["tile.bed"]

RE_MEME = os.path.join(RESULTS, "meme")
RE_MEME_CL = os.path.join(RE_MEME, CL)

# make the results
for dirname in [RE_MEME, RE_MEME_CL]:
    if os.path.exists(dirname) is False:
        os.mkdir(dirname)

# append meme path
sys.path.append(MEME)

# change directory 
os.chdir(RE_MEME_CL)

# %%
# write

section = "meme"

config[section][f'results'] = RE_MEME
config[section][CL] = RE_MEME_CL

crw.write(config, cfn)

# %% [markdown]
# # load data

# %%
def openAndFilter(file_name):
    df = pd.read_csv(file_name, sep='\t')  # (58333, 38)
    print("before filtering", file_name,  df.shape)
    df = df.loc[~df["label"].str.contains("Synthetic")].reset_index(
        drop=True)  # (26803, 38)
    print("filter out synthetics", df.shape)
    df = df.loc[~df["label"].str.contains("Pos")].reset_index(
        drop=True)  # (26659, 38)
    print("filter out positive controls", df.shape, '\n\n')

    return df

# %%
#hepg2 = openAndFilter(DATAHEPG2)
bj = openAndFilter(DATABJ)
# Out:
# before filtering /wynton/group/ahituv/fongsl/projects/US/data/full_bj_MPRA.clean.transformed.csv (58333, 38)
# filter out synthetics (26803, 38)
# filter out positive controls (26659, 38)

# %%
bj.shape
# Out:
# (26659, 38)

# %%
enh = pd.read_csv(BED, sep='\t')
enh.head()
# Out:
#                                 name              enh.id enh.name
# 0  hob_k27ac_down_chr1:826978-827247  chr1:826978-827704    enh.0
# 1  hob_k27ac_down_chr1:827110-827379  chr1:826978-827704    enh.0
# 2  hob_k27ac_down_chr1:827377-827646  chr1:826978-827704    enh.0
# 3  hob_k27ac_down_chr1:827435-827704  chr1:826978-827704    enh.0
# 4  hob_k27ac_down_chr1:827891-828160  chr1:827891-828160    enh.1

# %%
bj = pd.merge(bj, enh, how="left")

# %% [markdown]
# # add direction

# %%
def labelDirection(df):

    """label sequences with different directions of change between US and Control
    note

    neg.US_UP == US MPRA activity is negative, but less negative than CTRL MPRA activity, which is also negative
    pos.US_UP  == US MPRA activity is positive and more positive than CTRL MPRA activity, which is also positive. 
    US_UP == US activity is positive and higher than CTRL MPRA activity, which is negative. 
    """
    df["direction"] = None

    # Pos values only
    df.loc[(df["l2.ratio.mean.us"] > 0) &
           (df["l2.ratio.mean.ctrl"] > 0) &
           (df["delta.mean"] > 0),
           "direction"] = "Pos.US_UP"

    df.loc[(df["l2.ratio.mean.us"] > 0) &
           (df["l2.ratio.mean.ctrl"] > 0) &
           (df["delta.mean"] < 0),
           "direction"] = "Pos.CTRL_UP"

    # Negtaive values only
    df.loc[(df["l2.ratio.mean.us"] < 0) &
           (df["l2.ratio.mean.ctrl"] < 0) &
           (df["delta.mean"] > 0),
           "direction"] = "Neg.CTRL_DOWN"

    df.loc[(df["l2.ratio.mean.us"] < 0) &
           (df["l2.ratio.mean.ctrl"] < 0) &
           (df["delta.mean"] < 0),
           "direction"] = "Neg.US_DOWN"

    # crossing zero values only
    df.loc[(df["l2.ratio.mean.us"] > 0) &
           (df["l2.ratio.mean.ctrl"] < 0) &
           (df["delta.mean"] > 0),
           "direction"] = "US_UP"

    df.loc[(df["l2.ratio.mean.us"] < 0) &
           (df["l2.ratio.mean.ctrl"] > 0) &
           (df["delta.mean"] < 0),
           "direction"] = "CTRL_UP"

    print(df.loc[df["direction"] != None, ["l2.ratio.mean.ctrl",
          "l2.ratio.mean.us", 'delta.mean', "direction"]].sample(n=20))
    return df

# %%
bj = labelDirection(bj)
# Out:
#        l2.ratio.mean.ctrl  l2.ratio.mean.us  delta.mean      direction
# 8606             0.854922          0.970054    0.115132      Pos.US_UP
# 15147           -1.437165         -1.380124    0.057042  Neg.CTRL_DOWN
# 20310            0.332450          0.315237   -0.017214    Pos.CTRL_UP
# 9839             0.030963          0.085298    0.054334      Pos.US_UP
# 13136            0.082647          0.201773    0.119126      Pos.US_UP
# 1688            -0.567059         -0.269407    0.297653  Neg.CTRL_DOWN
# 8812            -0.399015         -0.479672   -0.080657    Neg.US_DOWN
# 14016            0.230165          0.180243   -0.049922    Pos.CTRL_UP
# 10733            0.193859          0.277830    0.083970      Pos.US_UP
# 24734            0.244664          0.247009    0.002345      Pos.US_UP
# 26376            0.192540          0.187703   -0.004837    Pos.CTRL_UP
# 20621            0.157396          0.142968   -0.014428    Pos.CTRL_UP
# 5197             0.287394          0.618321    0.330927      Pos.US_UP
# 10849            0.633332          0.679236    0.045904      Pos.US_UP
# 7538             0.341938          0.197506   -0.144432    Pos.CTRL_UP
# 18911           -0.411419         -0.438037   -0.026618    Neg.US_DOWN
# 19435            0.383292          0.358079   -0.025213    Pos.CTRL_UP
# 19556            0.173213          0.127968   -0.045245    Pos.CTRL_UP
# 3331             0.335724          0.220616   -0.115108    Pos.CTRL_UP
# 4514             0.576925          0.603391    0.026467      Pos.US_UP

# %%
set(bj["label"])
# Out:
# {'Differential_ATAC',
#  'Differential_H3K27ac',
#  'NegCtl_Ilias_MPRA',
#  'NegCtl_Vikram_MPRA',
#  'Non-differential',
#  'Promoter_DEG',
#  'Shuffle'}

# %% [markdown]
# # make fasta from luc

# %%
LUC="/wynton/group/ahituv/fongsl/projects/US/data/validation_luc/Candidate_ID_table_luc.txt"

luc = pd.read_csv(LUC, sep='\t')

luc.head()

luc_names = luc[["Sample name", "insert"]].copy()

luc_in_bj = pd.merge(bj, luc_names, left_on="name", right_on="insert")

luc_mpra_names=set(luc_in_bj["name"])

# %%
luc_in_bj
# Out:
#     Unnamed: 0     seq.id                                       name  \
# 0           13  seq.73727      hob_k27ac_up_chr2:145036567-145036836
# 1           16  seq.43954  hepg2_atac_down_chr10:109895366-109895635
# 2           44  seq.54465        hob_atac_up_chr22:41305657-41305926
# 3           85  seq.70398       hob_k27ac_up_chr12:32115256-32115525
# 4           94  seq.64864    hob_k27ac_down_chr2:172439092-172439361
# 5          110  seq.52945        hob_atac_up_chr18:11954494-11954763
# 6          126  seq.43392         bj_k27ac_up_chr4:53763341-53763610
# 7          135  seq.48100      hepg2_atac_up_chr16:82223879-82224148
# 8          296  seq.54392        hob_atac_up_chr22:30250826-30251095
# 9          346  seq.55039       hob_atac_up_chr3:127734774-127735043
# 10        1457  seq.81836          k562_atac_up_chr7:1917897-1918166
# 11        2717  seq.56315           hob_atac_up_chr7:4689923-4690192
# 12        9043  seq.52959        hob_atac_up_chr18:24076189-24076458
# 13        9525  seq.40696      bj_atac_down_chr1:147640884-147641153
# 14       12498  seq.52924        hob_atac_up_chr17:82288410-82288679
# 15       13947  seq.45501     hepg2_atac_down_chr1:41417200-41417469
# 16       16160  seq.59536     hob_k27ac_down_chr15:75844211-75844480
# 17       25938  seq.50236      hob_atac_down_chr14:73472122-73472391
# 18       33968  seq.80692       k562_atac_up_chr13:25406382-25406651
# 19       38848  seq.59840       hob_k27ac_down_chr16:2904526-2904795
# 20       43067  seq.46102   hepg2_atac_down_chr2:237298688-237298957
# 21       43443  seq.52797            hob_atac_up_chr17:538152-538421
# 22       44284  seq.54604       hob_atac_up_chr2:127153718-127153987
# 23       48995  seq.76242        hob_k27ac_up_chr4:94561079-94561348
# 24       51572  seq.48110      hepg2_atac_up_chr16:85650086-85650355
#
#                                     name_mpra                 label  \
# 0       hob_k27ac_up_chr2:145036567-145036836  Differential_H3K27ac
# 1   hepg2_atac_down_chr10:109895366-109895635     Differential_ATAC
# 2         hob_atac_up_chr22:41305657-41305926     Differential_ATAC
# 3        hob_k27ac_up_chr12:32115256-32115525  Differential_H3K27ac
# 4     hob_k27ac_down_chr2:172439092-172439361  Differential_H3K27ac
# 5         hob_atac_up_chr18:11954494-11954763     Differential_ATAC
# 6          bj_k27ac_up_chr4:53763341-53763610  Differential_H3K27ac
# 7       hepg2_atac_up_chr16:82223879-82224148     Differential_ATAC
# 8         hob_atac_up_chr22:30250826-30251095     Differential_ATAC
# 9        hob_atac_up_chr3:127734774-127735043     Differential_ATAC
# 10          k562_atac_up_chr7:1917897-1918166     Differential_ATAC
# 11           hob_atac_up_chr7:4689923-4690192     Differential_ATAC
# 12        hob_atac_up_chr18:24076189-24076458     Differential_ATAC
# 13      bj_atac_down_chr1:147640884-147641153     Differential_ATAC
# 14        hob_atac_up_chr17:82288410-82288679     Differential_ATAC
# 15     hepg2_atac_down_chr1:41417200-41417469     Differential_ATAC
# 16     hob_k27ac_down_chr15:75844211-75844480  Differential_H3K27ac
# 17      hob_atac_down_chr14:73472122-73472391     Differential_ATAC
# 18       k562_atac_up_chr13:25406382-25406651     Differential_ATAC
# 19       hob_k27ac_down_chr16:2904526-2904795  Differential_H3K27ac
# 20   hepg2_atac_down_chr2:237298688-237298957     Differential_ATAC
# 21            hob_atac_up_chr17:538152-538421     Differential_ATAC
# 22       hob_atac_up_chr2:127153718-127153987     Differential_ATAC
# 23        hob_k27ac_up_chr4:94561079-94561348  Differential_H3K27ac
# 24      hepg2_atac_up_chr16:85650086-85650355     Differential_ATAC
#
#     ratio.med.ctrl  label.ctrl  ratio.1.ctrl  ratio.2.ctrl  ratio.3.ctrl  ...  \
# 0         1.211559           0      1.207158      1.202002      1.225516  ...
# 1         1.300464           1      1.311166      1.255859      1.334368  ...
# 2         1.496837           1      1.487212      1.547266      1.456031  ...
# 3         1.268955           1      1.275983      1.269347      1.261534  ...
# 4         0.976388           0      1.018962      0.913553      0.996649  ...
# 5         1.128283           0      1.167571      1.106923      1.110353  ...
# 6         0.958684           0      1.036729      0.886585      0.952739  ...
# 7         1.228786           0      1.222346      1.231004      1.233009  ...
# 8         0.909094           0      0.907138      0.914107      0.906036  ...
# 9         1.233940           1      1.170351      1.271645      1.259825  ...
# 10        0.981713           0      0.976047      0.968317      1.000776  ...
# 11        1.141180           0      1.075330      1.112379      1.235830  ...
# 12        1.157025           0      1.100432      1.125586      1.245057  ...
# 13        1.178266           0      1.174792      1.130981      1.229023  ...
# 14        1.223041           0      1.155212      1.291032      1.222878  ...
# 15        1.167343           0      1.099421      1.156052      1.246555  ...
# 16        1.100003           0      1.070563      1.260794      0.968653  ...
# 17        1.289611           0      1.717880      1.208980      0.941974  ...
# 18        1.214141           0      1.194334      1.345647      1.102442  ...
# 19        1.229648           1      1.031439      1.295336      1.362168  ...
# 20        1.020831           0      1.000032      1.039402      1.023059  ...
# 21        1.057372           0      1.072984      1.238588      0.860544  ...
# 22        1.058487           0      0.984246      1.161005      1.030211  ...
# 23        1.319003           1      1.306787      1.226937      1.423285  ...
# 24        1.215603           0      1.222992      1.340570      1.083248  ...
#
#     l2.ratio.mean.us  l2.ratio.std.us  delta.med  delta.mean    direction  \
# 0           0.383905         0.013249   0.119904    0.107091    Pos.US_UP
# 1           0.004605         0.056796  -0.367063   -0.373955  Pos.CTRL_UP
# 2           0.193178         0.078497  -0.344518   -0.388280  Pos.CTRL_UP
# 3           0.188152         0.023721  -0.142433   -0.155474  Pos.CTRL_UP
# 4           0.412671         0.077964   0.409919    0.448732        US_UP
# 5           0.534846         0.061431   0.400501    0.361151    Pos.US_UP
# 6           0.431428         0.041973   0.520849    0.495254        US_UP
# 7           0.444580         0.020841   0.142174    0.147356    Pos.US_UP
# 8           0.352798         0.066372   0.457605    0.490308        US_UP
# 9           0.046174         0.070419  -0.250444   -0.256113  Pos.CTRL_UP
# 10          0.399422         0.134684   0.493845    0.426191        US_UP
# 11          0.694709         0.225765   0.602428    0.506739    Pos.US_UP
# 12          0.090071         0.073504  -0.098251   -0.118249  Pos.CTRL_UP
# 13          0.103483         0.118988  -0.184291   -0.132348  Pos.CTRL_UP
# 14          0.369432         0.056821   0.087756    0.080444    Pos.US_UP
# 15          0.105866         0.120700  -0.077622   -0.115433  Pos.CTRL_UP
# 16         -0.046428         0.147430  -0.221150   -0.175345      CTRL_UP
# 17          0.078623         0.289555  -0.079836   -0.244103  Pos.CTRL_UP
# 18          0.344949         0.140654   0.069304    0.069879    Pos.US_UP
# 19          0.158551         0.350293  -0.291416   -0.129412  Pos.CTRL_UP
# 20          0.037496         0.026253   0.005544    0.007933    Pos.US_UP
# 21          0.011191         0.167915   0.004728   -0.053357  Pos.CTRL_UP
# 22          0.124540         0.341155   0.239088    0.046072    Pos.US_UP
# 23          0.382296         0.066875  -0.020405   -0.014474  Pos.CTRL_UP
# 24          0.251414         0.196139   0.011094   -0.024795  Pos.CTRL_UP
#
#      -log10p                     enh.id  enh.name  Sample name  \
# 0   3.121102   chr2:145036567-145037368  enh.6060        BJ_U1
# 1   2.961901  chr10:109895366-109895767  enh.1411        BJ_D2
# 2   2.382040    chr22:41305657-41306058  enh.7141        BJ_D1
# 3   2.409182    chr12:32115124-32116051  enh.2181        BJ_D5
# 4   2.608324   chr2:172438825-172439626  enh.6145        BJ_U6
# 5   2.746125    chr18:11954428-11954829  enh.4804        BJ_U4
# 6   2.015071     chr4:53763341-53764193  enh.8052        BJ_U8
# 7   2.446827    chr16:82223879-82224280  enh.4049        BJ_U2
# 8   2.249283    chr22:30250694-30251095  enh.7063        BJ_U7
# 9   1.996580   chr3:127734708-127735109  enh.7677        BJ_D3
# 10  1.547722       chr7:1917765-1918166  enh.9580        BJ_U5
# 11  1.370014       chr7:4689791-4690192  enh.9599        BJ_U9
# 12  0.776025    chr18:24076189-24076590  enh.4838     Hepg2_D7
# 13  0.732188   chr1:147640752-147641153   enh.608     Hepg2_D4
# 14  0.625900    chr17:82288344-82288745  enh.4745     Hepg2_U1
# 15  0.582245     chr1:41417068-41417469   enh.311     Hepg2_U3
# 16  0.549625    chr15:75843679-75844480  enh.3499     Hepg2_U7
# 17  0.327477    chr14:73472055-73472456  enh.3091     Hepg2_D3
# 18  0.235804    chr13:25406316-25406717  enh.2618     Hepg2_U2
# 19  0.207861      chr16:2904127-2904928  enh.3693     Hepg2_U6
# 20  0.131631   chr2:237298688-237299089  enh.6439     Hepg2_D8
# 21  0.104983        chr17:538152-538553  enh.4141     Hepg2_D1
# 22  0.074440   chr2:127153651-127154052  enh.6006     Hepg2_D5
# 23  0.068315     chr4:94561079-94561880  enh.8145     Hepg2_D9
# 24  0.059412    chr16:85650019-85650420  enh.4082     Hepg2_U5
#
#                                        insert
# 0       hob_k27ac_up_chr2:145036567-145036836
# 1   hepg2_atac_down_chr10:109895366-109895635
# 2         hob_atac_up_chr22:41305657-41305926
# 3        hob_k27ac_up_chr12:32115256-32115525
# 4     hob_k27ac_down_chr2:172439092-172439361
# 5         hob_atac_up_chr18:11954494-11954763
# 6          bj_k27ac_up_chr4:53763341-53763610
# 7       hepg2_atac_up_chr16:82223879-82224148
# 8         hob_atac_up_chr22:30250826-30251095
# 9        hob_atac_up_chr3:127734774-127735043
# 10          k562_atac_up_chr7:1917897-1918166
# 11           hob_atac_up_chr7:4689923-4690192
# 12        hob_atac_up_chr18:24076189-24076458
# 13      bj_atac_down_chr1:147640884-147641153
# 14        hob_atac_up_chr17:82288410-82288679
# 15     hepg2_atac_down_chr1:41417200-41417469
# 16     hob_k27ac_down_chr15:75844211-75844480
# 17      hob_atac_down_chr14:73472122-73472391
# 18       k562_atac_up_chr13:25406382-25406651
# 19       hob_k27ac_down_chr16:2904526-2904795
# 20   hepg2_atac_down_chr2:237298688-237298957
# 21            hob_atac_up_chr17:538152-538421
# 22       hob_atac_up_chr2:127153718-127153987
# 23        hob_k27ac_up_chr4:94561079-94561348
# 24      hepg2_atac_up_chr16:85650086-85650355
#
# [25 rows x 42 columns]

# %% [markdown]
# # US up - BJ

# %%
EXP_NAME ="exp5.luc"
DIRECTION = "US_UP"
df = bj

# %%
def getDfDirectionSub(df, direction):
    """subset dataframe by directino of effect"""
    
    cols = ["name", "label", "l2.ratio.mean.ctrl",
        'l2.ratio.mean.us', "delta.mean", "direction"]

    df = df.loc[df["direction"] == direction, cols].sort_values(by='l2.ratio.mean.us', ascending=False).copy()

    return df



def makeFasta(names, direction, re, exp_name, fa):
    """write fastas for each quantile based on list of sequence names"""
    
    
    # files to write
    FA = os.path.join(re, f"{exp_name}.{direction}.fa")

    
    # write positive, negative names and sequences

    fa_writer = open(FA, "w") # open fa file to write

    with open(fa, "r") as reader:  # open the full fa file
        for value in sfp(reader):
            seq_id, seq = value  # get sequence id, sequence
            if seq_id in names:  # filter for sequences in pos/neg name list
                fa_writer.write(f'>{seq_id}\n{seq}\n')  # write those sequences to fa
    fa_writer.close()
        
    return FA

def runFimo(fimo, meme_txt, fa, direction, exp):

    OUTDIR = f"./fimo/{direction}.{exp}"
    cmd = " ".join([fimo,
                    "--oc",
                    OUTDIR,
                    meme_txt,
                    fa,

                    ])
    os.system(cmd)

    return OUTDIR

# %%
# make fa of luc names
FA = makeFasta(luc_mpra_names,  DIRECTION, RE_MEME_CL, EXP_NAME, FASTA)

plot = luc_in_bj
# fig,ax = plt.subplots(figsize=(6,6))
hue_order = ['US_UP',
             'CTRL_UP',
             'Neg.US_DOWN',
             'Neg.CTRL_DOWN',
             'Pos.US_UP',
             'Pos.CTRL_UP',
             ]

g = sns.jointplot(x="l2.ratio.mean.ctrl", y="l2.ratio.mean.us",
                  data=plot, hue="direction", hue_order=hue_order,
                  palette='tab20'
                 )
g.ax_joint.legend(frameon=False, bbox_to_anchor=(2, 1))

# %% [markdown]
# ## functions

# %% [markdown]
#         bottom 0.1 US_UP bkgd discovered motifs
#         CAGRCTCTCS
#         CCTGKRTGWGW
#         GAGRAGVMAGCMK
#
#         bottom0.1 US_UP and shuffle bkgd
#         AGGAGGMAGC
#         AGRSCCCAGC
#         CARRCTCTCCT

# %%
TOP_QUANTILE =0.9
MEME_TXT = os.path.join(RE_MEME_CL, f"{CL}.{DIRECTION}.{TOP_QUANTILE}.meme.txt")

# %%
OUTDIR_LUC=  runFimo(FIMO, MEME_TXT, FA, DIRECTION, EXP_NAME)
# Out:
# Using motif +CCCWGGCYCCTGC of width 13.
# Using motif -CCCWGGCYCCTGC of width 13.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.873233
# #   Estimated pi_0=0.886667
# Using motif +ASHCWGGMCTGG of width 12.
# Using motif -ASHCWGGMCTGG of width 12.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.943673
# #   Estimated pi_0=0.955169
# Using motif +CAGCWKYYCC of width 10.
# Using motif -CAGCWKYYCC of width 10.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.956063
# #   Estimated pi_0=0.961379

# %%
bottom_pred = os.path.join(OUTDIR_LUC, "fimo.tsv")


bdf = pd.read_csv(bottom_pred, sep='\t')
bdf["quantile"] = 'luc'
bdf["-log10q"]  = -1*np.log10(bdf["q-value"])
print(bdf.shape)


# concatenate the top and bottom values
plot = bdf

fig, ax= plt.subplots( figsize = (6,6))
sns.violinplot(x="motif_alt_id", y='-log10q', data= plot, hue="quantile", 
               order = ["MEME-1", "MEME-2", "MEME-3"])
#ax.set(ylim=(-0.10,2.75))
ax.legend(frameon=False, loc='upper left')
# Out:
# (35, 12)

# %%
IDS = ["MEME-1", "MEME-2", "MEME-3"]
VAL =  "-log10q" #"score"
for ID in IDS: 

    a = tdf.loc[tdf["motif_alt_id"]==ID, VAL]
    b = bdf.loc[bdf["motif_alt_id"]==ID, VAL]
    print(ID, stats.mannwhitneyu(a,b))
# Out:
# MEME-1 MannwhitneyuResult(statistic=2652.0, pvalue=6.210636942609216e-19)
# MEME-2 MannwhitneyuResult(statistic=1315.0, pvalue=2.2145117248723797e-12)
# MEME-3 MannwhitneyuResult(statistic=960.0, pvalue=9.412096742042295e-12)

# %% [markdown]
# ## Experiment 2: are motifs discovered in US_UP also discovered in POS.US_UP?
#     - hypothesis: top motifs in us_up are also driving increased activity in pos.US_up.
#     - approach: use FIMO to discover US_UP motifs in other data.
#     - data universe: sequences with positive baseline activity that increase activity w/ US

# %%
EXP_NAME ="exp2"
DIRECTION = "Pos.US_UP"

# %% [markdown]
# ### pos.us_up sequences only

# %%
### subset df by direction. 

df_dir = getDfDirectionSub(df, DIRECTION)

### top and bottom 10% of direction changes. 

# top quantile of delta.means, no shuffle data leakage
pos, pos_names, neg, neg_names = getQuantileDelta(df_dir, TOP_QUANTILE, df, False)

plot = pd.concat([pos, neg])
# fig,ax = plt.subplots(figsize=(6,6))
hue_order = ['US_UP',
             'CTRL_UP',
             'Neg.US_DOWN',
             'Neg.CTRL_DOWN',
             'Pos.US_UP',
             'Pos.CTRL_UP',
             ]

g = sns.jointplot(x="l2.ratio.mean.ctrl", y="l2.ratio.mean.us",
                  data=plot, hue="direction", hue_order=hue_order,
                  palette='tab20'
                 )
g.ax_joint.legend(frameon=False, bbox_to_anchor=(2, 1))

# %% [markdown]
# ### clean up data leakage
# - tiled enhancers which may have overlapping information

# %%
def getEnhSet(df, name_set):
    enh_names = df.loc[df["name"].isin(name_set), "enh.name"].unique()
    linkedtiles = df.loc[df["enh.name"].isin(enh_names), "name"].unique()
    
    return enh_names, linkedtiles

# %%
# get enh ids, linked tiles from exp1 dataset
exp1pos_enhnames, exp1pos_linkedtiles = getEnhSet(bj, exp1up)
exp1neg_enhnames, exp1neg_linkedtiles = getEnhSet(bj, exp1down)

# %%
# remove exp 1 linked tiles
pos_names_clean = set(pos_names).difference(set(exp1pos_linkedtiles))
neg_names_clean = set(neg_names).difference(set(exp1neg_linkedtiles))

# make fasta files from quantiles. 
FA_POS, FA_NEG = makeQuantileFasta(pos_names_clean, neg_names_clean, DIRECTION, RE_MEME_CL, TOP_QUANTILE, EXP_NAME, FASTA)

# add to config
config[section][f'{CL}.{DIRECTION}.{TOP_QUANTILE}.fa'] = FA_POS
config[section][f'{CL}.{DIRECTION}.{BOTTOM_QUANTILE}.fa'] = FA_NEG

crw.write(config, cfn)

# %% [markdown]
# ### sanity check

# %%
shuf = bj.loc[bj["label"] == "Shuffle"]
genome = bj.loc[bj["label"] != "Shuffle"]

fig, ax = plt.subplots()

"""
sns.histplot(x="delta.mean", data=df_dir,
             label=f"{DIRECTION}", stat="percent", kde=True,
             color="w", common_norm=False
            )
            
"""
sns.histplot(x="delta.mean", data=shuf, label="shuffle", kde=True,
             stat="percent", color="grey", common_norm=False)
sns.histplot(x="delta.mean", data=pos, label=f"{DIRECTION} top {TOP_QUANTILE}",
             kde=True,common_norm=False,
             stat="percent")
sns.histplot(x="delta.mean", data=neg, label=f"{DIRECTION} bottom {BOTTOM_QUANTILE}",
             kde=True,common_norm=False,
             stat="percent")
plt.legend(frameon=False, loc="upper left")



shuf["delta.mean"].quantile(0.975), pos["delta.mean"].describe()
# Out:
# (0.22299430179288693,
#  count    938.000000
#  mean       0.199157
#  std        0.065295
#  min        0.134542
#  25%        0.150366
#  50%        0.178526
#  75%        0.226405
#  max        0.558532
#  Name: delta.mean, dtype: float64)

# %% [markdown]
# ## Fimo

# %% [markdown]
# ### top

# %%
OUTDIR_TOP =  runFimo(FIMO, MEME_TXT, FA_POS, DIRECTION, TOP_QUANTILE)
OUTDIR_BOTTOM =  runFimo(FIMO, MEME_TXT, FA_NEG, DIRECTION, BOTTOM_QUANTILE)
# Out:
# Using motif +CCCWGGCYCCTGC of width 13.
# Using motif -CCCWGGCYCCTGC of width 13.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.862857
# #   Estimated pi_0=0.869155
# Using motif +ASHCWGGMCTGG of width 12.
# Using motif -ASHCWGGMCTGG of width 12.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.947778
# #   Estimated pi_0=0.95557
# Using motif +CAGCWKYYCC of width 10.
# Using motif -CAGCWKYYCC of width 10.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.952387
# #   Estimated pi_0=0.958256
# Using motif +CCCWGGCYCCTGC of width 13.
# Using motif -CCCWGGCYCCTGC of width 13.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.997273
# #   Estimated pi_0=0.997789
# Using motif +ASHCWGGMCTGG of width 12.
# Using motif -ASHCWGGMCTGG of width 12.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.997462
# #   Estimated pi_0=0.998593
# Using motif +CAGCWKYYCC of width 10.
# Using motif -CAGCWKYYCC of width 10.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.991412
# #   Estimated pi_0=0.995612

# %% [markdown]
# ### FET enrichment

# %%
OUTDIR_BOTTOM
# Out:
# './fimo/Pos.US_UP.0.1'

# %%
bottom_pred = os.path.join(OUTDIR_BOTTOM, "fimo.tsv")
top_pred = os.path.join(OUTDIR_TOP, "fimo.tsv")

tdf = pd.read_csv(top_pred, sep='\t')
tdf["quantile"] = 'top0.9'
tdf["-log10q"]  = -1*np.log10(tdf["q-value"])
print(tdf.shape)
tdf.head()

bdf = pd.read_csv(bottom_pred, sep='\t')
bdf["quantile"] = 'bottom0.1'
bdf["-log10q"]  = -1*np.log10(bdf["q-value"])
print(bdf.shape)
bdf.head()

# concatenate the top and bottom values
plot = pd.concat([tdf, bdf])

fig, ax= plt.subplots( figsize = (6,6))
sns.violinplot(x="motif_alt_id", y='-log10q', data= plot, hue="quantile", 
               order = ["MEME-1", "MEME-2", "MEME-3"])
ax.set(ylim=(-0.10,2.75))
ax.legend(frameon=False, loc='upper left')
# Out:
# (1296, 12)
# (365, 12)

# %%
IDS = ["MEME-1", "MEME-2", "MEME-3"]
VAL =  "-log10q" #"score"
for ID in IDS: 

    a = tdf.loc[tdf["motif_alt_id"]==ID, VAL]
    b = bdf.loc[bdf["motif_alt_id"]==ID, VAL]
    print(ID, stats.mannwhitneyu(a,b))
# Out:
# MEME-1 MannwhitneyuResult(statistic=108957.5, pvalue=5.33738127954429e-81)
# MEME-2 MannwhitneyuResult(statistic=35482.0, pvalue=1.3874096384246275e-34)
# MEME-3 MannwhitneyuResult(statistic=19648.0, pvalue=1.6020190340314663e-33)

# %% [markdown]
# ## experiment 3 - loss of enrichmetn in CTRL_UP

# %%
EXP_NAME ="exp3"
DIRECTION = "CTRL_UP"

### subset df by direction. 

df_dir = getDfDirectionSub(df, DIRECTION)

### top and bottom 10% of direction changes. 

# top quantile of delta.means
pos, pos_names, neg, neg_names = getQuantileDelta(df_dir, TOP_QUANTILE, df, False)

plot = pd.concat([pos, neg])
# fig,ax = plt.subplots(figsize=(6,6))
hue_order = ['US_UP',
             'CTRL_UP',
             'Neg.US_DOWN',
             'Neg.CTRL_DOWN',
             'Pos.US_UP',
             'Pos.CTRL_UP',
             ]

g = sns.jointplot(x="l2.ratio.mean.ctrl", y="l2.ratio.mean.us",
                  data=plot, hue="direction", hue_order=hue_order,
                  palette='tab20'
                 )
g.ax_joint.legend(frameon=False, bbox_to_anchor=(2, 1))

# %%
# get enh ids, linked tiles from exp1 dataset
exp1pos_enhnames, exp1pos_linkedtiles = getEnhSet(bj, exp1up)
exp1neg_enhnames, exp1neg_linkedtiles = getEnhSet(bj, exp1down)

# %%
# remove exp 1 linked tiles
pos_names_clean = set(pos_names).difference(set(exp1pos_linkedtiles))
neg_names_clean = set(neg_names).difference(set(exp1neg_linkedtiles))

# make fasta files from quantiles. 
FA_POS, FA_NEG = makeQuantileFasta(pos_names_clean, neg_names_clean, DIRECTION, RE_MEME_CL, TOP_QUANTILE, EXP_NAME, FASTA)


# add to config
config[section][f'{CL}.{DIRECTION}.{TOP_QUANTILE}.fa'] = FA_POS
config[section][f'{CL}.{DIRECTION}.{BOTTOM_QUANTILE}.fa'] = FA_NEG

crw.write(config, cfn)

shuf = bj.loc[bj["label"] == "Shuffle"]
genome = bj.loc[bj["label"] != "Shuffle"]

fig, ax = plt.subplots()

"""
sns.histplot(x="delta.mean", data=df_dir,
             label=f"{DIRECTION}", stat="percent", kde=True,
             color="w", common_norm=False
            )
            
"""
sns.histplot(x="delta.mean", data=shuf, label="shuffle", kde=True,
             stat="percent", color="grey", common_norm=False)
sns.histplot(x="delta.mean", data=pos, label=f"{DIRECTION} top {TOP_QUANTILE}",
             kde=True,common_norm=False, #color="orange", 
             stat="percent")
sns.histplot(x="delta.mean", data=neg, label=f"{DIRECTION} bottom {BOTTOM_QUANTILE}",
             kde=True,common_norm=False, #color="blue",
             stat="percent")
plt.legend(frameon=False, loc="upper left")

shuf["delta.mean"].quantile(0.975), pos["delta.mean"].describe()

pos.describe(), neg.describe()

# %%
OUTDIR_TOP =  runFimo(FIMO, MEME_TXT, FA_POS, DIRECTION, TOP_QUANTILE)
OUTDIR_BOTTOM =  runFimo(FIMO, MEME_TXT, FA_NEG, DIRECTION, BOTTOM_QUANTILE)
# Out:
# Using motif +CCCWGGCYCCTGC of width 13.
# Using motif -CCCWGGCYCCTGC of width 13.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.99171
# #   Estimated pi_0=0.995075
# Using motif +ASHCWGGMCTGG of width 12.
# Using motif -ASHCWGGMCTGG of width 12.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.994316
# #   Estimated pi_0=0.996683
# Using motif +CAGCWKYYCC of width 10.
# Using motif -CAGCWKYYCC of width 10.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.992165
# #   Estimated pi_0=0.995939
# Using motif +CCCWGGCYCCTGC of width 13.
# Using motif -CCCWGGCYCCTGC of width 13.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.808515
# #   Estimated pi_0=0.81552
# Using motif +ASHCWGGMCTGG of width 12.
# Using motif -ASHCWGGMCTGG of width 12.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.908
# #   Estimated pi_0=0.917391
# Using motif +CAGCWKYYCC of width 10.
# Using motif -CAGCWKYYCC of width 10.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.923252
# #   Estimated pi_0=0.942874

# %%
bottom_pred = os.path.join(OUTDIR_BOTTOM, "fimo.tsv")
top_pred = os.path.join(OUTDIR_TOP, "fimo.tsv")

tdf = pd.read_csv(top_pred, sep='\t')
tdf["quantile"] = 'top0.9'
tdf["-log10q"] = -1*np.log10(tdf["q-value"])
print(tdf.shape)
tdf.head()

bdf = pd.read_csv(bottom_pred, sep='\t')
bdf["quantile"] = 'bottom0.1'
bdf["-log10q"] = -1*np.log10(bdf["q-value"])
print(bdf.shape)
bdf.head()

# concatenate the top and bottom values
plot = pd.concat([tdf, bdf])

fig, ax = plt.subplots(figsize=(6, 6))
sns.violinplot(x="motif_alt_id", y='-log10q', data=plot, hue="quantile",
               #hue_order=["bottom0.1", "top0.1"],
               order=["MEME-1", "MEME-2", "MEME-3"])
ax.set(ylim=(-0.20,2.75))
ax.legend(frameon=False, loc='upper left')
# Out:
# (39, 12)
# (82, 12)

# %%
IDS = ["MEME-1", "MEME-2", "MEME-3"]
VAL =  "-log10q" #"score"
for ID in IDS: 

    a = tdf.loc[tdf["motif_alt_id"]==ID, VAL]
    b = bdf.loc[bdf["motif_alt_id"]==ID, VAL]
    print(ID, stats.mannwhitneyu(a,b))
# Out:
# MEME-1 MannwhitneyuResult(statistic=0.0, pvalue=7.2495772253943295e-09)
# MEME-2 MannwhitneyuResult(statistic=83.0, pvalue=0.0034984880529447533)
# MEME-3 MannwhitneyuResult(statistic=0.0, pvalue=0.0008314763155539484)

# %% [markdown]
# ## experiment 4

# %%
EXP_NAME ="exp4"
DIRECTION = "Pos.CTRL_UP"

### subset df by direction. 

df_dir = getDfDirectionSub(df, DIRECTION)

### top and bottom 10% of direction changes. 

# top quantile of delta.means
pos, pos_names, neg, neg_names = getQuantileDelta(df_dir, TOP_QUANTILE, df, False)

plot = pd.concat([pos, neg])
# fig,ax = plt.subplots(figsize=(6,6))
hue_order = ['US_UP',
             'CTRL_UP',
             'Neg.US_DOWN',
             'Neg.CTRL_DOWN',
             'Pos.US_UP',
             'Pos.CTRL_UP',
             ]

g = sns.jointplot(x="l2.ratio.mean.ctrl", y="l2.ratio.mean.us",
                  data=plot, hue="direction", hue_order=hue_order,
                  palette='tab20'
                 )
g.ax_joint.legend(frameon=False, bbox_to_anchor=(2, 1))

# %%
# get enh ids, linked tiles from exp1 dataset
exp1pos_enhnames, exp1pos_linkedtiles = getEnhSet(bj, exp1up)
exp1neg_enhnames, exp1neg_linkedtiles = getEnhSet(bj, exp1down)

# %%
# remove exp 1 linked tiles
pos_names_clean = set(pos_names).difference(set(exp1pos_linkedtiles))
neg_names_clean = set(neg_names).difference(set(exp1neg_linkedtiles))

# make fasta files from quantiles. 
FA_POS, FA_NEG = makeQuantileFasta(pos_names_clean, neg_names_clean, DIRECTION, RE_MEME_CL, TOP_QUANTILE, EXP_NAME, FASTA)


# add to config
config[section][f'{CL}.{DIRECTION}.{TOP_QUANTILE}.fa'] = FA_POS
config[section][f'{CL}.{DIRECTION}.{BOTTOM_QUANTILE}.fa'] = FA_NEG

crw.write(config, cfn)

shuf = bj.loc[bj["label"] == "Shuffle"]
genome = bj.loc[bj["label"] != "Shuffle"]

fig, ax = plt.subplots()

"""
sns.histplot(x="delta.mean", data=df_dir,
             label=f"{DIRECTION}", stat="percent", kde=True,
             color="w", common_norm=False
            )
            
"""
sns.histplot(x="delta.mean", data=shuf, label="shuffle", kde=True,
             stat="percent", color="grey", common_norm=False)
sns.histplot(x="delta.mean", data=pos, label=f"{DIRECTION} top {TOP_QUANTILE}",
             kde=True,common_norm=False, #color="orange", 
             stat="percent")
sns.histplot(x="delta.mean", data=neg, label=f"{DIRECTION} bottom {BOTTOM_QUANTILE}",
             kde=True,common_norm=False, #color="blue",
             stat="percent")
plt.legend(frameon=False, loc="upper left")

shuf["delta.mean"].quantile(0.975), pos["delta.mean"].describe()

pos.describe(), neg.describe()
# Out:
# (       l2.ratio.mean.ctrl  l2.ratio.mean.us  delta.mean
#  count          665.000000        665.000000  665.000000
#  mean             0.295332          0.292508   -0.002824
#  std              0.145520          0.145534    0.001560
#  min              0.001684          0.000847   -0.005523
#  25%              0.197816          0.194600   -0.004215
#  50%              0.294463          0.290687   -0.002754
#  75%              0.390845          0.386992   -0.001542
#  max              1.305856          1.302752   -0.000012,
#         l2.ratio.mean.ctrl  l2.ratio.mean.us  delta.mean
#  count          665.000000        665.000000  665.000000
#  mean             0.387397          0.211237   -0.176160
#  std              0.148404          0.138767    0.060408
#  min              0.121941          0.001687   -0.526881
#  25%              0.279159          0.102199   -0.201403
#  50%              0.375915          0.195145   -0.157504
#  75%              0.468022          0.293020   -0.134289
#  max              1.123083          0.764322   -0.115128)

# %%
OUTDIR_TOP =  runFimo(FIMO, MEME_TXT, FA_POS, DIRECTION, TOP_QUANTILE)
OUTDIR_BOTTOM =  runFimo(FIMO, MEME_TXT, FA_NEG, DIRECTION, BOTTOM_QUANTILE)
# Out:
# Using motif +CCCWGGCYCCTGC of width 13.
# Using motif -CCCWGGCYCCTGC of width 13.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.996429
# #   Estimated pi_0=0.997789
# Using motif +ASHCWGGMCTGG of width 12.
# Using motif -ASHCWGGMCTGG of width 12.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.997306
# #   Estimated pi_0=0.997789
# Using motif +CAGCWKYYCC of width 10.
# Using motif -CAGCWKYYCC of width 10.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.997423
# #   Estimated pi_0=1
# Using motif +CCCWGGCYCCTGC of width 13.
# Using motif -CCCWGGCYCCTGC of width 13.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.8588
# #   Estimated pi_0=0.866286
# Using motif +ASHCWGGMCTGG of width 12.
# Using motif -ASHCWGGMCTGG of width 12.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.929371
# #   Estimated pi_0=0.933464
# Using motif +CAGCWKYYCC of width 10.
# Using motif -CAGCWKYYCC of width 10.
# Computing q-values.
# # Computing q-values.
# #   Estimating pi_0 from a uniformly sampled set of 10000 p-values.
# #   Estimating pi_0.
# # Minimal pi_zero = 0.940159
# #   Estimated pi_0=0.947904

# %%
bottom_pred = os.path.join(OUTDIR_BOTTOM, "fimo.tsv")
top_pred = os.path.join(OUTDIR_TOP, "fimo.tsv")

tdf = pd.read_csv(top_pred, sep='\t')
tdf["quantile"] = 'top0.9'
tdf["-log10q"] = -1*np.log10(tdf["q-value"])
print(tdf.shape)
tdf.head()

bdf = pd.read_csv(bottom_pred, sep='\t')
bdf["quantile"] = 'bottom0.1'
bdf["-log10q"] = -1*np.log10(bdf["q-value"])
print(bdf.shape)
bdf.head()

# concatenate the top and bottom values
plot = pd.concat([tdf, bdf])

fig, ax = plt.subplots(figsize=(6, 6))
sns.violinplot(x="motif_alt_id", y='-log10q', data=plot, hue="quantile",
               #hue_order=["bottom0.1", "top0.1"],
               order=["MEME-1", "MEME-2", "MEME-3"])
ax.set(ylim=(-0.20,2.75))
ax.legend(frameon=False, loc='upper left')
# Out:
# (315, 12)
# (914, 12)

# %%
# make fa for luciferase tested elements.

# %%
LUC="/wynton/group/ahituv/fongsl/projects/US/data/validation_luc/Candidate_ID_table_luc.txt"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 DATA_PATH
#
# NameError: name 'DATA_PATH' is not defined
