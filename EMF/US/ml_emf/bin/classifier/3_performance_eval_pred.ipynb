# %%
import os, sys
import numpy as np
import pandas as pd

# %%
import h5py

import tensorflow as tf
from tensorflow import keras

# %%
PREFIX = "hepg2.us.ctrl.reg"

MODEL_NAME="DeepSTARR_ATAC"
DATA_PATH = "/wynton/home/ahituv/fongsl/EMF/US/ml_emf/data/deepstarr"

# %%
os.chdir(DATA_PATH)
# write model
#model_json = main_model.to_json()
#with open(f'Model_' + model_name + f'.{prefix}.json', "w") as json_file:
 #   json_file.write(model_json)
    
# load weights
m = os.path.join(DATA_PATH, f'Model_{MODEL_NAME}.{PREFIX}.json')

# %%
# %%bash
# head /wynton/home/ahituv/fongsl/EMF/US/ml_emf/data/deepstarr/Model_DeepSTARR_ATAC.hepg2.us.ctrl.reg.h5
# Out:
# �HDF
#
#
#
#
#
# 	dropout_5	Dense_2
# Dense_US
# activation_13
# Conv1D_1stinput_3

# %%
tf.keras.models.load_model(m)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /scratch/fongsl/ipykernel_2353641/1979968065.py in <module>
# ----> 1 tf.keras.models.load_model(m)
#
# ~/micromamba/envs/DeepSTARR/lib/python3.7/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile)
#     144       h5py is not None and (
#     145           isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 146     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     147
#     148   if isinstance(filepath, six.string_types):
#
# ~/micromamba/envs/DeepSTARR/lib/python3.7/site-packages/tensorflow/python/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     198   opened_new_file = not isinstance(filepath, h5py.File)
#     199   if opened_new_file:
# --> 200     f = h5py.File(filepath, mode='r')
# ...

# %%
list("a"*2)
# Out:
# ['a', 'a']
