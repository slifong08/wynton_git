# %%
import config_readwrite as crw
import matplotlib.pyplot as plt
import numpy as np
import os, sys
import pandas as pd

from scipy import stats
from sklearn.preprocessing import StandardScaler
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

import plot_params as pp
pp.fonts()
# Out:
# ('sans-serif', 'Arial', 18)

# %% [markdown]
# # params

# %%
CL = "hob"
PREFIX = "reg.all.2tasks"
DATA_PATH = f"/wynton/home/ahituv/fongsl/EMF/US/ml_emf/data/deepstarr/deseq2/{CL}/{PREFIX}"
DATA_PATH_SCALED = f"/wynton/home/ahituv/fongsl/EMF/US/ml_emf/data/deepstarr/deseq2/{CL}/reg.all_scaled.10epochs"

# %%
os.chdir(DATA_PATH)

# load predictions
PRED = f'DeepSTARR_ATAC.{PREFIX}.test.predictions.tsv'
TEST = f"{PREFIX}.Sequences_activity_Test.txt"
DIFF_ACC = f"/wynton/group/ahituv/data/US-MPRA/ATAC-seq/Diffbind_results/{CL}_deseq2-nondiff.in.diffAcc.bed"
TEST_CHR = "chr8"

SCALED = True

# %% [markdown]
# # load data

# %% [markdown]
# ## predictions

# %%
pred = pd.read_csv(PRED, sep='\t', skiprows =1, names =["pred0", "pred1"])
print(pred.shape)
pred.head()
# Out:
# (2472, 2)
#       pred0     pred1
# 0 -0.548406 -0.486234
# 1 -0.600183 -0.219371
# 2  0.501898  0.250954
# 3  0.789309  0.266760
# 4 -0.725717 -0.866148

# %% [markdown]
# ## test data

# %%
test = pd.read_csv(TEST, sep='\t')
test["type"] = test["coor.type"].apply(lambda x: x.split("|")[0])

print(test.shape)
test.head()
# Out:
# (2472, 4)
#                           coor.type      ctrl    US_DIF       type
# 0   hob.4316|chr8:19171816-19172087  6.447322 -0.329271   hob.4316
# 1  hob.57968|chr8:19385882-19386153  5.047055 -0.210356  hob.57968
# 2  hob.40397|chr8:47260745-47261016  7.543544 -0.135788  hob.40397
# 3   hob.8805|chr8:22599568-22599839  8.389745 -0.189404   hob.8805
# 4  hob.62830|chr8:23356094-23356365  7.606245 -0.094954  hob.62830

# %%
if SCALED is True:
    sc = StandardScaler()
    test_scaled = pd.DataFrame(sc.fit_transform(test[["US_DIF", "ctrl"]].copy()), 
                              columns = ['US_DIF_scaled', "ctrl_scaled"])
    
    test_scaled = pd.merge(test, test_scaled, left_index=True, right_index=True)

test_scaled
# Out:
#                                coor.type      ctrl    US_DIF       type  \
# 0        hob.4316|chr8:19171816-19172087  6.447322 -0.329271   hob.4316
# 1       hob.57968|chr8:19385882-19386153  5.047055 -0.210356  hob.57968
# 2       hob.40397|chr8:47260745-47261016  7.543544 -0.135788  hob.40397
# 3        hob.8805|chr8:22599568-22599839  8.389745 -0.189404   hob.8805
# 4       hob.62830|chr8:23356094-23356365  7.606245 -0.094954  hob.62830
# ...                                  ...       ...       ...        ...
# 2467  hob.85606|chr8:106047556-106047827  5.120050 -0.137020  hob.85606
# 2468    hob.16807|chr8:70669095-70669366  7.798929 -0.172670  hob.16807
# 2469    hob.24042|chr8:15789086-15789357  5.327867 -0.286471  hob.24042
# 2470    hob.26399|chr8:96103879-96104150  4.693414 -0.345608  hob.26399
# 2471    hob.81879|chr8:17131567-17131838  4.021300 -0.198210  hob.81879
#
#       US_DIF_scaled  ctrl_scaled
# 0         -0.811957     0.695288
# 1         -0.033632    -0.332227
# 2          0.454437     1.499696
# 3          0.103504     2.120637
# 4          0.721707     1.545706
# ...             ...          ...
# 2467       0.446372    -0.278664
# 2468       0.213036     1.687097
# 2469      -0.531824    -0.126167
# 2470      -0.918890    -0.591729
# 2471       0.045871    -1.084926
#
# [2472 rows x 6 columns]

# %% [markdown]
# ## merge all data

# %%
pt = pd.merge(test_scaled, pred, left_index=True, right_index=True)
pt["diff_acc"]=False

# %%
pt.corr()
# Out:
#                    ctrl    US_DIF  US_DIF_scaled  ctrl_scaled     pred0  \
# ctrl           1.000000  0.381195       0.381195     1.000000  0.561211
# US_DIF         0.381195  1.000000       1.000000     0.381195  0.168352
# US_DIF_scaled  0.381195  1.000000       1.000000     0.381195  0.168352
# ctrl_scaled    1.000000  0.381195       0.381195     1.000000  0.561211
# pred0          0.561211  0.168352       0.168352     0.561211  1.000000
# pred1          0.306337  0.133811       0.133811     0.306337  0.645450
# diff_acc            NaN       NaN            NaN          NaN       NaN
#
#                   pred1  diff_acc
# ctrl           0.306337       NaN
# US_DIF         0.133811       NaN
# US_DIF_scaled  0.133811       NaN
# ctrl_scaled    0.306337       NaN
# pred0          0.645450       NaN
# pred1          1.000000       NaN
# diff_acc            NaN       NaN

# %%
sns.jointplot(x="US_DIF_scaled", y="pred1", data=pt, kind="hex")

# %%
dif_acc = pd.read_csv(DIFF_ACC, sep='\t', header=None, 
                      names=["#chr_da", "start_da", "end_da", "id_da", 
                      "#chr_peak","start_peak", "end_peak", "type" ]
                     )
# get true differentially accessible peaks 
test_dif_acc = set(dif_acc.loc[dif_acc["#chr_peak"] == TEST_CHR, "type"])

# annotate ids that are differentially accessible according to DESEQ2
pt.loc[pt["type"].isin(test_dif_acc), "diff_acc"] = True

# %%
len(test_dif_acc)
# Out:
# 81

# %% [markdown]
# ## compute score differences

# %%
pt["ctrl-us"]= pt["ctrl_scaled"] - pt["US_scaled"]
pt["pred_ctrl-pred_us"]= pt["pred_ctrl"] - pt["pred_US"]

# %% [markdown]
# ## correlation between predictions

# %%
sns.jointplot(x="US_DIF_scaled", y="pred1", data=pt, hue = "diff_acc"
              #kind="hex"
             )

# %%
sns.jointplot(x="ctrl_scaled", y="pred0", data=pt,  hue = "diff_acc"
             # kind="hex"
             )

# %%
sns.jointplot(x="ctrl_scaled", y="pred0", data=pt, hue="diff_acc")

# %%
x = "ctrl-us"
y = "pred_ctrl-pred_us"
sns.scatterplot(x=x,y=y, data=pt)
# Out:
# <AxesSubplot:xlabel='ctrl-us', ylabel='pred_ctrl-pred_us'>

# %% [markdown]
# ## evaluate diff accessible

# %%
sns.jointplot(x=x,y=y, data=pt, hue="diff_acc", marginal_kws={"common_norm":False})

# %%
pt.loc[pt["diff_acc"]==True].corr()
# Out:
#                          US      ctrl  US_scaled  ctrl_scaled   pred_US  \
# US                 1.000000  0.537837   1.000000     0.537837  0.419272
# ctrl               0.537837  1.000000   0.537837     1.000000  0.449556
# US_scaled          1.000000  0.537837   1.000000     0.537837  0.419272
# ctrl_scaled        0.537837  1.000000   0.537837     1.000000  0.449556
# pred_US            0.419272  0.449556   0.419272     0.449556  1.000000
# pred_ctrl          0.414859  0.453347   0.414859     0.453347  0.998253
# diff_acc                NaN       NaN        NaN          NaN       NaN
# ctrl-us           -0.271611  0.665274  -0.271611     0.665274  0.141898
# pred_ctrl-pred_us  0.058642  0.201246   0.058642     0.201246  0.282383
#
#                    pred_ctrl  diff_acc   ctrl-us  pred_ctrl-pred_us
# US                  0.414859       NaN -0.271611           0.058642
# ctrl                0.453347       NaN  0.665274           0.201246
# US_scaled           0.414859       NaN -0.271611           0.058642
# ctrl_scaled         0.453347       NaN  0.665274           0.201246
# pred_US             0.998253       NaN  0.141898           0.282383
# pred_ctrl           1.000000       NaN  0.150134           0.338572
# diff_acc                 NaN       NaN       NaN                NaN
# ctrl-us             0.150134       NaN  1.000000           0.177805
# pred_ctrl-pred_us   0.338572       NaN  0.177805           1.000000

# %%
pt.loc[pt["diff_acc"]==True].corr(method="spearman")
# Out:
#                          US      ctrl  US_scaled  ctrl_scaled   pred_US  \
# US                 1.000000  0.476403   1.000000     0.476403  0.359745
# ctrl               0.476403  1.000000   0.476403     1.000000  0.405516
# US_scaled          1.000000  0.476403   1.000000     0.476403  0.359745
# ctrl_scaled        0.476403  1.000000   0.476403     1.000000  0.405516
# pred_US            0.359745  0.405516   0.359745     0.405516  1.000000
# pred_ctrl          0.346310  0.403459   0.346310     0.403459  0.997537
# diff_acc                NaN       NaN        NaN          NaN       NaN
# ctrl-us           -0.377211  0.607467  -0.377211     0.607467  0.067541
# pred_ctrl-pred_us  0.103786  0.240273   0.103786     0.240273  0.566697
#
#                    pred_ctrl  diff_acc   ctrl-us  pred_ctrl-pred_us
# US                  0.346310       NaN -0.377211           0.103786
# ctrl                0.403459       NaN  0.607467           0.240273
# US_scaled           0.346310       NaN -0.377211           0.103786
# ctrl_scaled         0.403459       NaN  0.607467           0.240273
# pred_US             0.997537       NaN  0.067541           0.566697
# pred_ctrl           1.000000       NaN  0.070490           0.598068
# diff_acc                 NaN       NaN       NaN                NaN
# ctrl-us             0.070490       NaN  1.000000           0.128275
# pred_ctrl-pred_us   0.598068       NaN  0.128275           1.000000

# %%
sns.jointplot(x=x,y=y, data=pt.loc[pt["diff_acc"]==True], marginal_kws={"common_norm":False})
